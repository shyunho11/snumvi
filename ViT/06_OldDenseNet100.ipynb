# %%
# !nvidia-smi
# Out:
# Sat Jul 29 13:43:14 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:3B:00.0 Off |                  Off |
# | N/A   29C    P0    58W / 300W |      0MiB / 32768MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch

from monai.apps import download_and_extract
from monai.config import print_config
from monai.utils import set_determinism

print_config()
set_determinism(0)

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.filterwarnings("ignore", category=UserWarning)

#pip install torch==1.12.1+cu113 torchvision==0.13.1+cu113 torchaudio==0.12.1 --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# MONAI version: 1.1.0
# Numpy version: 1.23.5
# Pytorch version: 1.13.1+cu117
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: a2ec3752f54bfc3b40e7952234fbeb5452ed63e3
# MONAI __file__: /home/fastmri2/.conda/envs/snumvi/lib/python3.8/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.4.8
# Nibabel version: 5.0.0
# scikit-image version: 0.19.3
# Pillow version: 10.0.0
# Tensorboard version: 2.11.0
# gdown version: 4.6.0
# TorchVision version: 0.14.1+cu117
# tqdm version: 4.64.1
# lmdb version: 1.4.0
# psutil version: 5.9.5
# pandas version: 1.5.2
# einops version: 0.6.0
# transformers version: 4.25.1
# mlflow version: 2.1.1
# pynrrd version: 1.0.0
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %%
cropped_size = 100

directory = "temp"
if not os.path.exists(directory):
    os.makedirs(directory)
root_dir = tempfile.mkdtemp() if directory is None else directory
data_dir = "cropped/" + str(cropped_size) + str(cropped_size) + str(cropped_size//2)

# %%
#!pip install openpyxl

patient_data = pd.read_excel("new_dataload.xlsx", usecols=['File_Name', 'MVI']).set_index('File_Name')
print(patient_data)
# Out:
#                 MVI
# File_Name
# 0007739.nii.gz    1
# 0020491.nii.gz    1
# 0050368.nii.gz    0
# 0059047.nii.gz    0
# 0063193.nii.gz    1
# ...             ...
# 349.nii.gz        0
# 350.nii.gz        1
# 351.nii.gz        1
# 352.nii.gz        1
# 355.nii.gz        1
#
# [494 rows x 1 columns]

# %%
import random
random.seed(516)

train_images = sorted(glob.glob(os.path.join(data_dir, "*.nii.gz")))
train_labels = [patient_data.loc[os.path.basename(x), "MVI"] for x in train_images]
train_labels = torch.nn.functional.one_hot(torch.as_tensor(train_labels)).float()
data_list = list(zip(train_images, train_labels))
random.shuffle(data_list)
data_dicts = [{"image": image, "label": label} for image, label in data_list]
print(len(data_dicts))
print(data_dicts[0])
# Out:
# 475
# {'image': 'cropped/10010050/0100006.nii.gz', 'label': tensor([0., 1.])}

# %%
train_files, val_files = data_dicts[:400], data_dicts[400:]
set_determinism(seed=0)

# %%
def nii_loader(filename) :
    import nibabel as nib
    import numpy as np
    import matplotlib.pyplot as plt
    nimg = nib.load( filename )
    return nimg.get_fdata() , nimg.affine, nimg.header 

def visualize(dataset, idx=0):
    import matplotlib.pyplot as plt    

    image = dataset[idx]['image']
    label = dataset[idx]['label']
    image_data, image_affine, image_header = nii_loader(image)
    
    print('[file path]', image)
    print('[dimension]', image_data.shape)
    print('[label]', label)
    target_image = image_data[:,:,image_data.shape[2]//2]

    plt.imshow(target_image, cmap='gray' )
    plt.show()
    return tuple(image_data.shape)

# %%
spatial_size = visualize(val_files, idx=1)
# Out:
# [file path] cropped/10010050/250.nii.gz
# [dimension] (100, 100, 50)
# [label] tensor([0., 1.])

# %%
from monai.transforms import (
    Compose,
    LoadImaged,
    EnsureChannelFirstd,
    AddChanneld,
    Orientationd,
    ScaleIntensityRanged,
    CropForegroundd,
    RandAffined,
    SpatialPadd,
    EnsureTyped,
)

# %%
# ScaleIntensityRanged min/max differ by organs
# for liver, min = 30 + 150/2 = 105, max = 30 - 150/2 = -45
# see more info here https://radiopaedia.org/articles/windowing-ct

from monai.transforms import Compose

train_transforms = Compose(
    [
        LoadImaged(keys=["image"]),
        EnsureChannelFirstd(keys=["image"]),
        #AddChanneld(keys=["label"]),
        Orientationd(keys=["image"], axcodes="RAS"),
        #ScaleIntensityRanged(keys=["image"], a_min=-45, a_max=105, b_min=0.0, b_max=1.0, clip=True),
        CropForegroundd(keys=["image"], source_key="image"),
        RandAffined(
            keys=["image"],
            mode=("bilinear"),
            prob=1.0, spatial_size=spatial_size,
            rotate_range=(0, 0, 0),
            scale_range=(0, 0, 0)),
        SpatialPadd(keys=["image"], spatial_size=spatial_size),
        EnsureTyped(keys=["image"]),
    ]
)
val_transforms = Compose(
    [
        LoadImaged(keys=["image"]),
        EnsureChannelFirstd(keys=["image"]),
        #AddChanneld(keys=["label"]),
        Orientationd(keys=["image"], axcodes="RAS"),
        #ScaleIntensityRanged(keys=["image"], a_min=-45, a_max=105, b_min=0.0, b_max=1.0, clip=True),
        CropForegroundd(keys=["image"], source_key="image"),
        SpatialPadd(keys=["image"], spatial_size=spatial_size),
        EnsureTyped(keys=["image"]),
    ]
)

# %%
from monai.data import CacheDataset, DataLoader, Dataset
from monai.utils import first, set_determinism

check_ds = Dataset(data=train_files, transform=train_transforms)
check_loader = DataLoader(check_ds, batch_size=1)
check_data = first(check_loader)
image, label = (check_data["image"][0][0], check_data["label"][0][0])
print(f"image shape: {image.shape}, label shape: {label.shape}")

plt.imshow(image[:, :, spatial_size[2]//2], cmap="gray")
plt.show()
# Out:
# image shape: torch.Size([100, 100, 50]), label shape: torch.Size([])

# %%
from monai.data import CacheDataset, DataLoader

train_ds = CacheDataset(data=train_files, transform=train_transforms, cache_rate=1.0, num_workers=4, progress=True)
train_loader = DataLoader(train_ds, batch_size=4, shuffle=True, num_workers=10)

val_ds = CacheDataset(data=val_files, transform=val_transforms, cache_rate=1.0, num_workers=4, progress=True)
val_loader = DataLoader(val_ds, batch_size=1, num_workers=10)
# Out:
# Loading dataset: 100%|████████████████████████| 400/400 [00:04<00:00, 97.87it/s]
# Loading dataset: 100%|██████████████████████████| 75/75 [00:00<00:00, 99.52it/s]

# %%
from monai.networks.nets import DenseNet264

device = torch.device("cuda:0")
model = DenseNet264(
    spatial_dims=3,
    in_channels=1,
    out_channels=2
).to(device)

# %%
loss_function = torch.nn.BCEWithLogitsLoss()
optimizer = torch.optim.AdamW(model.parameters(), 1e-3)
max_epochs = 100
val_interval = 1
save_interval = 10
best_score = -1
best_score_epoch = -1
epoch_loss_values = []
metric_values = []
model_name = 'Densenet264_' + str(spatial_size[0])

# %%
# %%time

import time

for epoch in range(max_epochs):
    tic_epoch = time.time()
    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step += 1
        inputs, labels = batch_data["image"].to(device), batch_data["label"].to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        if step % 10 ==0:
            print(f"\nepoch {epoch + 1}/{max_epochs} steps {step}/{len(train_ds) // train_loader.batch_size}, |train-loss: {loss.item():.4f}", end='')
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    toc_epoch = time.time()
    dur_epoch = toc_epoch - tic_epoch
    print(f" |avg-loss: {epoch_loss:.4f} dur {dur_epoch:.1f}s ", end='')

    if (epoch + 1) % val_interval == 0:
        model.eval()
        val_count = 0
        val_correct = 0.0
        
        with torch.no_grad():
            for val_data in val_loader:
                inputs, labels = (
                    val_data["image"].to(device),
                    val_data["label"].to(device),
                )
                outputs = model(inputs)
                val_result = torch.eq(outputs.argmax(dim=1), labels.argmax(dim=1))
                val_count += len(val_result)
                val_correct += val_result.sum().item()
            
            val_score = val_correct / val_count
            metric_values.append(val_score)
            print(f"|val-acc: {val_score:.4f} |old-best: {best_score:.4f} " , end="")
            
            if val_score > best_score:
                best_score = val_score
                best_score_epoch = epoch + 1
                torch.save(model.state_dict(), os.path.join(root_dir, "{}_model_best.pth".format(model_name)))
                torch.save(optimizer.state_dict(), os.path.join(root_dir, "{}_optim_best.pth".format(model_name)))
                print("|best model saved", end="")
    
    if (epoch+1) % save_interval == 0:
        torch.save(model.state_dict(), os.path.join(root_dir, "{}_model_{:04d}.pth".format(model_name, epoch+1)))
        torch.save(optimizer.state_dict(), os.path.join(root_dir, "{}_optim_{:04d}.pth".format(model_name, epoch+1)))
        print("|{}ep model saved".format(epoch+1), end='')
                            
print(f"\ntrain completed, best_metric: {best_score:.4f} at epoch: {best_score_epoch} for {max_epochs} epoches")
# Out:
# epoch 1/100 steps 10/100, |train-loss: 0.5769
# epoch 1/100 steps 20/100, |train-loss: 0.5747
# epoch 1/100 steps 30/100, |train-loss: 0.6305
# epoch 1/100 steps 40/100, |train-loss: 0.7411
# epoch 1/100 steps 50/100, |train-loss: 0.4546
# epoch 1/100 steps 60/100, |train-loss: 0.7549
# epoch 1/100 steps 70/100, |train-loss: 0.5210
# epoch 1/100 steps 80/100, |train-loss: 0.7535
# epoch 1/100 steps 90/100, |train-loss: 0.7671
# epoch 1/100 steps 100/100, |train-loss: 1.0283 |avg-loss: 0.7734 dur 31.6s |val-acc: 0.4400 |old-best: -1.0000 |best model saved
# epoch 2/100 steps 10/100, |train-loss: 0.8239
# epoch 2/100 steps 20/100, |train-loss: 0.5186
# epoch 2/100 steps 30/100, |train-loss: 1.8659
# epoch 2/100 steps 40/100, |train-loss: 1.0208
# epoch 2/100 steps 50/100, |train-loss: 0.9832
# epoch 2/100 steps 60/100, |train-loss: 0.4450
# epoch 2/100 steps 70/100, |train-loss: 0.8809
# epoch 2/100 steps 80/100, |train-loss: 0.8909
# epoch 2/100 steps 90/100, |train-loss: 0.8912
# epoch 2/100 steps 100/100, |train-loss: 1.4607 |avg-loss: 0.7589 dur 31.4s |val-acc: 0.6267 |old-best: 0.4400 |best model saved
# epoch 3/100 steps 10/100, |train-loss: 0.7383
# epoch 3/100 steps 20/100, |train-loss: 0.7120
# epoch 3/100 steps 30/100, |train-loss: 0.5005
# epoch 3/100 steps 40/100, |train-loss: 0.7914
# epoch 3/100 steps 50/100, |train-loss: 0.6405
# epoch 3/100 steps 60/100, |train-loss: 0.8533
# epoch 3/100 steps 70/100, |train-loss: 0.7697
# epoch 3/100 steps 80/100, |train-loss: 0.6383
# epoch 3/100 steps 90/100, |train-loss: 0.6104
# epoch 3/100 steps 100/100, |train-loss: 0.6641 |avg-loss: 0.7252 dur 31.5s |val-acc: 0.5867 |old-best: 0.6267
# epoch 4/100 steps 10/100, |train-loss: 0.6206
# epoch 4/100 steps 20/100, |train-loss: 0.8440
# epoch 4/100 steps 30/100, |train-loss: 0.7604
# epoch 4/100 steps 40/100, |train-loss: 0.9025
# epoch 4/100 steps 50/100, |train-loss: 0.5044
# epoch 4/100 steps 60/100, |train-loss: 1.5280
# epoch 4/100 steps 70/100, |train-loss: 0.8578
# epoch 4/100 steps 80/100, |train-loss: 0.4020
# epoch 4/100 steps 90/100, |train-loss: 1.3540
# epoch 4/100 steps 100/100, |train-loss: 1.0181 |avg-loss: 0.7739 dur 31.2s |val-acc: 0.5067 |old-best: 0.6267
# epoch 5/100 steps 10/100, |train-loss: 0.5906
# epoch 5/100 steps 20/100, |train-loss: 0.7076
# epoch 5/100 steps 30/100, |train-loss: 0.8160
# epoch 5/100 steps 40/100, |train-loss: 0.6506
# epoch 5/100 steps 50/100, |train-loss: 0.6573
# epoch 5/100 steps 60/100, |train-loss: 0.7829
# epoch 5/100 steps 70/100, |train-loss: 0.5062
# epoch 5/100 steps 80/100, |train-loss: 0.5895
# epoch 5/100 steps 90/100, |train-loss: 0.8127
# epoch 5/100 steps 100/100, |train-loss: 0.7519 |avg-loss: 0.7331 dur 31.4s |val-acc: 0.6667 |old-best: 0.6267 |best model saved
# epoch 6/100 steps 10/100, |train-loss: 0.7880
# epoch 6/100 steps 20/100, |train-loss: 0.5132
# epoch 6/100 steps 30/100, |train-loss: 0.7410
# epoch 6/100 steps 40/100, |train-loss: 0.5460
# epoch 6/100 steps 50/100, |train-loss: 0.8181
# epoch 6/100 steps 60/100, |train-loss: 0.6185
# epoch 6/100 steps 70/100, |train-loss: 1.0573
# epoch 6/100 steps 80/100, |train-loss: 0.9476
# epoch 6/100 steps 90/100, |train-loss: 0.6063
# epoch 6/100 steps 100/100, |train-loss: 1.2027 |avg-loss: 0.7438 dur 31.3s |val-acc: 0.6267 |old-best: 0.6667
# epoch 7/100 steps 10/100, |train-loss: 0.7888
# epoch 7/100 steps 20/100, |train-loss: 0.6635
# epoch 7/100 steps 30/100, |train-loss: 0.7022
# epoch 7/100 steps 40/100, |train-loss: 0.5794
# epoch 7/100 steps 50/100, |train-loss: 0.6862
# epoch 7/100 steps 60/100, |train-loss: 0.8516
# epoch 7/100 steps 70/100, |train-loss: 0.5752
# epoch 7/100 steps 80/100, |train-loss: 0.9764
# epoch 7/100 steps 90/100, |train-loss: 0.7766
# epoch 7/100 steps 100/100, |train-loss: 0.6613 |avg-loss: 0.7244 dur 31.3s |val-acc: 0.6667 |old-best: 0.6667
# epoch 8/100 steps 10/100, |train-loss: 0.8796
# epoch 8/100 steps 20/100, |train-loss: 0.8430
# epoch 8/100 steps 30/100, |train-loss: 0.7818
# epoch 8/100 steps 40/100, |train-loss: 0.6625
# epoch 8/100 steps 50/100, |train-loss: 0.7774
# epoch 8/100 steps 60/100, |train-loss: 0.5340
# epoch 8/100 steps 70/100, |train-loss: 0.6008
# epoch 8/100 steps 80/100, |train-loss: 0.5980
# epoch 8/100 steps 90/100, |train-loss: 0.9367
# epoch 8/100 steps 100/100, |train-loss: 0.8106 |avg-loss: 0.7074 dur 31.3s |val-acc: 0.6800 |old-best: 0.6667 |best model saved
# epoch 9/100 steps 10/100, |train-loss: 0.6247
# epoch 9/100 steps 20/100, |train-loss: 0.7902
# epoch 9/100 steps 30/100, |train-loss: 0.6306
# epoch 9/100 steps 40/100, |train-loss: 0.8120
# epoch 9/100 steps 50/100, |train-loss: 0.7217
# epoch 9/100 steps 60/100, |train-loss: 0.5690
# epoch 9/100 steps 70/100, |train-loss: 0.6564
# epoch 9/100 steps 80/100, |train-loss: 0.7759
# epoch 9/100 steps 90/100, |train-loss: 0.8945
# epoch 9/100 steps 100/100, |train-loss: 0.7571 |avg-loss: 0.6951 dur 31.2s |val-acc: 0.5333 |old-best: 0.6800
# epoch 10/100 steps 10/100, |train-loss: 0.7467
# epoch 10/100 steps 20/100, |train-loss: 0.6447
# epoch 10/100 steps 30/100, |train-loss: 0.7008
# epoch 10/100 steps 40/100, |train-loss: 0.7026
# epoch 10/100 steps 50/100, |train-loss: 0.7342
# epoch 10/100 steps 60/100, |train-loss: 0.6527
# epoch 10/100 steps 70/100, |train-loss: 0.6920
# epoch 10/100 steps 80/100, |train-loss: 0.5086
# epoch 10/100 steps 90/100, |train-loss: 0.5750
# epoch 10/100 steps 100/100, |train-loss: 0.5775 |avg-loss: 0.6872 dur 31.2s |val-acc: 0.6267 |old-best: 0.6800 |10ep model saved
# epoch 11/100 steps 10/100, |train-loss: 0.4683
# epoch 11/100 steps 20/100, |train-loss: 0.6886
# epoch 11/100 steps 30/100, |train-loss: 0.6794
# epoch 11/100 steps 40/100, |train-loss: 0.7186
# epoch 11/100 steps 50/100, |train-loss: 0.6392
# epoch 11/100 steps 60/100, |train-loss: 0.6840
# epoch 11/100 steps 70/100, |train-loss: 0.6779
# epoch 11/100 steps 80/100, |train-loss: 0.5719
# epoch 11/100 steps 90/100, |train-loss: 0.7368
# epoch 11/100 steps 100/100, |train-loss: 0.7017 |avg-loss: 0.6926 dur 31.0s |val-acc: 0.5600 |old-best: 0.6800
# epoch 12/100 steps 10/100, |train-loss: 0.6460
# epoch 12/100 steps 20/100, |train-loss: 0.7422
# epoch 12/100 steps 30/100, |train-loss: 0.9533
# epoch 12/100 steps 40/100, |train-loss: 0.6097
# epoch 12/100 steps 50/100, |train-loss: 0.6931
# epoch 12/100 steps 60/100, |train-loss: 0.6544
# epoch 12/100 steps 70/100, |train-loss: 0.8445
# epoch 12/100 steps 80/100, |train-loss: 0.7990
# epoch 12/100 steps 90/100, |train-loss: 0.6458
# epoch 12/100 steps 100/100, |train-loss: 0.6783 |avg-loss: 0.6968 dur 31.3s |val-acc: 0.5467 |old-best: 0.6800
# epoch 13/100 steps 10/100, |train-loss: 0.7205
# epoch 13/100 steps 20/100, |train-loss: 0.5091
# epoch 13/100 steps 30/100, |train-loss: 0.8020
# epoch 13/100 steps 40/100, |train-loss: 0.6498
# epoch 13/100 steps 50/100, |train-loss: 0.6786
# epoch 13/100 steps 60/100, |train-loss: 0.7028
# epoch 13/100 steps 70/100, |train-loss: 0.7887
# epoch 13/100 steps 80/100, |train-loss: 0.8890
# epoch 13/100 steps 90/100, |train-loss: 0.6912
# epoch 13/100 steps 100/100, |train-loss: 0.7399 |avg-loss: 0.7000 dur 31.1s |val-acc: 0.6133 |old-best: 0.6800
# epoch 14/100 steps 10/100, |train-loss: 0.6986
# epoch 14/100 steps 20/100, |train-loss: 0.7385
# epoch 14/100 steps 30/100, |train-loss: 0.7196
# epoch 14/100 steps 40/100, |train-loss: 0.6103
# epoch 14/100 steps 50/100, |train-loss: 0.8029
# epoch 14/100 steps 60/100, |train-loss: 0.6636
# epoch 14/100 steps 70/100, |train-loss: 0.7307
# epoch 14/100 steps 80/100, |train-loss: 0.7625
# epoch 14/100 steps 90/100, |train-loss: 0.6506
# epoch 14/100 steps 100/100, |train-loss: 0.6854 |avg-loss: 0.6936 dur 31.0s |val-acc: 0.6533 |old-best: 0.6800
# epoch 15/100 steps 10/100, |train-loss: 0.6848
# epoch 15/100 steps 20/100, |train-loss: 0.5758
# epoch 15/100 steps 30/100, |train-loss: 0.8017
# epoch 15/100 steps 40/100, |train-loss: 0.6707
# epoch 15/100 steps 50/100, |train-loss: 0.6486
# epoch 15/100 steps 60/100, |train-loss: 0.5986
# epoch 15/100 steps 70/100, |train-loss: 0.5962
# epoch 15/100 steps 80/100, |train-loss: 0.7438
# epoch 15/100 steps 90/100, |train-loss: 0.7476
# epoch 15/100 steps 100/100, |train-loss: 0.6444 |avg-loss: 0.6928 dur 31.6s |val-acc: 0.5333 |old-best: 0.6800
# epoch 16/100 steps 10/100, |train-loss: 0.7262
# epoch 16/100 steps 20/100, |train-loss: 0.7099
# epoch 16/100 steps 30/100, |train-loss: 0.7073
# epoch 16/100 steps 40/100, |train-loss: 0.7053
# epoch 16/100 steps 50/100, |train-loss: 0.8896
# epoch 16/100 steps 60/100, |train-loss: 0.7813
# epoch 16/100 steps 70/100, |train-loss: 0.5494
# epoch 16/100 steps 80/100, |train-loss: 0.6867
# epoch 16/100 steps 90/100, |train-loss: 0.6007
# epoch 16/100 steps 100/100, |train-loss: 0.8960 |avg-loss: 0.6889 dur 31.4s |val-acc: 0.6267 |old-best: 0.6800
# epoch 17/100 steps 10/100, |train-loss: 0.6644
# epoch 17/100 steps 20/100, |train-loss: 0.6621
# epoch 17/100 steps 30/100, |train-loss: 0.7738
# epoch 17/100 steps 40/100, |train-loss: 0.7139
# epoch 17/100 steps 50/100, |train-loss: 0.6875
# epoch 17/100 steps 60/100, |train-loss: 0.8259
# epoch 17/100 steps 70/100, |train-loss: 0.4975
# epoch 17/100 steps 80/100, |train-loss: 0.6994
# epoch 17/100 steps 90/100, |train-loss: 0.6117
# epoch 17/100 steps 100/100, |train-loss: 0.6492 |avg-loss: 0.6946 dur 31.5s |val-acc: 0.6267 |old-best: 0.6800
# epoch 18/100 steps 10/100, |train-loss: 0.7433
# epoch 18/100 steps 20/100, |train-loss: 0.6403
# epoch 18/100 steps 30/100, |train-loss: 0.8782
# epoch 18/100 steps 40/100, |train-loss: 0.6106
# epoch 18/100 steps 50/100, |train-loss: 0.6747
# epoch 18/100 steps 60/100, |train-loss: 0.7639
# epoch 18/100 steps 70/100, |train-loss: 0.6856
# epoch 18/100 steps 80/100, |train-loss: 0.6306
# epoch 18/100 steps 90/100, |train-loss: 0.7715
# epoch 18/100 steps 100/100, |train-loss: 0.5396 |avg-loss: 0.6820 dur 31.3s |val-acc: 0.4267 |old-best: 0.6800
# epoch 19/100 steps 10/100, |train-loss: 0.6623
# epoch 19/100 steps 20/100, |train-loss: 0.6055
# epoch 19/100 steps 30/100, |train-loss: 0.8447
# epoch 19/100 steps 40/100, |train-loss: 0.6365
# epoch 19/100 steps 50/100, |train-loss: 0.5667
# epoch 19/100 steps 60/100, |train-loss: 0.7305
# epoch 19/100 steps 70/100, |train-loss: 0.5457
# epoch 19/100 steps 80/100, |train-loss: 0.5672
# epoch 19/100 steps 90/100, |train-loss: 0.6870
# epoch 19/100 steps 100/100, |train-loss: 0.7227 |avg-loss: 0.7039 dur 31.5s |val-acc: 0.4533 |old-best: 0.6800
# epoch 20/100 steps 10/100, |train-loss: 0.7934
# epoch 20/100 steps 20/100, |train-loss: 0.5061
# epoch 20/100 steps 30/100, |train-loss: 0.8214
# epoch 20/100 steps 40/100, |train-loss: 0.7654
# epoch 20/100 steps 50/100, |train-loss: 0.6957
# epoch 20/100 steps 60/100, |train-loss: 0.6641
# epoch 20/100 steps 70/100, |train-loss: 0.6597
# epoch 20/100 steps 80/100, |train-loss: 0.6698
# epoch 20/100 steps 90/100, |train-loss: 0.6072
# epoch 20/100 steps 100/100, |train-loss: 0.9516 |avg-loss: 0.6906 dur 31.3s |val-acc: 0.6267 |old-best: 0.6800 |20ep model saved
# epoch 21/100 steps 10/100, |train-loss: 0.6280
# epoch 21/100 steps 20/100, |train-loss: 0.7385
# epoch 21/100 steps 30/100, |train-loss: 0.7908
# epoch 21/100 steps 40/100, |train-loss: 0.8908
# epoch 21/100 steps 50/100, |train-loss: 0.6156
# epoch 21/100 steps 60/100, |train-loss: 0.6179
# epoch 21/100 steps 70/100, |train-loss: 0.7575
# epoch 21/100 steps 80/100, |train-loss: 0.6919
# epoch 21/100 steps 90/100, |train-loss: 0.6318
# epoch 21/100 steps 100/100, |train-loss: 0.5981 |avg-loss: 0.7107 dur 31.5s |val-acc: 0.6400 |old-best: 0.6800
# epoch 22/100 steps 10/100, |train-loss: 0.6676
# epoch 22/100 steps 20/100, |train-loss: 0.5664
# epoch 22/100 steps 30/100, |train-loss: 0.8398
# epoch 22/100 steps 40/100, |train-loss: 0.9241
# epoch 22/100 steps 50/100, |train-loss: 0.7077
# epoch 22/100 steps 60/100, |train-loss: 0.7051
# epoch 22/100 steps 70/100, |train-loss: 0.5969
# epoch 22/100 steps 80/100, |train-loss: 0.6090
# epoch 22/100 steps 90/100, |train-loss: 0.7816
# epoch 22/100 steps 100/100, |train-loss: 0.4424 |avg-loss: 0.6971 dur 31.4s |val-acc: 0.6267 |old-best: 0.6800
# epoch 23/100 steps 10/100, |train-loss: 0.6572
# epoch 23/100 steps 20/100, |train-loss: 0.7574
# epoch 23/100 steps 30/100, |train-loss: 0.7003
# epoch 23/100 steps 40/100, |train-loss: 0.7194
# epoch 23/100 steps 50/100, |train-loss: 0.6517
# epoch 23/100 steps 60/100, |train-loss: 0.7722
# epoch 23/100 steps 70/100, |train-loss: 0.7558
# epoch 23/100 steps 80/100, |train-loss: 0.5645
# epoch 23/100 steps 90/100, |train-loss: 0.7037
# epoch 23/100 steps 100/100, |train-loss: 0.4935 |avg-loss: 0.6818 dur 31.1s |val-acc: 0.6400 |old-best: 0.6800
# epoch 24/100 steps 10/100, |train-loss: 0.7298
# epoch 24/100 steps 20/100, |train-loss: 0.6899
# epoch 24/100 steps 30/100, |train-loss: 0.7838
# epoch 24/100 steps 40/100, |train-loss: 0.5915
# epoch 24/100 steps 50/100, |train-loss: 0.5623
# epoch 24/100 steps 60/100, |train-loss: 0.7212
# epoch 24/100 steps 70/100, |train-loss: 0.7080
# epoch 24/100 steps 80/100, |train-loss: 0.7101
# epoch 24/100 steps 90/100, |train-loss: 0.6962
# epoch 24/100 steps 100/100, |train-loss: 0.6527 |avg-loss: 0.7050 dur 31.3s |val-acc: 0.6267 |old-best: 0.6800
# epoch 25/100 steps 10/100, |train-loss: 0.5697
# epoch 25/100 steps 20/100, |train-loss: 0.4668
# epoch 25/100 steps 30/100, |train-loss: 0.6618
# epoch 25/100 steps 40/100, |train-loss: 0.5161
# epoch 25/100 steps 50/100, |train-loss: 0.7136
# epoch 25/100 steps 60/100, |train-loss: 0.7258
# epoch 25/100 steps 70/100, |train-loss: 0.7510
# epoch 25/100 steps 80/100, |train-loss: 0.6794
# epoch 25/100 steps 90/100, |train-loss: 0.6562
# epoch 25/100 steps 100/100, |train-loss: 0.8544 |avg-loss: 0.6994 dur 31.4s |val-acc: 0.6267 |old-best: 0.6800
# epoch 26/100 steps 10/100, |train-loss: 0.7236
# epoch 26/100 steps 20/100, |train-loss: 0.7408
# epoch 26/100 steps 30/100, |train-loss: 0.7307
# epoch 26/100 steps 40/100, |train-loss: 0.6203
# epoch 26/100 steps 50/100, |train-loss: 0.6506
# epoch 26/100 steps 60/100, |train-loss: 0.7977
# epoch 26/100 steps 70/100, |train-loss: 0.7542
# epoch 26/100 steps 80/100, |train-loss: 0.7137
# epoch 26/100 steps 90/100, |train-loss: 0.6251
# epoch 26/100 steps 100/100, |train-loss: 0.6931 |avg-loss: 0.6958 dur 31.4s |val-acc: 0.6267 |old-best: 0.6800
# epoch 27/100 steps 10/100, |train-loss: 0.6533
# epoch 27/100 steps 20/100, |train-loss: 0.6869
# epoch 27/100 steps 30/100, |train-loss: 0.5520
# epoch 27/100 steps 40/100, |train-loss: 0.5854
# epoch 27/100 steps 50/100, |train-loss: 0.6061
# epoch 27/100 steps 60/100, |train-loss: 0.6770
# epoch 27/100 steps 70/100, |train-loss: 0.6857
# epoch 27/100 steps 80/100, |train-loss: 0.6671
# epoch 27/100 steps 90/100, |train-loss: 0.7080
# epoch 27/100 steps 100/100, |train-loss: 0.7111 |avg-loss: 0.6880 dur 31.7s |val-acc: 0.6267 |old-best: 0.6800
# epoch 28/100 steps 10/100, |train-loss: 0.6336
# epoch 28/100 steps 20/100, |train-loss: 0.7773
# epoch 28/100 steps 30/100, |train-loss: 0.5532
# epoch 28/100 steps 40/100, |train-loss: 0.5345
# epoch 28/100 steps 50/100, |train-loss: 0.7788
# epoch 28/100 steps 60/100, |train-loss: 0.7644
# epoch 28/100 steps 70/100, |train-loss: 0.6243
# epoch 28/100 steps 80/100, |train-loss: 0.6299
# epoch 28/100 steps 90/100, |train-loss: 0.7312
# epoch 28/100 steps 100/100, |train-loss: 0.6593 |avg-loss: 0.6837 dur 31.3s |val-acc: 0.5333 |old-best: 0.6800
# epoch 29/100 steps 10/100, |train-loss: 0.6737
# epoch 29/100 steps 20/100, |train-loss: 0.6503
# epoch 29/100 steps 30/100, |train-loss: 0.6659
# epoch 29/100 steps 40/100, |train-loss: 0.7406
# epoch 29/100 steps 50/100, |train-loss: 0.6376
# epoch 29/100 steps 60/100, |train-loss: 0.5802
# epoch 29/100 steps 70/100, |train-loss: 0.5792
# epoch 29/100 steps 80/100, |train-loss: 0.6725
# epoch 29/100 steps 90/100, |train-loss: 0.5944
# epoch 29/100 steps 100/100, |train-loss: 0.6502 |avg-loss: 0.6853 dur 31.3s |val-acc: 0.6267 |old-best: 0.6800
# epoch 30/100 steps 10/100, |train-loss: 0.5886
# epoch 30/100 steps 20/100, |train-loss: 0.6027
# epoch 30/100 steps 30/100, |train-loss: 0.5929
# epoch 30/100 steps 40/100, |train-loss: 0.7957
# epoch 30/100 steps 50/100, |train-loss: 0.6574
# epoch 30/100 steps 60/100, |train-loss: 0.6555
# epoch 30/100 steps 70/100, |train-loss: 0.7205
# epoch 30/100 steps 80/100, |train-loss: 0.6577
# epoch 30/100 steps 90/100, |train-loss: 0.5994
# epoch 30/100 steps 100/100, |train-loss: 0.7192 |avg-loss: 0.6887 dur 31.3s |val-acc: 0.6267 |old-best: 0.6800 |30ep model saved
# epoch 31/100 steps 10/100, |train-loss: 0.7184
# epoch 31/100 steps 20/100, |train-loss: 0.8116
# epoch 31/100 steps 30/100, |train-loss: 0.6215
# epoch 31/100 steps 40/100, |train-loss: 0.6458
# epoch 31/100 steps 50/100, |train-loss: 0.6784
# epoch 31/100 steps 60/100, |train-loss: 0.6528
# epoch 31/100 steps 70/100, |train-loss: 0.6575
# epoch 31/100 steps 80/100, |train-loss: 0.5725
# epoch 31/100 steps 90/100, |train-loss: 0.5312
# epoch 31/100 steps 100/100, |train-loss: 0.8136 |avg-loss: 0.6888 dur 31.5s |val-acc: 0.6267 |old-best: 0.6800
# epoch 32/100 steps 10/100, |train-loss: 0.7281
# epoch 32/100 steps 20/100, |train-loss: 0.6111
# epoch 32/100 steps 30/100, |train-loss: 0.6548
# epoch 32/100 steps 40/100, |train-loss: 0.7538
# epoch 32/100 steps 50/100, |train-loss: 0.6385
# epoch 32/100 steps 60/100, |train-loss: 0.6682
# epoch 32/100 steps 70/100, |train-loss: 0.6220
# epoch 32/100 steps 80/100, |train-loss: 0.6369
# epoch 32/100 steps 90/100, |train-loss: 0.7542
# epoch 32/100 steps 100/100, |train-loss: 0.5850 |avg-loss: 0.6881 dur 31.2s |val-acc: 0.6267 |old-best: 0.6800
# epoch 33/100 steps 10/100, |train-loss: 0.5839
# epoch 33/100 steps 20/100, |train-loss: 0.7697
# epoch 33/100 steps 30/100, |train-loss: 0.7513
# epoch 33/100 steps 40/100, |train-loss: 0.6902
# epoch 33/100 steps 50/100, |train-loss: 0.7367
# epoch 33/100 steps 60/100, |train-loss: 0.5401
# epoch 33/100 steps 70/100, |train-loss: 0.7776
# epoch 33/100 steps 80/100, |train-loss: 0.6133
# epoch 33/100 steps 90/100, |train-loss: 0.7057
# epoch 33/100 steps 100/100, |train-loss: 0.7280 |avg-loss: 0.6846 dur 31.4s |val-acc: 0.6267 |old-best: 0.6800
# epoch 34/100 steps 10/100, |train-loss: 0.8106
# epoch 34/100 steps 20/100, |train-loss: 0.6341
# epoch 34/100 steps 30/100, |train-loss: 0.7394
# epoch 34/100 steps 40/100, |train-loss: 0.7325
# epoch 34/100 steps 50/100, |train-loss: 0.6509
# epoch 34/100 steps 60/100, |train-loss: 0.6799
# epoch 34/100 steps 70/100, |train-loss: 0.6590
# epoch 34/100 steps 80/100, |train-loss: 0.6704
# epoch 34/100 steps 90/100, |train-loss: 0.7686
# epoch 34/100 steps 100/100, |train-loss: 0.6673 |avg-loss: 0.6905 dur 31.4s |val-acc: 0.6267 |old-best: 0.6800
# epoch 35/100 steps 10/100, |train-loss: 0.6558
# epoch 35/100 steps 20/100, |train-loss: 0.6658
# epoch 35/100 steps 30/100, |train-loss: 0.6355
# epoch 35/100 steps 40/100, |train-loss: 0.7911
# epoch 35/100 steps 50/100, |train-loss: 0.8170
# epoch 35/100 steps 60/100, |train-loss: 0.6799
# epoch 35/100 steps 70/100, |train-loss: 0.6998
# epoch 35/100 steps 80/100, |train-loss: 0.6966
# epoch 35/100 steps 90/100, |train-loss: 0.6820
# epoch 35/100 steps 100/100, |train-loss: 0.6459 |avg-loss: 0.6881 dur 31.4s |val-acc: 0.6267 |old-best: 0.6800
# epoch 36/100 steps 10/100, |train-loss: 0.6718
# epoch 36/100 steps 20/100, |train-loss: 0.7422
# epoch 36/100 steps 30/100, |train-loss: 0.7129
# epoch 36/100 steps 40/100, |train-loss: 0.5482
# epoch 36/100 steps 50/100, |train-loss: 0.7668
# epoch 36/100 steps 60/100, |train-loss: 0.9487
# epoch 36/100 steps 70/100, |train-loss: 0.7555
# epoch 36/100 steps 80/100, |train-loss: 0.7666
# epoch 36/100 steps 90/100, |train-loss: 0.6855
# epoch 36/100 steps 100/100, |train-loss: 0.6104 |avg-loss: 0.6864 dur 31.2s |val-acc: 0.6267 |old-best: 0.6800
# epoch 37/100 steps 10/100, |train-loss: 0.7039
# epoch 37/100 steps 20/100, |train-loss: 0.7502
# epoch 37/100 steps 30/100, |train-loss: 0.5651
# epoch 37/100 steps 40/100, |train-loss: 0.6708
# epoch 37/100 steps 50/100, |train-loss: 0.7760
# epoch 37/100 steps 60/100, |train-loss: 0.5359
# epoch 37/100 steps 70/100, |train-loss: 0.6671
# epoch 37/100 steps 80/100, |train-loss: 0.6550
# epoch 37/100 steps 90/100, |train-loss: 0.6960
# epoch 37/100 steps 100/100, |train-loss: 0.5938 |avg-loss: 0.6826 dur 31.2s |val-acc: 0.6267 |old-best: 0.6800
# epoch 38/100 steps 10/100, |train-loss: 0.6910
# epoch 38/100 steps 20/100, |train-loss: 0.6605
# epoch 38/100 steps 30/100, |train-loss: 0.6959
# epoch 38/100 steps 40/100, |train-loss: 0.6256
# epoch 38/100 steps 50/100, |train-loss: 0.7512
# epoch 38/100 steps 60/100, |train-loss: 0.6334
# epoch 38/100 steps 70/100, |train-loss: 0.7771
# epoch 38/100 steps 80/100, |train-loss: 0.7097
# epoch 38/100 steps 90/100, |train-loss: 0.6115
# epoch 38/100 steps 100/100, |train-loss: 0.5248 |avg-loss: 0.6827 dur 31.3s |val-acc: 0.6267 |old-best: 0.6800
# epoch 39/100 steps 10/100, |train-loss: 0.7752
# epoch 39/100 steps 20/100, |train-loss: 0.4863
# epoch 39/100 steps 30/100, |train-loss: 0.6537
# epoch 39/100 steps 40/100, |train-loss: 0.7104
# epoch 39/100 steps 50/100, |train-loss: 0.7467
# epoch 39/100 steps 60/100, |train-loss: 0.7881
# epoch 39/100 steps 70/100, |train-loss: 0.6948
# epoch 39/100 steps 80/100, |train-loss: 0.6778
# epoch 39/100 steps 90/100, |train-loss: 0.6604
# epoch 39/100 steps 100/100, |train-loss: 0.6930 |avg-loss: 0.6829 dur 31.3s |val-acc: 0.6267 |old-best: 0.6800
# epoch 40/100 steps 10/100, |train-loss: 0.7427
# epoch 40/100 steps 20/100, |train-loss: 0.7015
# epoch 40/100 steps 30/100, |train-loss: 0.7421
# epoch 40/100 steps 40/100, |train-loss: 0.6992
# epoch 40/100 steps 50/100, |train-loss: 0.6975
# epoch 40/100 steps 60/100, |train-loss: 0.6780
# epoch 40/100 steps 70/100, |train-loss: 0.8462
# epoch 40/100 steps 80/100, |train-loss: 0.6474
# epoch 40/100 steps 90/100, |train-loss: 0.5858
# epoch 40/100 steps 100/100, |train-loss: 0.6072 |avg-loss: 0.6813 dur 31.1s |val-acc: 0.6267 |old-best: 0.6800 |40ep model saved
# epoch 41/100 steps 10/100, |train-loss: 0.5902
# epoch 41/100 steps 20/100, |train-loss: 0.7044
# epoch 41/100 steps 30/100, |train-loss: 0.6567
# epoch 41/100 steps 40/100, |train-loss: 0.5688
# epoch 41/100 steps 50/100, |train-loss: 0.6155
# epoch 41/100 steps 60/100, |train-loss: 0.5881
# epoch 41/100 steps 70/100, |train-loss: 0.7555
# epoch 41/100 steps 80/100, |train-loss: 0.5775
# epoch 41/100 steps 90/100, |train-loss: 0.5907
# epoch 41/100 steps 100/100, |train-loss: 0.5325 |avg-loss: 0.6826 dur 31.2s |val-acc: 0.6000 |old-best: 0.6800
# epoch 42/100 steps 10/100, |train-loss: 0.7571
# epoch 42/100 steps 20/100, |train-loss: 0.6411
# epoch 42/100 steps 30/100, |train-loss: 0.5276
# epoch 42/100 steps 40/100, |train-loss: 0.6146
# epoch 42/100 steps 50/100, |train-loss: 0.6557
# epoch 42/100 steps 60/100, |train-loss: 0.6939
# epoch 42/100 steps 70/100, |train-loss: 0.8605
# epoch 42/100 steps 80/100, |train-loss: 0.6963
# epoch 42/100 steps 90/100, |train-loss: 0.7055
# epoch 42/100 steps 100/100, |train-loss: 0.6247 |avg-loss: 0.6913 dur 31.2s |val-acc: 0.5600 |old-best: 0.6800
# epoch 43/100 steps 10/100, |train-loss: 0.7861
# epoch 43/100 steps 20/100, |train-loss: 0.6594
# epoch 43/100 steps 30/100, |train-loss: 0.7086
# epoch 43/100 steps 40/100, |train-loss: 0.6544
# epoch 43/100 steps 50/100, |train-loss: 0.7416
# epoch 43/100 steps 60/100, |train-loss: 0.7371
# epoch 43/100 steps 70/100, |train-loss: 0.6656
# epoch 43/100 steps 80/100, |train-loss: 0.6171
# epoch 43/100 steps 90/100, |train-loss: 0.7896
# epoch 43/100 steps 100/100, |train-loss: 0.5835 |avg-loss: 0.6852 dur 31.2s |val-acc: 0.6933 |old-best: 0.6800 |best model saved
# epoch 44/100 steps 10/100, |train-loss: 0.5976
# epoch 44/100 steps 20/100, |train-loss: 0.5386
# epoch 44/100 steps 30/100, |train-loss: 0.5826
# epoch 44/100 steps 40/100, |train-loss: 0.5917
# epoch 44/100 steps 50/100, |train-loss: 0.6405
# epoch 44/100 steps 60/100, |train-loss: 0.7647
# epoch 44/100 steps 70/100, |train-loss: 0.7906
# epoch 44/100 steps 80/100, |train-loss: 0.7908
# epoch 44/100 steps 90/100, |train-loss: 0.8176
# epoch 44/100 steps 100/100, |train-loss: 0.8387 |avg-loss: 0.6866 dur 31.6s |val-acc: 0.6400 |old-best: 0.6933
# epoch 45/100 steps 10/100, |train-loss: 0.5656
# epoch 45/100 steps 20/100, |train-loss: 0.6851
# epoch 45/100 steps 30/100, |train-loss: 0.5972
# epoch 45/100 steps 40/100, |train-loss: 0.5709
# epoch 45/100 steps 50/100, |train-loss: 0.6162
# epoch 45/100 steps 60/100, |train-loss: 0.8388
# epoch 45/100 steps 70/100, |train-loss: 0.6788
# epoch 45/100 steps 80/100, |train-loss: 0.6746
# epoch 45/100 steps 90/100, |train-loss: 0.5690
# epoch 45/100 steps 100/100, |train-loss: 0.7665 |avg-loss: 0.6829 dur 31.5s |val-acc: 0.6000 |old-best: 0.6933
# epoch 46/100 steps 10/100, |train-loss: 0.7082
# epoch 46/100 steps 20/100, |train-loss: 0.6723
# epoch 46/100 steps 30/100, |train-loss: 0.5731
# epoch 46/100 steps 40/100, |train-loss: 0.6598
# epoch 46/100 steps 50/100, |train-loss: 0.7029
# epoch 46/100 steps 60/100, |train-loss: 0.8137
# epoch 46/100 steps 70/100, |train-loss: 0.7224
# epoch 46/100 steps 80/100, |train-loss: 0.5611
# epoch 46/100 steps 90/100, |train-loss: 0.5980
# epoch 46/100 steps 100/100, |train-loss: 0.6093 |avg-loss: 0.6853 dur 31.6s |val-acc: 0.5733 |old-best: 0.6933
# epoch 47/100 steps 10/100, |train-loss: 0.6034
# epoch 47/100 steps 20/100, |train-loss: 0.6894
# epoch 47/100 steps 30/100, |train-loss: 0.5465
# epoch 47/100 steps 40/100, |train-loss: 0.7734
# epoch 47/100 steps 50/100, |train-loss: 0.6246
# epoch 47/100 steps 60/100, |train-loss: 0.7017
# epoch 47/100 steps 70/100, |train-loss: 0.7201
# epoch 47/100 steps 80/100, |train-loss: 0.7263
# epoch 47/100 steps 90/100, |train-loss: 0.5586
# epoch 47/100 steps 100/100, |train-loss: 0.6972 |avg-loss: 0.6808 dur 31.2s |val-acc: 0.5467 |old-best: 0.6933
# epoch 48/100 steps 10/100, |train-loss: 0.7626
# epoch 48/100 steps 20/100, |train-loss: 0.7979
# epoch 48/100 steps 30/100, |train-loss: 0.6036
# epoch 48/100 steps 40/100, |train-loss: 0.7668
# epoch 48/100 steps 50/100, |train-loss: 0.8447
# epoch 48/100 steps 60/100, |train-loss: 0.8166
# epoch 48/100 steps 70/100, |train-loss: 0.6349
# epoch 48/100 steps 80/100, |train-loss: 0.7487
# epoch 48/100 steps 90/100, |train-loss: 0.7428
# epoch 48/100 steps 100/100, |train-loss: 0.7993 |avg-loss: 0.6920 dur 31.2s |val-acc: 0.6267 |old-best: 0.6933
# epoch 49/100 steps 10/100, |train-loss: 0.6334
# epoch 49/100 steps 20/100, |train-loss: 0.6217
# epoch 49/100 steps 30/100, |train-loss: 0.6880
# epoch 49/100 steps 40/100, |train-loss: 0.5944
# epoch 49/100 steps 50/100, |train-loss: 0.6093
# epoch 49/100 steps 60/100, |train-loss: 0.6865
# epoch 49/100 steps 70/100, |train-loss: 0.5772
# epoch 49/100 steps 80/100, |train-loss: 0.6344
# epoch 49/100 steps 90/100, |train-loss: 0.6559
# epoch 49/100 steps 100/100, |train-loss: 0.7389 |avg-loss: 0.6930 dur 31.4s |val-acc: 0.6267 |old-best: 0.6933
# epoch 50/100 steps 10/100, |train-loss: 0.5509
# epoch 50/100 steps 20/100, |train-loss: 0.6426
# epoch 50/100 steps 30/100, |train-loss: 0.7343
# epoch 50/100 steps 40/100, |train-loss: 0.6573
# epoch 50/100 steps 50/100, |train-loss: 0.6930
# epoch 50/100 steps 60/100, |train-loss: 0.6444
# epoch 50/100 steps 70/100, |train-loss: 0.6786
# epoch 50/100 steps 80/100, |train-loss: 0.6449
# epoch 50/100 steps 90/100, |train-loss: 0.5811
# epoch 50/100 steps 100/100, |train-loss: 0.7040 |avg-loss: 0.6856 dur 31.3s |val-acc: 0.6267 |old-best: 0.6933 |50ep model saved
# epoch 51/100 steps 10/100, |train-loss: 0.7305
# epoch 51/100 steps 20/100, |train-loss: 0.6236
# epoch 51/100 steps 30/100, |train-loss: 0.7333
# epoch 51/100 steps 40/100, |train-loss: 0.7566
# epoch 51/100 steps 50/100, |train-loss: 0.5963
# epoch 51/100 steps 60/100, |train-loss: 0.8529
# epoch 51/100 steps 70/100, |train-loss: 0.7815
# epoch 51/100 steps 80/100, |train-loss: 0.6728
# epoch 51/100 steps 90/100, |train-loss: 0.8543
# epoch 51/100 steps 100/100, |train-loss: 0.5175 |avg-loss: 0.6791 dur 31.4s |val-acc: 0.6133 |old-best: 0.6933
# epoch 52/100 steps 10/100, |train-loss: 0.6345
# epoch 52/100 steps 20/100, |train-loss: 0.5413
# epoch 52/100 steps 30/100, |train-loss: 0.5041
# epoch 52/100 steps 40/100, |train-loss: 0.8170
# epoch 52/100 steps 50/100, |train-loss: 0.6094
# epoch 52/100 steps 60/100, |train-loss: 0.6065
# epoch 52/100 steps 70/100, |train-loss: 0.7436
# epoch 52/100 steps 80/100, |train-loss: 0.8142
# epoch 52/100 steps 90/100, |train-loss: 0.5782
# epoch 52/100 steps 100/100, |train-loss: 0.5767 |avg-loss: 0.6824 dur 31.3s |val-acc: 0.6000 |old-best: 0.6933
# epoch 53/100 steps 10/100, |train-loss: 0.8005
# epoch 53/100 steps 20/100, |train-loss: 0.6546
# epoch 53/100 steps 30/100, |train-loss: 0.7540
# epoch 53/100 steps 40/100, |train-loss: 0.6113
# epoch 53/100 steps 50/100, |train-loss: 0.7221
# epoch 53/100 steps 60/100, |train-loss: 0.6940
# epoch 53/100 steps 70/100, |train-loss: 0.7034
# epoch 53/100 steps 80/100, |train-loss: 0.6328
# epoch 53/100 steps 90/100, |train-loss: 0.6793
# epoch 53/100 steps 100/100, |train-loss: 0.6076 |avg-loss: 0.6856 dur 31.1s |val-acc: 0.6000 |old-best: 0.6933
# epoch 54/100 steps 10/100, |train-loss: 0.5255
# epoch 54/100 steps 20/100, |train-loss: 0.7312
# epoch 54/100 steps 30/100, |train-loss: 0.6495
# epoch 54/100 steps 40/100, |train-loss: 0.6456
# epoch 54/100 steps 50/100, |train-loss: 0.7813
# epoch 54/100 steps 60/100, |train-loss: 0.6745
# epoch 54/100 steps 70/100, |train-loss: 0.7501
# epoch 54/100 steps 80/100, |train-loss: 0.6303
# epoch 54/100 steps 90/100, |train-loss: 0.7011
# epoch 54/100 steps 100/100, |train-loss: 0.7275 |avg-loss: 0.6829 dur 31.2s |val-acc: 0.5867 |old-best: 0.6933
# epoch 55/100 steps 10/100, |train-loss: 0.6603
# epoch 55/100 steps 20/100, |train-loss: 0.6567
# epoch 55/100 steps 30/100, |train-loss: 0.6050
# epoch 55/100 steps 40/100, |train-loss: 0.6862
# epoch 55/100 steps 50/100, |train-loss: 0.6737
# epoch 55/100 steps 60/100, |train-loss: 0.7190
# epoch 55/100 steps 70/100, |train-loss: 0.7019
# epoch 55/100 steps 80/100, |train-loss: 0.5887
# epoch 55/100 steps 90/100, |train-loss: 0.7217
# epoch 55/100 steps 100/100, |train-loss: 0.7511 |avg-loss: 0.6813 dur 31.4s |val-acc: 0.6133 |old-best: 0.6933
# epoch 56/100 steps 10/100, |train-loss: 0.7156
# epoch 56/100 steps 20/100, |train-loss: 0.6544
# epoch 56/100 steps 30/100, |train-loss: 0.6840
# epoch 56/100 steps 40/100, |train-loss: 0.6778
# epoch 56/100 steps 50/100, |train-loss: 0.6653
# epoch 56/100 steps 60/100, |train-loss: 0.7241
# epoch 56/100 steps 70/100, |train-loss: 0.7614
# epoch 56/100 steps 80/100, |train-loss: 0.5897
# epoch 56/100 steps 90/100, |train-loss: 0.7575
# epoch 56/100 steps 100/100, |train-loss: 0.7320 |avg-loss: 0.6773 dur 31.4s |val-acc: 0.6000 |old-best: 0.6933
# epoch 57/100 steps 10/100, |train-loss: 0.8417
# epoch 57/100 steps 20/100, |train-loss: 0.7073
# epoch 57/100 steps 30/100, |train-loss: 0.7385
# epoch 57/100 steps 40/100, |train-loss: 0.6614
# epoch 57/100 steps 50/100, |train-loss: 0.7474
# epoch 57/100 steps 60/100, |train-loss: 0.5727
# epoch 57/100 steps 70/100, |train-loss: 0.5808
# epoch 57/100 steps 80/100, |train-loss: 0.5922
# epoch 57/100 steps 90/100, |train-loss: 0.5775
# epoch 57/100 steps 100/100, |train-loss: 0.7109 |avg-loss: 0.6819 dur 31.3s |val-acc: 0.6133 |old-best: 0.6933
# epoch 58/100 steps 10/100, |train-loss: 0.5456
# epoch 58/100 steps 20/100, |train-loss: 0.7625
# epoch 58/100 steps 30/100, |train-loss: 0.7450
# epoch 58/100 steps 40/100, |train-loss: 0.7492
# epoch 58/100 steps 50/100, |train-loss: 0.7210
# epoch 58/100 steps 60/100, |train-loss: 0.5935
# epoch 58/100 steps 70/100, |train-loss: 0.6054
# epoch 58/100 steps 80/100, |train-loss: 0.6713
# epoch 58/100 steps 90/100, |train-loss: 0.7460
# epoch 58/100 steps 100/100, |train-loss: 0.7797 |avg-loss: 0.6880 dur 31.2s |val-acc: 0.6533 |old-best: 0.6933
# epoch 59/100 steps 10/100, |train-loss: 0.6422
# epoch 59/100 steps 20/100, |train-loss: 0.5739
# epoch 59/100 steps 30/100, |train-loss: 0.7320
# epoch 59/100 steps 40/100, |train-loss: 0.6126
# epoch 59/100 steps 50/100, |train-loss: 0.6027
# epoch 59/100 steps 60/100, |train-loss: 0.6014
# epoch 59/100 steps 70/100, |train-loss: 0.5741
# epoch 59/100 steps 80/100, |train-loss: 0.7321
# epoch 59/100 steps 90/100, |train-loss: 0.7432
# epoch 59/100 steps 100/100, |train-loss: 0.6989 |avg-loss: 0.6843 dur 31.2s |val-acc: 0.6267 |old-best: 0.6933
# epoch 60/100 steps 10/100, |train-loss: 0.5712
# epoch 60/100 steps 20/100, |train-loss: 0.6443
# epoch 60/100 steps 30/100, |train-loss: 0.6460
# epoch 60/100 steps 40/100, |train-loss: 0.6637
# epoch 60/100 steps 50/100, |train-loss: 0.6525
# epoch 60/100 steps 60/100, |train-loss: 0.7941
# epoch 60/100 steps 70/100, |train-loss: 0.6533
# epoch 60/100 steps 80/100, |train-loss: 0.7409
# epoch 60/100 steps 90/100, |train-loss: 0.7607
# epoch 60/100 steps 100/100, |train-loss: 0.7914 |avg-loss: 0.6804 dur 31.4s |val-acc: 0.6400 |old-best: 0.6933 |60ep model saved
# epoch 61/100 steps 10/100, |train-loss: 0.6969
# epoch 61/100 steps 20/100, |train-loss: 0.7136
# epoch 61/100 steps 30/100, |train-loss: 0.6721
# epoch 61/100 steps 40/100, |train-loss: 0.6912
# epoch 61/100 steps 50/100, |train-loss: 0.5374
# epoch 61/100 steps 60/100, |train-loss: 0.7872
# epoch 61/100 steps 70/100, |train-loss: 0.6355
# epoch 61/100 steps 80/100, |train-loss: 0.6907
# epoch 61/100 steps 90/100, |train-loss: 0.7114
# epoch 61/100 steps 100/100, |train-loss: 0.5722 |avg-loss: 0.6915 dur 31.4s |val-acc: 0.6267 |old-best: 0.6933
# epoch 62/100 steps 10/100, |train-loss: 0.6662
# epoch 62/100 steps 20/100, |train-loss: 0.7874
# epoch 62/100 steps 30/100, |train-loss: 0.5874
# epoch 62/100 steps 40/100, |train-loss: 0.6480
# epoch 62/100 steps 50/100, |train-loss: 0.7228
# epoch 62/100 steps 60/100, |train-loss: 0.6097
# epoch 62/100 steps 70/100, |train-loss: 0.7475
# epoch 62/100 steps 80/100, |train-loss: 0.8017
# epoch 62/100 steps 90/100, |train-loss: 0.7725
# epoch 62/100 steps 100/100, |train-loss: 0.6740 |avg-loss: 0.6862 dur 31.1s |val-acc: 0.6400 |old-best: 0.6933
# epoch 63/100 steps 10/100, |train-loss: 0.7439
# epoch 63/100 steps 20/100, |train-loss: 0.6249
# epoch 63/100 steps 30/100, |train-loss: 0.5699
# epoch 63/100 steps 40/100, |train-loss: 0.6342
# epoch 63/100 steps 50/100, |train-loss: 0.7029
# epoch 63/100 steps 60/100, |train-loss: 0.7856
# epoch 63/100 steps 70/100, |train-loss: 0.6308
# epoch 63/100 steps 80/100, |train-loss: 0.6343
# epoch 63/100 steps 90/100, |train-loss: 0.7852
# epoch 63/100 steps 100/100, |train-loss: 0.6982 |avg-loss: 0.6866 dur 31.3s |val-acc: 0.6133 |old-best: 0.6933
# epoch 64/100 steps 10/100, |train-loss: 0.7119
# epoch 64/100 steps 20/100, |train-loss: 0.6509
# epoch 64/100 steps 30/100, |train-loss: 0.5692
# epoch 64/100 steps 40/100, |train-loss: 0.6381
# epoch 64/100 steps 50/100, |train-loss: 0.5883
# epoch 64/100 steps 60/100, |train-loss: 0.6019
# epoch 64/100 steps 70/100, |train-loss: 0.7359
# epoch 64/100 steps 80/100, |train-loss: 0.5689
# epoch 64/100 steps 90/100, |train-loss: 0.6350
# epoch 64/100 steps 100/100, |train-loss: 0.7134 |avg-loss: 0.6782 dur 31.3s |val-acc: 0.6133 |old-best: 0.6933
# epoch 65/100 steps 10/100, |train-loss: 0.6018
# epoch 65/100 steps 20/100, |train-loss: 0.7270
# epoch 65/100 steps 30/100, |train-loss: 0.7401
# epoch 65/100 steps 40/100, |train-loss: 0.7056
# epoch 65/100 steps 50/100, |train-loss: 0.6851
# epoch 65/100 steps 60/100, |train-loss: 0.7869
# epoch 65/100 steps 70/100, |train-loss: 0.7429
# epoch 65/100 steps 80/100, |train-loss: 0.5843
# epoch 65/100 steps 90/100, |train-loss: 0.5831
# epoch 65/100 steps 100/100, |train-loss: 0.7694 |avg-loss: 0.6814 dur 31.1s |val-acc: 0.6400 |old-best: 0.6933
# epoch 66/100 steps 10/100, |train-loss: 0.8920
# epoch 66/100 steps 20/100, |train-loss: 0.7943
# epoch 66/100 steps 30/100, |train-loss: 0.5786
# epoch 66/100 steps 40/100, |train-loss: 0.6187
# epoch 66/100 steps 50/100, |train-loss: 0.6240
# epoch 66/100 steps 60/100, |train-loss: 0.6965
# epoch 66/100 steps 70/100, |train-loss: 0.5934
# epoch 66/100 steps 80/100, |train-loss: 0.5906
# epoch 66/100 steps 90/100, |train-loss: 0.8219
# epoch 66/100 steps 100/100, |train-loss: 0.7048 |avg-loss: 0.6845 dur 31.4s |val-acc: 0.6133 |old-best: 0.6933
# epoch 67/100 steps 10/100, |train-loss: 0.7632
# epoch 67/100 steps 20/100, |train-loss: 0.5977
# epoch 67/100 steps 30/100, |train-loss: 0.6368
# epoch 67/100 steps 40/100, |train-loss: 0.6650
# epoch 67/100 steps 50/100, |train-loss: 0.6004
# epoch 67/100 steps 60/100, |train-loss: 0.5446
# epoch 67/100 steps 70/100, |train-loss: 0.5792
# epoch 67/100 steps 80/100, |train-loss: 0.6642
# epoch 67/100 steps 90/100, |train-loss: 0.6793
# epoch 67/100 steps 100/100, |train-loss: 0.5861 |avg-loss: 0.6747 dur 31.4s |val-acc: 0.6533 |old-best: 0.6933
# epoch 68/100 steps 10/100, |train-loss: 0.5190
# epoch 68/100 steps 20/100, |train-loss: 0.7518
# epoch 68/100 steps 30/100, |train-loss: 0.5734
# epoch 68/100 steps 40/100, |train-loss: 0.6248
# epoch 68/100 steps 50/100, |train-loss: 0.7374
# epoch 68/100 steps 60/100, |train-loss: 0.2740
# epoch 68/100 steps 70/100, |train-loss: 0.9440
# epoch 68/100 steps 80/100, |train-loss: 0.6176
# epoch 68/100 steps 90/100, |train-loss: 0.4301
# epoch 68/100 steps 100/100, |train-loss: 0.6493 |avg-loss: 0.6762 dur 31.4s |val-acc: 0.6667 |old-best: 0.6933
# epoch 69/100 steps 10/100, |train-loss: 0.6349
# epoch 69/100 steps 20/100, |train-loss: 0.7115
# epoch 69/100 steps 30/100, |train-loss: 0.8821
# epoch 69/100 steps 40/100, |train-loss: 0.5197
# epoch 69/100 steps 50/100, |train-loss: 0.7098
# epoch 69/100 steps 60/100, |train-loss: 0.7443
# epoch 69/100 steps 70/100, |train-loss: 0.6163
# epoch 69/100 steps 80/100, |train-loss: 0.6410
# epoch 69/100 steps 90/100, |train-loss: 0.6451
# epoch 69/100 steps 100/100, |train-loss: 0.6156 |avg-loss: 0.6914 dur 31.3s |val-acc: 0.6400 |old-best: 0.6933
# epoch 70/100 steps 10/100, |train-loss: 0.5025
# epoch 70/100 steps 20/100, |train-loss: 0.7539
# epoch 70/100 steps 30/100, |train-loss: 0.5745
# epoch 70/100 steps 40/100, |train-loss: 0.6016
# epoch 70/100 steps 50/100, |train-loss: 0.8919
# epoch 70/100 steps 60/100, |train-loss: 0.8340
# epoch 70/100 steps 70/100, |train-loss: 0.6608
# epoch 70/100 steps 80/100, |train-loss: 0.6096
# epoch 70/100 steps 90/100, |train-loss: 0.6490
# epoch 70/100 steps 100/100, |train-loss: 0.6310 |avg-loss: 0.6831 dur 30.9s |val-acc: 0.6133 |old-best: 0.6933 |70ep model saved
# epoch 71/100 steps 10/100, |train-loss: 0.6104
# epoch 71/100 steps 20/100, |train-loss: 0.6549
# epoch 71/100 steps 30/100, |train-loss: 0.6640
# epoch 71/100 steps 40/100, |train-loss: 0.5640
# epoch 71/100 steps 50/100, |train-loss: 0.8141
# epoch 71/100 steps 60/100, |train-loss: 0.6083
# epoch 71/100 steps 70/100, |train-loss: 0.6026
# epoch 71/100 steps 80/100, |train-loss: 0.7330
# epoch 71/100 steps 90/100, |train-loss: 0.6588
# epoch 71/100 steps 100/100, |train-loss: 0.6228 |avg-loss: 0.6834 dur 31.1s |val-acc: 0.6267 |old-best: 0.6933
# epoch 72/100 steps 10/100, |train-loss: 0.7447
# epoch 72/100 steps 20/100, |train-loss: 0.6758
# epoch 72/100 steps 30/100, |train-loss: 0.7658
# epoch 72/100 steps 40/100, |train-loss: 0.5671
# epoch 72/100 steps 50/100, |train-loss: 0.6744
# epoch 72/100 steps 60/100, |train-loss: 0.7394
# epoch 72/100 steps 70/100, |train-loss: 0.8501
# epoch 72/100 steps 80/100, |train-loss: 0.7257
# epoch 72/100 steps 90/100, |train-loss: 0.6250
# epoch 72/100 steps 100/100, |train-loss: 0.6332 |avg-loss: 0.6769 dur 31.1s |val-acc: 0.5733 |old-best: 0.6933
# epoch 73/100 steps 10/100, |train-loss: 0.7583
# epoch 73/100 steps 20/100, |train-loss: 0.5715
# epoch 73/100 steps 30/100, |train-loss: 0.6540
# epoch 73/100 steps 40/100, |train-loss: 0.5419
# epoch 73/100 steps 50/100, |train-loss: 0.8450
# epoch 73/100 steps 60/100, |train-loss: 0.5428
# epoch 73/100 steps 70/100, |train-loss: 0.7787
# epoch 73/100 steps 80/100, |train-loss: 0.6112
# epoch 73/100 steps 90/100, |train-loss: 0.5689
# epoch 73/100 steps 100/100, |train-loss: 0.6358 |avg-loss: 0.6784 dur 31.1s |val-acc: 0.6533 |old-best: 0.6933
# epoch 74/100 steps 10/100, |train-loss: 0.6678
# epoch 74/100 steps 20/100, |train-loss: 0.6071
# epoch 74/100 steps 30/100, |train-loss: 0.8074
# epoch 74/100 steps 40/100, |train-loss: 0.6507
# epoch 74/100 steps 50/100, |train-loss: 0.7565
# epoch 74/100 steps 60/100, |train-loss: 0.7209
# epoch 74/100 steps 70/100, |train-loss: 0.6311
# epoch 74/100 steps 80/100, |train-loss: 0.8527
# epoch 74/100 steps 90/100, |train-loss: 0.6128
# epoch 74/100 steps 100/100, |train-loss: 0.6251 |avg-loss: 0.6838 dur 31.2s |val-acc: 0.6267 |old-best: 0.6933
# epoch 75/100 steps 10/100, |train-loss: 0.6838
# epoch 75/100 steps 20/100, |train-loss: 0.7544
# epoch 75/100 steps 30/100, |train-loss: 0.6981
# epoch 75/100 steps 40/100, |train-loss: 0.5630
# epoch 75/100 steps 50/100, |train-loss: 0.7854
# epoch 75/100 steps 60/100, |train-loss: 0.6184
# epoch 75/100 steps 70/100, |train-loss: 0.7297
# epoch 75/100 steps 80/100, |train-loss: 0.6677
# epoch 75/100 steps 90/100, |train-loss: 0.7301
# epoch 75/100 steps 100/100, |train-loss: 0.8227 |avg-loss: 0.6775 dur 30.9s |val-acc: 0.6267 |old-best: 0.6933
# epoch 76/100 steps 10/100, |train-loss: 0.7280
# epoch 76/100 steps 20/100, |train-loss: 0.8583
# epoch 76/100 steps 30/100, |train-loss: 0.8063
# epoch 76/100 steps 40/100, |train-loss: 0.8585
# epoch 76/100 steps 50/100, |train-loss: 0.7255
# epoch 76/100 steps 60/100, |train-loss: 0.8225
# epoch 76/100 steps 70/100, |train-loss: 0.5182
# epoch 76/100 steps 80/100, |train-loss: 0.7126
# epoch 76/100 steps 90/100, |train-loss: 0.6218
# epoch 76/100 steps 100/100, |train-loss: 0.8150 |avg-loss: 0.6739 dur 31.4s |val-acc: 0.6667 |old-best: 0.6933
# epoch 77/100 steps 10/100, |train-loss: 0.7078
# epoch 77/100 steps 20/100, |train-loss: 0.6107
# epoch 77/100 steps 30/100, |train-loss: 0.6598
# epoch 77/100 steps 40/100, |train-loss: 0.7370
# epoch 77/100 steps 50/100, |train-loss: 0.5660
# epoch 77/100 steps 60/100, |train-loss: 0.8488
# epoch 77/100 steps 70/100, |train-loss: 0.6712
# epoch 77/100 steps 80/100, |train-loss: 0.6131
# epoch 77/100 steps 90/100, |train-loss: 0.6380
# epoch 77/100 steps 100/100, |train-loss: 0.7477 |avg-loss: 0.6824 dur 31.3s |val-acc: 0.6267 |old-best: 0.6933
# epoch 78/100 steps 10/100, |train-loss: 0.7485
# epoch 78/100 steps 20/100, |train-loss: 0.5391
# epoch 78/100 steps 30/100, |train-loss: 0.6764
# epoch 78/100 steps 40/100, |train-loss: 0.4999
# epoch 78/100 steps 50/100, |train-loss: 0.6666
# epoch 78/100 steps 60/100, |train-loss: 0.6576
# epoch 78/100 steps 70/100, |train-loss: 0.5566
# epoch 78/100 steps 80/100, |train-loss: 0.5298
# epoch 78/100 steps 90/100, |train-loss: 0.5573
# epoch 78/100 steps 100/100, |train-loss: 0.7506 |avg-loss: 0.6753 dur 31.1s |val-acc: 0.6667 |old-best: 0.6933
# epoch 79/100 steps 10/100, |train-loss: 0.6466
# epoch 79/100 steps 20/100, |train-loss: 0.7240
# epoch 79/100 steps 30/100, |train-loss: 0.7451
# epoch 79/100 steps 40/100, |train-loss: 0.6222
# epoch 79/100 steps 50/100, |train-loss: 0.5203
# epoch 79/100 steps 60/100, |train-loss: 0.8605
# epoch 79/100 steps 70/100, |train-loss: 0.6466
# epoch 79/100 steps 80/100, |train-loss: 0.8120
# epoch 79/100 steps 90/100, |train-loss: 0.7793
# epoch 79/100 steps 100/100, |train-loss: 0.7558 |avg-loss: 0.6677 dur 31.1s |val-acc: 0.7067 |old-best: 0.6933 |best model saved
# epoch 80/100 steps 10/100, |train-loss: 0.6578
# epoch 80/100 steps 20/100, |train-loss: 0.5599
# epoch 80/100 steps 30/100, |train-loss: 0.4903
# epoch 80/100 steps 40/100, |train-loss: 0.5416
# epoch 80/100 steps 50/100, |train-loss: 0.6177
# epoch 80/100 steps 60/100, |train-loss: 0.6333
# epoch 80/100 steps 70/100, |train-loss: 0.8072
# epoch 80/100 steps 80/100, |train-loss: 0.8056
# epoch 80/100 steps 90/100, |train-loss: 0.5740
# epoch 80/100 steps 100/100, |train-loss: 0.8064 |avg-loss: 0.6771 dur 31.1s |val-acc: 0.6000 |old-best: 0.7067 |80ep model saved
# epoch 81/100 steps 10/100, |train-loss: 0.6563
# epoch 81/100 steps 20/100, |train-loss: 0.6635
# epoch 81/100 steps 30/100, |train-loss: 0.6571
# epoch 81/100 steps 40/100, |train-loss: 0.7351
# epoch 81/100 steps 50/100, |train-loss: 0.6981
# epoch 81/100 steps 60/100, |train-loss: 0.7283
# epoch 81/100 steps 70/100, |train-loss: 0.7292
# epoch 81/100 steps 80/100, |train-loss: 0.7667
# epoch 81/100 steps 90/100, |train-loss: 0.5969
# epoch 81/100 steps 100/100, |train-loss: 0.6338 |avg-loss: 0.6785 dur 31.1s |val-acc: 0.6400 |old-best: 0.7067
# epoch 82/100 steps 10/100, |train-loss: 0.5844
# epoch 82/100 steps 20/100, |train-loss: 0.6178
# epoch 82/100 steps 30/100, |train-loss: 0.6789
# epoch 82/100 steps 40/100, |train-loss: 0.6279
# epoch 82/100 steps 50/100, |train-loss: 0.6155
# epoch 82/100 steps 60/100, |train-loss: 0.9193
# epoch 82/100 steps 70/100, |train-loss: 0.5954
# epoch 82/100 steps 80/100, |train-loss: 0.6170
# epoch 82/100 steps 90/100, |train-loss: 0.8089
# epoch 82/100 steps 100/100, |train-loss: 0.7376 |avg-loss: 0.6732 dur 31.2s |val-acc: 0.6000 |old-best: 0.7067
# epoch 83/100 steps 10/100, |train-loss: 0.8825
# epoch 83/100 steps 20/100, |train-loss: 0.5959
# epoch 83/100 steps 30/100, |train-loss: 0.6451
# epoch 83/100 steps 40/100, |train-loss: 0.7106
# epoch 83/100 steps 50/100, |train-loss: 0.5822
# epoch 83/100 steps 60/100, |train-loss: 0.6228
# epoch 83/100 steps 70/100, |train-loss: 0.6658
# epoch 83/100 steps 80/100, |train-loss: 0.7050
# epoch 83/100 steps 90/100, |train-loss: 0.8478
# epoch 83/100 steps 100/100, |train-loss: 0.6721 |avg-loss: 0.6797 dur 31.4s |val-acc: 0.6533 |old-best: 0.7067
# epoch 84/100 steps 10/100, |train-loss: 0.6203
# epoch 84/100 steps 20/100, |train-loss: 0.5547
# epoch 84/100 steps 30/100, |train-loss: 0.7255
# epoch 84/100 steps 40/100, |train-loss: 0.6772
# epoch 84/100 steps 50/100, |train-loss: 0.6199
# epoch 84/100 steps 60/100, |train-loss: 0.5829
# epoch 84/100 steps 70/100, |train-loss: 0.9424
# epoch 84/100 steps 80/100, |train-loss: 0.9537
# epoch 84/100 steps 90/100, |train-loss: 0.6225
# epoch 84/100 steps 100/100, |train-loss: 0.7334 |avg-loss: 0.6680 dur 30.9s |val-acc: 0.6267 |old-best: 0.7067
# epoch 85/100 steps 10/100, |train-loss: 0.5829
# epoch 85/100 steps 20/100, |train-loss: 0.4365
# epoch 85/100 steps 30/100, |train-loss: 0.8202
# epoch 85/100 steps 40/100, |train-loss: 0.7433
# epoch 85/100 steps 50/100, |train-loss: 0.6370
# epoch 85/100 steps 60/100, |train-loss: 0.6171
# epoch 85/100 steps 70/100, |train-loss: 0.8293
# epoch 85/100 steps 80/100, |train-loss: 0.7374
# epoch 85/100 steps 90/100, |train-loss: 0.5478
# epoch 85/100 steps 100/100, |train-loss: 0.6286 |avg-loss: 0.6708 dur 30.9s |val-acc: 0.6800 |old-best: 0.7067
# epoch 86/100 steps 10/100, |train-loss: 0.6440
# epoch 86/100 steps 20/100, |train-loss: 0.5708
# epoch 86/100 steps 30/100, |train-loss: 0.9054
# epoch 86/100 steps 40/100, |train-loss: 0.6396
# epoch 86/100 steps 50/100, |train-loss: 0.5898
# epoch 86/100 steps 60/100, |train-loss: 0.6757
# epoch 86/100 steps 70/100, |train-loss: 0.5795
# epoch 86/100 steps 80/100, |train-loss: 0.8100
# epoch 86/100 steps 90/100, |train-loss: 0.6604
# epoch 86/100 steps 100/100, |train-loss: 0.5566 |avg-loss: 0.6806 dur 31.3s |val-acc: 0.6400 |old-best: 0.7067
# epoch 87/100 steps 10/100, |train-loss: 0.6544
# epoch 87/100 steps 20/100, |train-loss: 0.6207
# epoch 87/100 steps 30/100, |train-loss: 0.5817
# epoch 87/100 steps 40/100, |train-loss: 0.6284
# epoch 87/100 steps 50/100, |train-loss: 0.6242
# epoch 87/100 steps 60/100, |train-loss: 0.9403
# epoch 87/100 steps 70/100, |train-loss: 0.7276
# epoch 87/100 steps 80/100, |train-loss: 0.9022
# epoch 87/100 steps 90/100, |train-loss: 0.7542
# epoch 87/100 steps 100/100, |train-loss: 0.7224 |avg-loss: 0.6704 dur 31.3s |val-acc: 0.6533 |old-best: 0.7067
# epoch 88/100 steps 10/100, |train-loss: 0.5956
# epoch 88/100 steps 20/100, |train-loss: 0.6819
# epoch 88/100 steps 30/100, |train-loss: 0.6375
# epoch 88/100 steps 40/100, |train-loss: 0.5464
# epoch 88/100 steps 50/100, |train-loss: 1.0338
# epoch 88/100 steps 60/100, |train-loss: 0.6485
# epoch 88/100 steps 70/100, |train-loss: 0.4869
# epoch 88/100 steps 80/100, |train-loss: 0.4461
# epoch 88/100 steps 90/100, |train-loss: 0.5697
# epoch 88/100 steps 100/100, |train-loss: 0.5703 |avg-loss: 0.6682 dur 31.5s |val-acc: 0.6133 |old-best: 0.7067
# epoch 89/100 steps 10/100, |train-loss: 0.6251
# epoch 89/100 steps 20/100, |train-loss: 0.6096
# epoch 89/100 steps 30/100, |train-loss: 0.6291
# epoch 89/100 steps 40/100, |train-loss: 0.5748
# epoch 89/100 steps 50/100, |train-loss: 0.5232
# epoch 89/100 steps 60/100, |train-loss: 0.8964
# epoch 89/100 steps 70/100, |train-loss: 0.6252
# epoch 89/100 steps 80/100, |train-loss: 0.6172
# epoch 89/100 steps 90/100, |train-loss: 0.7080
# epoch 89/100 steps 100/100, |train-loss: 0.6064 |avg-loss: 0.6699 dur 31.0s |val-acc: 0.6400 |old-best: 0.7067
# epoch 90/100 steps 10/100, |train-loss: 0.7198
# epoch 90/100 steps 20/100, |train-loss: 0.6904
# epoch 90/100 steps 30/100, |train-loss: 0.6598
# epoch 90/100 steps 40/100, |train-loss: 0.7054
# epoch 90/100 steps 50/100, |train-loss: 0.6016
# epoch 90/100 steps 60/100, |train-loss: 0.7877
# epoch 90/100 steps 70/100, |train-loss: 0.5699
# epoch 90/100 steps 80/100, |train-loss: 0.6116
# epoch 90/100 steps 90/100, |train-loss: 0.5786
# epoch 90/100 steps 100/100, |train-loss: 0.7832 |avg-loss: 0.6728 dur 31.3s |val-acc: 0.6400 |old-best: 0.7067 |90ep model saved
# epoch 91/100 steps 10/100, |train-loss: 0.5755
# epoch 91/100 steps 20/100, |train-loss: 0.7926
# epoch 91/100 steps 30/100, |train-loss: 0.6066
# epoch 91/100 steps 40/100, |train-loss: 0.5585
# epoch 91/100 steps 50/100, |train-loss: 0.5159
# epoch 91/100 steps 60/100, |train-loss: 0.6920
# epoch 91/100 steps 70/100, |train-loss: 0.8302
# epoch 91/100 steps 80/100, |train-loss: 0.7592
# epoch 91/100 steps 90/100, |train-loss: 0.4413
# epoch 91/100 steps 100/100, |train-loss: 0.6730 |avg-loss: 0.6721 dur 31.0s |val-acc: 0.6533 |old-best: 0.7067
# epoch 92/100 steps 10/100, |train-loss: 0.5423
# epoch 92/100 steps 20/100, |train-loss: 0.5378
# epoch 92/100 steps 30/100, |train-loss: 0.7030
# epoch 92/100 steps 40/100, |train-loss: 0.5783
# epoch 92/100 steps 50/100, |train-loss: 0.6356
# epoch 92/100 steps 60/100, |train-loss: 0.5215
# epoch 92/100 steps 70/100, |train-loss: 0.9467
# epoch 92/100 steps 80/100, |train-loss: 0.8682
# epoch 92/100 steps 90/100, |train-loss: 0.6952
# epoch 92/100 steps 100/100, |train-loss: 0.5946 |avg-loss: 0.6663 dur 31.3s |val-acc: 0.5867 |old-best: 0.7067
# epoch 93/100 steps 10/100, |train-loss: 0.5435
# epoch 93/100 steps 20/100, |train-loss: 0.7405
# epoch 93/100 steps 30/100, |train-loss: 0.5613
# epoch 93/100 steps 40/100, |train-loss: 0.6395
# epoch 93/100 steps 50/100, |train-loss: 0.6478
# epoch 93/100 steps 60/100, |train-loss: 0.5978
# epoch 93/100 steps 70/100, |train-loss: 0.6450
# epoch 93/100 steps 80/100, |train-loss: 0.5552
# epoch 93/100 steps 90/100, |train-loss: 0.5765
# epoch 93/100 steps 100/100, |train-loss: 0.7461 |avg-loss: 0.6605 dur 31.2s |val-acc: 0.6267 |old-best: 0.7067
# epoch 94/100 steps 10/100, |train-loss: 0.8114
# epoch 94/100 steps 20/100, |train-loss: 0.5677
# epoch 94/100 steps 30/100, |train-loss: 0.7621
# epoch 94/100 steps 40/100, |train-loss: 0.8445
# epoch 94/100 steps 50/100, |train-loss: 0.7229
# epoch 94/100 steps 60/100, |train-loss: 0.6565
# epoch 94/100 steps 70/100, |train-loss: 0.7185
# epoch 94/100 steps 80/100, |train-loss: 0.5822
# epoch 94/100 steps 90/100, |train-loss: 0.5868
# epoch 94/100 steps 100/100, |train-loss: 0.5101 |avg-loss: 0.6608 dur 31.2s |val-acc: 0.6533 |old-best: 0.7067
# epoch 95/100 steps 10/100, |train-loss: 0.4671
# epoch 95/100 steps 20/100, |train-loss: 0.4852
# epoch 95/100 steps 30/100, |train-loss: 0.5956
# epoch 95/100 steps 40/100, |train-loss: 0.8013
# epoch 95/100 steps 50/100, |train-loss: 0.7616
# epoch 95/100 steps 60/100, |train-loss: 0.4561
# epoch 95/100 steps 70/100, |train-loss: 0.6244
# epoch 95/100 steps 80/100, |train-loss: 0.5844
# epoch 95/100 steps 90/100, |train-loss: 0.5403
# epoch 95/100 steps 100/100, |train-loss: 0.9834 |avg-loss: 0.6584 dur 31.4s |val-acc: 0.6133 |old-best: 0.7067
# epoch 96/100 steps 10/100, |train-loss: 0.6147
# epoch 96/100 steps 20/100, |train-loss: 0.5944
# epoch 96/100 steps 30/100, |train-loss: 0.8491
# epoch 96/100 steps 40/100, |train-loss: 0.6918
# epoch 96/100 steps 50/100, |train-loss: 0.9031
# epoch 96/100 steps 60/100, |train-loss: 0.9485
# epoch 96/100 steps 70/100, |train-loss: 0.6760
# epoch 96/100 steps 80/100, |train-loss: 0.6101
# epoch 96/100 steps 90/100, |train-loss: 0.6298
# epoch 96/100 steps 100/100, |train-loss: 0.6429 |avg-loss: 0.6657 dur 31.5s |val-acc: 0.6133 |old-best: 0.7067
# epoch 97/100 steps 10/100, |train-loss: 0.6891
# epoch 97/100 steps 20/100, |train-loss: 0.4467
# epoch 97/100 steps 30/100, |train-loss: 0.6154
# epoch 97/100 steps 40/100, |train-loss: 0.8189
# epoch 97/100 steps 50/100, |train-loss: 0.6605
# epoch 97/100 steps 60/100, |train-loss: 0.7221
# epoch 97/100 steps 70/100, |train-loss: 0.8111
# epoch 97/100 steps 80/100, |train-loss: 0.8866
# epoch 97/100 steps 90/100, |train-loss: 0.6569
# epoch 97/100 steps 100/100, |train-loss: 0.5704 |avg-loss: 0.6631 dur 31.0s |val-acc: 0.6400 |old-best: 0.7067
# epoch 98/100 steps 10/100, |train-loss: 0.7079
# epoch 98/100 steps 20/100, |train-loss: 0.5760
# epoch 98/100 steps 30/100, |train-loss: 0.7268
# epoch 98/100 steps 40/100, |train-loss: 0.6508
# epoch 98/100 steps 50/100, |train-loss: 0.6086
# epoch 98/100 steps 60/100, |train-loss: 0.7398
# epoch 98/100 steps 70/100, |train-loss: 0.5322
# epoch 98/100 steps 80/100, |train-loss: 0.5239
# epoch 98/100 steps 90/100, |train-loss: 0.7640
# epoch 98/100 steps 100/100, |train-loss: 0.5612 |avg-loss: 0.6684 dur 31.1s |val-acc: 0.6533 |old-best: 0.7067
# epoch 99/100 steps 10/100, |train-loss: 0.8304
# epoch 99/100 steps 20/100, |train-loss: 0.5327
# epoch 99/100 steps 30/100, |train-loss: 0.5668
# epoch 99/100 steps 40/100, |train-loss: 0.5676
# epoch 99/100 steps 50/100, |train-loss: 0.5589
# epoch 99/100 steps 60/100, |train-loss: 0.6337
# epoch 99/100 steps 70/100, |train-loss: 0.8085
# epoch 99/100 steps 80/100, |train-loss: 0.5611
# epoch 99/100 steps 90/100, |train-loss: 0.7433
# epoch 99/100 steps 100/100, |train-loss: 0.4557 |avg-loss: 0.6499 dur 31.4s |val-acc: 0.5733 |old-best: 0.7067
# epoch 100/100 steps 10/100, |train-loss: 0.6786
# epoch 100/100 steps 20/100, |train-loss: 0.5557
# epoch 100/100 steps 30/100, |train-loss: 0.5129
# epoch 100/100 steps 40/100, |train-loss: 0.8002
# epoch 100/100 steps 50/100, |train-loss: 0.5283
# epoch 100/100 steps 60/100, |train-loss: 0.6180
# epoch 100/100 steps 70/100, |train-loss: 0.7124
# epoch 100/100 steps 80/100, |train-loss: 0.6940
# epoch 100/100 steps 90/100, |train-loss: 0.5497
# epoch 100/100 steps 100/100, |train-loss: 0.6698 |avg-loss: 0.6570 dur 31.4s |val-acc: 0.6133 |old-best: 0.7067 |100ep model saved
# train completed, best_metric: 0.7067 at epoch: 79 for 100 epoches
# CPU times: user 57min 2s, sys: 6min 33s, total: 1h 3min 36s
# Wall time: 1h 7min 29s

# %%
# !rm -rf pymp-*

# %%
import matplotlib.pyplot as plt

plt.figure("train", (12, 6))
plt.subplot(1, 2, 1)
plt.title("Epoch Average Loss")
x = [i + 1 for i in range(len(epoch_loss_values))]
y = epoch_loss_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.ylim(0,1)
plt.subplot(1, 2, 2)
plt.title("Val Accuracy")
x = [val_interval * (i + 1) for i in range(len(metric_values))]
y = metric_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.ylim(0,1)
plt.show()

# %%
with open('densenet100.out', 'w') as f:
    for val_data in val_files:
        f.write(str(val_data) + '\n')

# %%
# %matplotlib inline

from enum import Enum
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from monai.metrics import ConfusionMatrixMetric
class Diagnosis(Enum):
    no_MVI = 0
    MVI = 1    
threshold = 0.5

model.load_state_dict(torch.load(os.path.join(root_dir, "{}_model_best.pth".format(model_name)), map_location='cpu'))
model.to(device)
model.eval()

with torch.no_grad():
    y_pred = torch.tensor([], dtype=torch.float32, device=device)
    y = torch.tensor([], dtype=torch.long, device=device)

    for val_data in val_loader:
        val_images = val_data["image"].to(device)
        val_labels = val_data["label"].to(device)
        outputs = model(val_images)
        y_probs = torch.softmax(outputs, dim=1)[:, 1]
        y_pred = torch.cat([y_pred, (y_probs >= threshold).float()], dim=0)
        y_real = val_labels.argmax(dim=1)
        y = torch.cat([y, y_real], dim=0)
        
        #print prob
        for i in range(len(val_labels)):
            print(f'GT {int(y_real[i].cpu())} | P {float(y_probs[i].cpu())}')

print(classification_report(
    y.cpu().numpy(),
    y_pred.cpu().numpy(),
    labels = [0, 1],
    target_names=[d.name for d in Diagnosis]))

cm = confusion_matrix (
    y.cpu().numpy(),
    y_pred.cpu().numpy(),
    labels = [0, 1],
    normalize=None,
)
cmm = ConfusionMatrixMetric(include_background=True, metric_name=["sensitivity","specificity","negative predictive value"])

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=[d.name for d in Diagnosis],
)
disp.plot(ax=plt.subplots(1, 1, facecolor='white')[1])
# Out:
# GT 1 | P 0.9191584587097168
# GT 1 | P 0.7737993597984314
# GT 0 | P 0.2824111878871918
# GT 1 | P 0.4913727939128876
# GT 1 | P 0.7806622982025146
# GT 1 | P 0.8103375434875488
# GT 0 | P 0.3107750713825226
# GT 0 | P 0.6338645815849304
# GT 0 | P 0.5808704495429993
# GT 1 | P 0.8578879833221436
# GT 1 | P 0.7988398671150208
# GT 1 | P 0.7200904488563538
# GT 0 | P 0.8150377869606018
# GT 0 | P 0.5653786063194275
# GT 1 | P 0.8888158798217773
# GT 0 | P 0.5266454815864563
# GT 1 | P 0.5603916049003601
# GT 0 | P 0.8601205945014954
# GT 1 | P 0.7478806972503662
# GT 1 | P 0.8455864191055298
# GT 1 | P 0.8904638290405273
# GT 1 | P 0.526547372341156
# GT 1 | P 0.7977116703987122
# GT 0 | P 0.5966324210166931
# GT 1 | P 0.5126522183418274
# GT 0 | P 0.7162262201309204
# GT 1 | P 0.7792491912841797
# GT 1 | P 0.7838582992553711
# GT 1 | P 0.7889307737350464
# GT 0 | P 0.8206126093864441
# GT 0 | P 0.8006200790405273
# GT 0 | P 0.3578376770019531
# GT 1 | P 0.7648025155067444
# GT 0 | P 0.22460980713367462
# GT 1 | P 0.7669227123260498
# GT 1 | P 0.8878496885299683
# GT 0 | P 0.8834385871887207
# GT 0 | P 0.46351978182792664
# GT 0 | P 0.6593788862228394
# GT 1 | P 0.4324078857898712
# GT 1 | P 0.8957106471061707
# GT 1 | P 0.8325440287590027
# GT 1 | P 0.7776375412940979
# GT 1 | P 0.7279711365699768
# GT 1 | P 0.7747437357902527
# GT 1 | P 0.8221778273582458
# GT 1 | P 0.5462859869003296
# GT 0 | P 0.8188117146492004
# GT 0 | P 0.8309796452522278
# GT 1 | P 0.6627294421195984
# GT 0 | P 0.3097993731498718
# GT 1 | P 0.8464019298553467
# GT 0 | P 0.46733954548835754
# GT 1 | P 0.5716930031776428
# GT 0 | P 0.7364107966423035
# GT 1 | P 0.5500393509864807
# GT 0 | P 0.7715784907341003
# GT 1 | P 0.5478808879852295
# GT 0 | P 0.8865136504173279
# GT 1 | P 0.6228289604187012
# GT 0 | P 0.4172237813472748
# GT 1 | P 0.7500945925712585
# GT 1 | P 0.13644711673259735
# GT 0 | P 0.7640620470046997
# GT 1 | P 0.763552725315094
# GT 1 | P 0.6230571269989014
# GT 1 | P 0.8090475797653198
# GT 1 | P 0.7682048678398132
# GT 1 | P 0.627195417881012
# GT 1 | P 0.7825869917869568
# GT 1 | P 0.6437672972679138
# GT 0 | P 0.7728865742683411
# GT 0 | P 0.15379759669303894
# GT 1 | P 0.6987923979759216
# GT 1 | P 0.7160699367523193
#               precision    recall  f1-score   support
#
#       no_MVI       0.75      0.32      0.45        28
#          MVI       0.70      0.94      0.80        47
#
#     accuracy                           0.71        75
#    macro avg       0.72      0.63      0.62        75
# weighted avg       0.72      0.71      0.67        75
