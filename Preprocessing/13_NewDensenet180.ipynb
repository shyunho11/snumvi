# %%
# !nvidia-smi
# Out:
# Fri May  5 10:18:50 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 520.61.05    Driver Version: 520.61.05    CUDA Version: 11.8     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:B2:00.0 Off |                  Off |
# | N/A   46C    P0   236W / 300W |   8677MiB / 32768MiB |     20%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
import sys
sys.path.append('/home/fastmri2/.conda/envs/snumvi/lib/python3.8/site-packages')

import os
import glob

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch

from monai.apps import download_and_extract
from monai.config import print_config
from monai.utils import set_determinism

print_config()
set_determinism(0)

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.filterwarnings("ignore", category=UserWarning)
# Out:
# /home/fastmri2/.conda/envs/snumvi/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# MONAI version: 1.1.0
# Numpy version: 1.23.5
# Pytorch version: 1.7.1+cu110
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: a2ec3752f54bfc3b40e7952234fbeb5452ed63e3
# MONAI __file__: /home/fastmri2/.conda/envs/snumvi/lib/python3.8/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.4.8
# Nibabel version: 5.0.0
# scikit-image version: 0.19.3
# Pillow version: 9.4.0
# Tensorboard version: 2.4.0
# gdown version: 4.6.0
# TorchVision version: 0.8.2+cu110
# tqdm version: 4.65.0
# lmdb version: 1.4.0
# psutil version: 5.9.0
# pandas version: 1.5.2
# einops version: 0.6.0
# transformers version: NOT INSTALLED or UNKNOWN VERSION.
# mlflow version: 2.1.1
# pynrrd version: 1.0.0
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %%
directory = "temp"
if not os.path.exists(directory):
    os.makedirs(directory)
root_dir = tempfile.mkdtemp() if directory is None else directory
data_dir = "cropped/HBP/18018090"

# %%
#!pip install openpyxl

patient_data = pd.read_excel("patient_data.xlsx", usecols="A,B")

# %%
import random

train_images = sorted(glob.glob(os.path.join(data_dir, "*.nii.gz")))
train_labels = torch.nn.functional.one_hot(torch.as_tensor(patient_data["MVI"])).float()
data_list = list(zip(train_images, train_labels))
random.shuffle(data_list)
data_dicts = [{"image": image, "label": label} for image, label in data_list]
print(len(data_dicts))
print(data_dicts[0])
# Out:
# 244
# {'image': 'cropped/HBP/18018090/0020491.nii.gz', 'label': tensor([0., 1.])}

# %%
train_files, val_files = data_dicts[:200], data_dicts[200:]
target_layer=8
set_determinism(seed=0)

# %%
def nii_loader(filename) :
    import nibabel as nib
    import numpy as np
    import matplotlib.pyplot as plt
    nimg = nib.load( filename )
    return nimg.get_fdata() , nimg.affine, nimg.header 

def visualize(dataset, idx=0, target_layer=10):
    import matplotlib.pyplot as plt    

    image = dataset[idx]['image']
    label = dataset[idx]['label']
    image_data, image_affine, image_header = nii_loader(image)
    
    print('[file path]', image)
    print('[dimension]', image_data.shape)
    print('[label]', label)
    target_image = image_data[:,:,target_layer]

    plt.imshow(target_image, cmap='gray' )
    plt.show()
    return tuple(image_data.shape)

# %%
spatial_size = visualize( val_files, idx=1,  target_layer=target_layer)
# Out:
# [file path] cropped/HBP/18018090/0099705.nii.gz
# [dimension] (180, 180, 90)
# [label] tensor([0., 1.])

# %%
from monai.transforms import (
    Compose,
    LoadImaged,
    EnsureChannelFirstd,
    AddChanneld,
    Orientationd,
    ScaleIntensityRanged,
    CropForegroundd,
    RandAffined,
    SpatialPadd,
    EnsureTyped,
)

# %%
# ScaleIntensityRanged min/max differ by organs
# for liver, min = 30 + 150/2 = 105, max = 30 - 150/2 = -45
# see more info here https://radiopaedia.org/articles/windowing-ct

from monai.transforms import Compose

train_transforms = Compose(
    [
        LoadImaged(keys=["image"]),
        EnsureChannelFirstd(keys=["image"]),
        #AddChanneld(keys=["label"]),
        Orientationd(keys=["image"], axcodes="RAS"),
        ScaleIntensityRanged(
            keys=["image"], a_min=-45, a_max=105,
            b_min=0.0, b_max=1.0, clip=True,
        ),
        CropForegroundd(keys=["image"], source_key="image"),
        RandAffined(
            keys=["image"],
            mode=("bilinear"),
            prob=1.0, spatial_size=spatial_size,
            rotate_range=(0, 0, 0),
            scale_range=(0, 0, 0)),
        SpatialPadd(keys=["image"], spatial_size=spatial_size),
        EnsureTyped(keys=["image"]),
    ]
)
val_transforms = Compose(
    [
        LoadImaged(keys=["image"]),
        EnsureChannelFirstd(keys=["image"]),
        #AddChanneld(keys=["label"]),
        Orientationd(keys=["image"], axcodes="RAS"),
        ScaleIntensityRanged(
            keys=["image"], a_min=-45, a_max=105,
            b_min=0.0, b_max=1.0, clip=True,
        ),
        CropForegroundd(keys=["image"], source_key="image"),
        SpatialPadd(keys=["image"], spatial_size=spatial_size),
        EnsureTyped(keys=["image"]),
    ]
)

# %%
from monai.data import CacheDataset, DataLoader, Dataset
from monai.utils import first, set_determinism

check_ds = Dataset(data=train_files, transform=train_transforms)
check_loader = DataLoader(check_ds, batch_size=1)
check_data = first(check_loader)
image, label = (check_data["image"][0][0], check_data["label"][0][0])
print(f"image shape: {image.shape}, label shape: {label.shape}")

plt.imshow(image[:, :, spatial_size[2]//2], cmap="gray")
plt.show()
# Out:
# image shape: torch.Size([180, 180, 90]), label shape: torch.Size([])

# %%
from monai.data import CacheDataset, DataLoader

train_ds = CacheDataset(data=train_files, transform=train_transforms, cache_rate=1.0, num_workers=4, progress=True)
train_loader = DataLoader(train_ds, batch_size=2, shuffle=True, num_workers=10)

val_ds = CacheDataset(data=val_files, transform=val_transforms, cache_rate=1.0, num_workers=4, progress=True)
val_loader = DataLoader(val_ds, batch_size=1, num_workers=10)
# Out:
# Loading dataset: 100%|██████████| 200/200 [00:28<00:00,  7.06it/s]
# Loading dataset: 100%|██████████| 44/44 [00:06<00:00,  7.06it/s]

# %%
from monai.networks.nets import DenseNet121

device = torch.device("cuda:0")
model = DenseNet121(
    spatial_dims=3,
    in_channels=1,
    out_channels=2
).to(device)

# %%
loss_function = torch.nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), 1e-4)
max_epochs = 50
val_interval = 1
save_interval = 10
best_score = -1
best_score_epoch = -1
epoch_loss_values = []
metric_values = []
model_name = 'Densenet180'

# %%
# %%time

import time

for epoch in range(max_epochs):
    tic_epoch = time.time()
    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step += 1
        inputs, labels = batch_data["image"].to(device), batch_data["label"].to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        if step % 5 ==0:
            print(f"\nepoch {epoch + 1}/{max_epochs} steps {step}/{len(train_ds) // train_loader.batch_size}, |train-loss: {loss.item():.4f}", end='')
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    toc_epoch = time.time()
    dur_epoch = toc_epoch - tic_epoch
    print(f" |avg-loss: {epoch_loss:.4f} dur {dur_epoch:.1f}s ", end='')

    if (epoch + 1) % val_interval == 0:
        model.eval()
        val_count = 0
        val_correct = 0.0
        
        with torch.no_grad():
            for val_data in val_loader:
                inputs, labels = (
                    val_data["image"].to(device),
                    val_data["label"].to(device),
                )
                outputs = model(inputs)
                val_result = torch.eq(outputs.argmax(dim=1), labels.argmax(dim=1))
                val_count += len(val_result)
                val_correct += val_result.sum().item()
            
            val_score = val_correct / val_count
            metric_values.append(val_score)
            print(f"|val-acc: {val_score:.4f} |old-best: {best_score:.4f} " , end="")
            
            if val_score > best_score:
                best_score = val_score
                best_score_epoch = epoch + 1
                torch.save(model.state_dict(), os.path.join(root_dir, "{}_model_best.pth".format(model_name)))
                torch.save(optimizer.state_dict(), os.path.join(root_dir, "{}_optim_best.pth".format(model_name)))
                print("|best model saved", end="")
    
    if (epoch+1) % save_interval == 0:
        torch.save(model.state_dict(), os.path.join(root_dir, "{}_model_{:04d}.pth".format(model_name, epoch+1)))
        torch.save(optimizer.state_dict(), os.path.join(root_dir, "{}_optim_{:04d}.pth".format(model_name, epoch+1)))
        print("|{}ep model saved".format(epoch+1), end='')
                            
print(f"\ntrain completed, best_metric: {best_score:.4f} at epoch: {best_score_epoch} for {max_epochs} epoches")
# Out:
# epoch 1/50 steps 5/100, |train-loss: 0.7726
# epoch 1/50 steps 10/100, |train-loss: 0.5885
# epoch 1/50 steps 15/100, |train-loss: 0.6139
# epoch 1/50 steps 20/100, |train-loss: 0.7765
# epoch 1/50 steps 25/100, |train-loss: 0.7569
# epoch 1/50 steps 30/100, |train-loss: 0.6936
# epoch 1/50 steps 35/100, |train-loss: 0.6631
# epoch 1/50 steps 40/100, |train-loss: 0.7742
# epoch 1/50 steps 45/100, |train-loss: 0.7673
# epoch 1/50 steps 50/100, |train-loss: 1.1677
# epoch 1/50 steps 55/100, |train-loss: 0.6405
# epoch 1/50 steps 60/100, |train-loss: 0.6188
# epoch 1/50 steps 65/100, |train-loss: 0.7683
# epoch 1/50 steps 70/100, |train-loss: 0.6395
# epoch 1/50 steps 75/100, |train-loss: 0.6382
# epoch 1/50 steps 80/100, |train-loss: 0.5134
# epoch 1/50 steps 85/100, |train-loss: 0.6951
# epoch 1/50 steps 90/100, |train-loss: 0.3411
# epoch 1/50 steps 95/100, |train-loss: 0.4763
# epoch 1/50 steps 100/100, |train-loss: 0.6566 |avg-loss: 0.7154 dur 57.1s |val-acc: 0.5227 |old-best: -1.0000 |best model saved
# epoch 2/50 steps 5/100, |train-loss: 0.7977
# epoch 2/50 steps 10/100, |train-loss: 0.6548
# epoch 2/50 steps 15/100, |train-loss: 0.6220
# epoch 2/50 steps 20/100, |train-loss: 0.7555
# epoch 2/50 steps 25/100, |train-loss: 0.7203
# epoch 2/50 steps 30/100, |train-loss: 0.7683
# epoch 2/50 steps 35/100, |train-loss: 0.7172
# epoch 2/50 steps 40/100, |train-loss: 0.6460
# epoch 2/50 steps 45/100, |train-loss: 0.7388
# epoch 2/50 steps 50/100, |train-loss: 0.6995
# epoch 2/50 steps 55/100, |train-loss: 0.4536
# epoch 2/50 steps 60/100, |train-loss: 0.7254
# epoch 2/50 steps 65/100, |train-loss: 0.7367
# epoch 2/50 steps 70/100, |train-loss: 0.4471
# epoch 2/50 steps 75/100, |train-loss: 0.6623
# epoch 2/50 steps 80/100, |train-loss: 0.6136
# epoch 2/50 steps 85/100, |train-loss: 0.7884
# epoch 2/50 steps 90/100, |train-loss: 0.7269
# epoch 2/50 steps 95/100, |train-loss: 0.5206
# epoch 2/50 steps 100/100, |train-loss: 0.7227 |avg-loss: 0.6899 dur 54.0s |val-acc: 0.5000 |old-best: 0.5227
# epoch 3/50 steps 5/100, |train-loss: 0.8756
# epoch 3/50 steps 10/100, |train-loss: 0.8072
# epoch 3/50 steps 15/100, |train-loss: 0.4670
# epoch 3/50 steps 20/100, |train-loss: 0.5757
# epoch 3/50 steps 25/100, |train-loss: 0.7537
# epoch 3/50 steps 30/100, |train-loss: 0.8430
# epoch 3/50 steps 35/100, |train-loss: 0.4425
# epoch 3/50 steps 40/100, |train-loss: 1.1038
# epoch 3/50 steps 45/100, |train-loss: 0.9686
# epoch 3/50 steps 50/100, |train-loss: 0.6167
# epoch 3/50 steps 55/100, |train-loss: 0.6245
# epoch 3/50 steps 60/100, |train-loss: 0.6933
# epoch 3/50 steps 65/100, |train-loss: 0.8281
# epoch 3/50 steps 70/100, |train-loss: 0.5721
# epoch 3/50 steps 75/100, |train-loss: 0.6943
# epoch 3/50 steps 80/100, |train-loss: 0.5450
# epoch 3/50 steps 85/100, |train-loss: 0.6981
# epoch 3/50 steps 90/100, |train-loss: 0.7648
# epoch 3/50 steps 95/100, |train-loss: 1.0109
# epoch 3/50 steps 100/100, |train-loss: 0.9959 |avg-loss: 0.7096 dur 55.4s |val-acc: 0.5682 |old-best: 0.5227 |best model saved
# epoch 4/50 steps 5/100, |train-loss: 0.7635
# epoch 4/50 steps 10/100, |train-loss: 0.5087
# epoch 4/50 steps 15/100, |train-loss: 0.5367
# epoch 4/50 steps 20/100, |train-loss: 0.7133
# epoch 4/50 steps 25/100, |train-loss: 0.9276
# epoch 4/50 steps 30/100, |train-loss: 0.6491
# epoch 4/50 steps 35/100, |train-loss: 0.7323
# epoch 4/50 steps 40/100, |train-loss: 0.7296
# epoch 4/50 steps 45/100, |train-loss: 0.7433
# epoch 4/50 steps 50/100, |train-loss: 0.7403
# epoch 4/50 steps 55/100, |train-loss: 0.6896
# epoch 4/50 steps 60/100, |train-loss: 0.6855
# epoch 4/50 steps 65/100, |train-loss: 0.8536
# epoch 4/50 steps 70/100, |train-loss: 0.7833
# epoch 4/50 steps 75/100, |train-loss: 0.8882
# epoch 4/50 steps 80/100, |train-loss: 0.7661
# epoch 4/50 steps 85/100, |train-loss: 0.7521
# epoch 4/50 steps 90/100, |train-loss: 0.6849
# epoch 4/50 steps 95/100, |train-loss: 0.7571
# epoch 4/50 steps 100/100, |train-loss: 0.7313 |avg-loss: 0.7082 dur 52.8s |val-acc: 0.5000 |old-best: 0.5682
# epoch 5/50 steps 5/100, |train-loss: 0.6897
# epoch 5/50 steps 10/100, |train-loss: 0.6492
# epoch 5/50 steps 15/100, |train-loss: 0.7573
# epoch 5/50 steps 20/100, |train-loss: 0.7549
# epoch 5/50 steps 25/100, |train-loss: 0.6957
# epoch 5/50 steps 30/100, |train-loss: 0.5804
# epoch 5/50 steps 35/100, |train-loss: 0.8639
# epoch 5/50 steps 40/100, |train-loss: 0.6829
# epoch 5/50 steps 45/100, |train-loss: 0.6662
# epoch 5/50 steps 50/100, |train-loss: 0.5322
# epoch 5/50 steps 55/100, |train-loss: 0.6723
# epoch 5/50 steps 60/100, |train-loss: 0.3768
# epoch 5/50 steps 65/100, |train-loss: 0.6045
# epoch 5/50 steps 70/100, |train-loss: 0.7536
# epoch 5/50 steps 75/100, |train-loss: 0.7285
# epoch 5/50 steps 80/100, |train-loss: 0.6025
# epoch 5/50 steps 85/100, |train-loss: 0.8105
# epoch 5/50 steps 90/100, |train-loss: 0.6192
# epoch 5/50 steps 95/100, |train-loss: 0.4607
# epoch 5/50 steps 100/100, |train-loss: 0.6930 |avg-loss: 0.6972 dur 54.3s |val-acc: 0.5455 |old-best: 0.5682
# epoch 6/50 steps 5/100, |train-loss: 0.6897
# epoch 6/50 steps 10/100, |train-loss: 0.5450
# epoch 6/50 steps 15/100, |train-loss: 0.6920
# epoch 6/50 steps 20/100, |train-loss: 0.7290
# epoch 6/50 steps 25/100, |train-loss: 0.6365
# epoch 6/50 steps 30/100, |train-loss: 0.3388
# epoch 6/50 steps 35/100, |train-loss: 0.7200
# epoch 6/50 steps 40/100, |train-loss: 0.7432
# epoch 6/50 steps 45/100, |train-loss: 0.6029
# epoch 6/50 steps 50/100, |train-loss: 0.7009
# epoch 6/50 steps 55/100, |train-loss: 0.6511
# epoch 6/50 steps 60/100, |train-loss: 0.5049
# epoch 6/50 steps 65/100, |train-loss: 0.8835
# epoch 6/50 steps 70/100, |train-loss: 1.0697
# epoch 6/50 steps 75/100, |train-loss: 0.6311
# epoch 6/50 steps 80/100, |train-loss: 0.4393
# epoch 6/50 steps 85/100, |train-loss: 1.0143
# epoch 6/50 steps 90/100, |train-loss: 1.1143
# epoch 6/50 steps 95/100, |train-loss: 0.6126
# epoch 6/50 steps 100/100, |train-loss: 0.6359 |avg-loss: 0.6768 dur 55.2s |val-acc: 0.4545 |old-best: 0.5682
# epoch 7/50 steps 5/100, |train-loss: 0.6044
# epoch 7/50 steps 10/100, |train-loss: 0.5971
# epoch 7/50 steps 15/100, |train-loss: 0.6447
# epoch 7/50 steps 20/100, |train-loss: 0.7911
# epoch 7/50 steps 25/100, |train-loss: 0.6004
# epoch 7/50 steps 30/100, |train-loss: 0.6578
# epoch 7/50 steps 35/100, |train-loss: 0.6738
# epoch 7/50 steps 40/100, |train-loss: 0.6998
# epoch 7/50 steps 45/100, |train-loss: 0.5624
# epoch 7/50 steps 50/100, |train-loss: 0.6646
# epoch 7/50 steps 55/100, |train-loss: 0.6736
# epoch 7/50 steps 60/100, |train-loss: 0.7606
# epoch 7/50 steps 65/100, |train-loss: 1.0243
# epoch 7/50 steps 70/100, |train-loss: 0.7219
# epoch 7/50 steps 75/100, |train-loss: 0.6876
# epoch 7/50 steps 80/100, |train-loss: 0.5019
# epoch 7/50 steps 85/100, |train-loss: 0.5733
# epoch 7/50 steps 90/100, |train-loss: 0.6728
# epoch 7/50 steps 95/100, |train-loss: 0.6787
# epoch 7/50 steps 100/100, |train-loss: 1.0954 |avg-loss: 0.6856 dur 53.9s |val-acc: 0.4545 |old-best: 0.5682
# epoch 8/50 steps 5/100, |train-loss: 0.8440
# epoch 8/50 steps 10/100, |train-loss: 0.6954
# epoch 8/50 steps 15/100, |train-loss: 0.6599
# epoch 8/50 steps 20/100, |train-loss: 0.7759
# epoch 8/50 steps 25/100, |train-loss: 0.7101
# epoch 8/50 steps 30/100, |train-loss: 0.6999
# epoch 8/50 steps 35/100, |train-loss: 0.7472
# epoch 8/50 steps 40/100, |train-loss: 0.8719
# epoch 8/50 steps 45/100, |train-loss: 0.3572
# epoch 8/50 steps 50/100, |train-loss: 0.6927
# epoch 8/50 steps 55/100, |train-loss: 0.7080
# epoch 8/50 steps 60/100, |train-loss: 0.8388
# epoch 8/50 steps 65/100, |train-loss: 0.8825
# epoch 8/50 steps 70/100, |train-loss: 0.6285
# epoch 8/50 steps 75/100, |train-loss: 0.8019
# epoch 8/50 steps 80/100, |train-loss: 0.8678
# epoch 8/50 steps 85/100, |train-loss: 0.5893
# epoch 8/50 steps 90/100, |train-loss: 0.7412
# epoch 8/50 steps 95/100, |train-loss: 0.6471
# epoch 8/50 steps 100/100, |train-loss: 0.7576 |avg-loss: 0.6897 dur 34.9s |val-acc: 0.4545 |old-best: 0.5682
# epoch 9/50 steps 5/100, |train-loss: 0.6691
# epoch 9/50 steps 10/100, |train-loss: 0.6034
# epoch 9/50 steps 15/100, |train-loss: 0.6035
# epoch 9/50 steps 20/100, |train-loss: 0.6483
# epoch 9/50 steps 25/100, |train-loss: 0.3766
# epoch 9/50 steps 30/100, |train-loss: 0.4871
# epoch 9/50 steps 35/100, |train-loss: 0.5419
# epoch 9/50 steps 40/100, |train-loss: 0.5420
# epoch 9/50 steps 45/100, |train-loss: 0.4676
# epoch 9/50 steps 50/100, |train-loss: 0.5419
# epoch 9/50 steps 55/100, |train-loss: 0.5911
# epoch 9/50 steps 60/100, |train-loss: 0.6063
# epoch 9/50 steps 65/100, |train-loss: 0.7444
# epoch 9/50 steps 70/100, |train-loss: 0.7248
# epoch 9/50 steps 75/100, |train-loss: 0.6735
# epoch 9/50 steps 80/100, |train-loss: 0.5211
# epoch 9/50 steps 85/100, |train-loss: 0.9710
# epoch 9/50 steps 90/100, |train-loss: 0.8654
# epoch 9/50 steps 95/100, |train-loss: 0.8968
# epoch 9/50 steps 100/100, |train-loss: 0.5743 |avg-loss: 0.6769 dur 32.9s |val-acc: 0.3864 |old-best: 0.5682
# epoch 10/50 steps 5/100, |train-loss: 0.5769
# epoch 10/50 steps 10/100, |train-loss: 0.7433
# epoch 10/50 steps 15/100, |train-loss: 0.8693
# epoch 10/50 steps 20/100, |train-loss: 0.8549
# epoch 10/50 steps 25/100, |train-loss: 0.8125
# epoch 10/50 steps 30/100, |train-loss: 0.6947
# epoch 10/50 steps 35/100, |train-loss: 0.8362
# epoch 10/50 steps 40/100, |train-loss: 0.6480
# epoch 10/50 steps 45/100, |train-loss: 0.5963
# epoch 10/50 steps 50/100, |train-loss: 0.6307
# epoch 10/50 steps 55/100, |train-loss: 0.7025
# epoch 10/50 steps 60/100, |train-loss: 0.7349
# epoch 10/50 steps 65/100, |train-loss: 0.6763
# epoch 10/50 steps 70/100, |train-loss: 0.7147
# epoch 10/50 steps 75/100, |train-loss: 0.5812
# epoch 10/50 steps 80/100, |train-loss: 0.6649
# epoch 10/50 steps 85/100, |train-loss: 0.8185
# epoch 10/50 steps 90/100, |train-loss: 0.8343
# epoch 10/50 steps 95/100, |train-loss: 0.7389
# epoch 10/50 steps 100/100, |train-loss: 0.7258 |avg-loss: 0.6899 dur 34.6s |val-acc: 0.5000 |old-best: 0.5682 |10ep model saved
# epoch 11/50 steps 5/100, |train-loss: 0.5049
# epoch 11/50 steps 10/100, |train-loss: 0.6589
# epoch 11/50 steps 15/100, |train-loss: 0.8142
# epoch 11/50 steps 20/100, |train-loss: 0.5393
# epoch 11/50 steps 25/100, |train-loss: 0.5879
# epoch 11/50 steps 30/100, |train-loss: 0.7786
# epoch 11/50 steps 35/100, |train-loss: 0.4476
# epoch 11/50 steps 40/100, |train-loss: 0.8238
# epoch 11/50 steps 45/100, |train-loss: 0.7884
# epoch 11/50 steps 50/100, |train-loss: 0.6272
# epoch 11/50 steps 55/100, |train-loss: 0.3506
# epoch 11/50 steps 60/100, |train-loss: 0.5278
# epoch 11/50 steps 65/100, |train-loss: 0.8350
# epoch 11/50 steps 70/100, |train-loss: 0.3453
# epoch 11/50 steps 75/100, |train-loss: 0.7158
# epoch 11/50 steps 80/100, |train-loss: 0.6330
# epoch 11/50 steps 85/100, |train-loss: 0.6764
# epoch 11/50 steps 90/100, |train-loss: 0.6144
# epoch 11/50 steps 95/100, |train-loss: 0.8757
# epoch 11/50 steps 100/100, |train-loss: 0.6175 |avg-loss: 0.6737 dur 49.9s |val-acc: 0.4091 |old-best: 0.5682
# epoch 12/50 steps 5/100, |train-loss: 0.7475
# epoch 12/50 steps 10/100, |train-loss: 0.3755
# epoch 12/50 steps 15/100, |train-loss: 0.5778
# epoch 12/50 steps 20/100, |train-loss: 1.1021
# epoch 12/50 steps 25/100, |train-loss: 0.6371
# epoch 12/50 steps 30/100, |train-loss: 0.4602
# epoch 12/50 steps 35/100, |train-loss: 0.7465
# epoch 12/50 steps 40/100, |train-loss: 0.4021
# epoch 12/50 steps 45/100, |train-loss: 0.7225
# epoch 12/50 steps 50/100, |train-loss: 0.4393
# epoch 12/50 steps 55/100, |train-loss: 0.8440
# epoch 12/50 steps 60/100, |train-loss: 0.6986
# epoch 12/50 steps 65/100, |train-loss: 0.7057
# epoch 12/50 steps 70/100, |train-loss: 0.6361
# epoch 12/50 steps 75/100, |train-loss: 0.7681
# epoch 12/50 steps 80/100, |train-loss: 0.7330
# epoch 12/50 steps 85/100, |train-loss: 0.7557
# epoch 12/50 steps 90/100, |train-loss: 0.7057
# epoch 12/50 steps 95/100, |train-loss: 0.7684
# epoch 12/50 steps 100/100, |train-loss: 0.7433 |avg-loss: 0.6548 dur 50.5s |val-acc: 0.4545 |old-best: 0.5682
# epoch 13/50 steps 5/100, |train-loss: 0.8316
# epoch 13/50 steps 10/100, |train-loss: 0.7115
# epoch 13/50 steps 15/100, |train-loss: 0.6741
# epoch 13/50 steps 20/100, |train-loss: 0.7541
# epoch 13/50 steps 25/100, |train-loss: 0.4197
# epoch 13/50 steps 30/100, |train-loss: 1.0497
# epoch 13/50 steps 35/100, |train-loss: 0.7747
# epoch 13/50 steps 40/100, |train-loss: 0.4731
# epoch 13/50 steps 45/100, |train-loss: 0.4277
# epoch 13/50 steps 50/100, |train-loss: 0.8031
# epoch 13/50 steps 55/100, |train-loss: 0.4008
# epoch 13/50 steps 60/100, |train-loss: 0.6763
# epoch 13/50 steps 65/100, |train-loss: 0.4698
# epoch 13/50 steps 70/100, |train-loss: 0.6032
# epoch 13/50 steps 75/100, |train-loss: 0.6556
# epoch 13/50 steps 80/100, |train-loss: 0.6426
# epoch 13/50 steps 85/100, |train-loss: 0.7697
# epoch 13/50 steps 90/100, |train-loss: 0.7672
# epoch 13/50 steps 95/100, |train-loss: 0.7288
# epoch 13/50 steps 100/100, |train-loss: 0.3792 |avg-loss: 0.6477 dur 51.8s |val-acc: 0.3864 |old-best: 0.5682
# epoch 14/50 steps 5/100, |train-loss: 0.7098
# epoch 14/50 steps 10/100, |train-loss: 0.3698
# epoch 14/50 steps 15/100, |train-loss: 0.8160
# epoch 14/50 steps 20/100, |train-loss: 0.9663
# epoch 14/50 steps 25/100, |train-loss: 0.7370
# epoch 14/50 steps 30/100, |train-loss: 0.7380
# epoch 14/50 steps 35/100, |train-loss: 0.4878
# epoch 14/50 steps 40/100, |train-loss: 0.6672
# epoch 14/50 steps 45/100, |train-loss: 0.2554
# epoch 14/50 steps 50/100, |train-loss: 0.8806
# epoch 14/50 steps 55/100, |train-loss: 0.8748
# epoch 14/50 steps 60/100, |train-loss: 0.6808
# epoch 14/50 steps 65/100, |train-loss: 0.5889
# epoch 14/50 steps 70/100, |train-loss: 0.8285
# epoch 14/50 steps 75/100, |train-loss: 0.2816
# epoch 14/50 steps 80/100, |train-loss: 0.7358
# epoch 14/50 steps 85/100, |train-loss: 0.4252
# epoch 14/50 steps 90/100, |train-loss: 0.5955
# epoch 14/50 steps 95/100, |train-loss: 0.5528
# epoch 14/50 steps 100/100, |train-loss: 0.9028 |avg-loss: 0.6544 dur 49.1s |val-acc: 0.4318 |old-best: 0.5682
# epoch 15/50 steps 5/100, |train-loss: 0.6801
# epoch 15/50 steps 10/100, |train-loss: 0.5605
# epoch 15/50 steps 15/100, |train-loss: 0.7546
# epoch 15/50 steps 20/100, |train-loss: 1.0615
# epoch 15/50 steps 25/100, |train-loss: 0.8084
# epoch 15/50 steps 30/100, |train-loss: 0.7198
# epoch 15/50 steps 35/100, |train-loss: 0.5285
# epoch 15/50 steps 40/100, |train-loss: 0.6979
# epoch 15/50 steps 45/100, |train-loss: 0.5917
# epoch 15/50 steps 50/100, |train-loss: 0.6788
# epoch 15/50 steps 55/100, |train-loss: 0.7207
# epoch 15/50 steps 60/100, |train-loss: 0.5905
# epoch 15/50 steps 65/100, |train-loss: 0.4280
# epoch 15/50 steps 70/100, |train-loss: 0.8587
# epoch 15/50 steps 75/100, |train-loss: 0.8768
# epoch 15/50 steps 80/100, |train-loss: 0.6421
# epoch 15/50 steps 85/100, |train-loss: 0.4638
# epoch 15/50 steps 90/100, |train-loss: 0.6784
# epoch 15/50 steps 95/100, |train-loss: 0.8185
# epoch 15/50 steps 100/100, |train-loss: 0.7841 |avg-loss: 0.6912 dur 50.7s |val-acc: 0.4091 |old-best: 0.5682
# epoch 16/50 steps 5/100, |train-loss: 0.7574
# epoch 16/50 steps 10/100, |train-loss: 0.2795
# epoch 16/50 steps 15/100, |train-loss: 0.9144
# epoch 16/50 steps 20/100, |train-loss: 0.7158
# epoch 16/50 steps 25/100, |train-loss: 0.8597
# epoch 16/50 steps 30/100, |train-loss: 0.7455
# epoch 16/50 steps 35/100, |train-loss: 0.6847
# epoch 16/50 steps 40/100, |train-loss: 0.6607
# epoch 16/50 steps 45/100, |train-loss: 0.7320
# epoch 16/50 steps 50/100, |train-loss: 0.6618
# epoch 16/50 steps 55/100, |train-loss: 0.6742
# epoch 16/50 steps 60/100, |train-loss: 0.4578
# epoch 16/50 steps 65/100, |train-loss: 0.6403
# epoch 16/50 steps 70/100, |train-loss: 0.4880
# epoch 16/50 steps 75/100, |train-loss: 0.5758
# epoch 16/50 steps 80/100, |train-loss: 0.6182
# epoch 16/50 steps 85/100, |train-loss: 0.4960
# epoch 16/50 steps 90/100, |train-loss: 0.8750
# epoch 16/50 steps 95/100, |train-loss: 0.5183
# epoch 16/50 steps 100/100, |train-loss: 0.6344 |avg-loss: 0.6931 dur 52.4s |val-acc: 0.4545 |old-best: 0.5682
# epoch 17/50 steps 5/100, |train-loss: 0.6823
# epoch 17/50 steps 10/100, |train-loss: 0.6688
# epoch 17/50 steps 15/100, |train-loss: 0.6797
# epoch 17/50 steps 20/100, |train-loss: 0.6376
# epoch 17/50 steps 25/100, |train-loss: 0.6028
# epoch 17/50 steps 30/100, |train-loss: 0.6705
# epoch 17/50 steps 35/100, |train-loss: 0.6278
# epoch 17/50 steps 40/100, |train-loss: 0.5400
# epoch 17/50 steps 45/100, |train-loss: 0.8213
# epoch 17/50 steps 50/100, |train-loss: 0.7172
# epoch 17/50 steps 55/100, |train-loss: 0.5284
# epoch 17/50 steps 60/100, |train-loss: 0.9650
# epoch 17/50 steps 65/100, |train-loss: 0.6556
# epoch 17/50 steps 70/100, |train-loss: 0.3513
# epoch 17/50 steps 75/100, |train-loss: 0.5771
# epoch 17/50 steps 80/100, |train-loss: 0.4960
# epoch 17/50 steps 85/100, |train-loss: 0.5355
# epoch 17/50 steps 90/100, |train-loss: 0.6400
# epoch 17/50 steps 95/100, |train-loss: 0.4521
# epoch 17/50 steps 100/100, |train-loss: 0.8787 |avg-loss: 0.6521 dur 50.1s |val-acc: 0.5000 |old-best: 0.5682
# epoch 18/50 steps 5/100, |train-loss: 0.6107
# epoch 18/50 steps 10/100, |train-loss: 0.6622
# epoch 18/50 steps 15/100, |train-loss: 0.7253
# epoch 18/50 steps 20/100, |train-loss: 0.7422
# epoch 18/50 steps 25/100, |train-loss: 0.3993
# epoch 18/50 steps 30/100, |train-loss: 0.7932
# epoch 18/50 steps 35/100, |train-loss: 0.7556
# epoch 18/50 steps 40/100, |train-loss: 0.5155
# epoch 18/50 steps 45/100, |train-loss: 0.7000
# epoch 18/50 steps 50/100, |train-loss: 0.8764
# epoch 18/50 steps 55/100, |train-loss: 0.5736
# epoch 18/50 steps 60/100, |train-loss: 0.6495
# epoch 18/50 steps 65/100, |train-loss: 1.2982
# epoch 18/50 steps 70/100, |train-loss: 0.6648
# epoch 18/50 steps 75/100, |train-loss: 0.6581
# epoch 18/50 steps 80/100, |train-loss: 0.6906
# epoch 18/50 steps 85/100, |train-loss: 0.2884
# epoch 18/50 steps 90/100, |train-loss: 0.7909
# epoch 18/50 steps 95/100, |train-loss: 0.6879
# epoch 18/50 steps 100/100, |train-loss: 0.6682 |avg-loss: 0.6304 dur 49.2s |val-acc: 0.4091 |old-best: 0.5682
# epoch 19/50 steps 5/100, |train-loss: 0.7650
# epoch 19/50 steps 10/100, |train-loss: 0.7708
# epoch 19/50 steps 15/100, |train-loss: 0.3040
# epoch 19/50 steps 20/100, |train-loss: 0.5700
# epoch 19/50 steps 25/100, |train-loss: 0.5240
# epoch 19/50 steps 30/100, |train-loss: 0.4683
# epoch 19/50 steps 35/100, |train-loss: 0.9750
# epoch 19/50 steps 40/100, |train-loss: 1.4427
# epoch 19/50 steps 45/100, |train-loss: 0.7272
# epoch 19/50 steps 50/100, |train-loss: 0.5662
# epoch 19/50 steps 55/100, |train-loss: 0.7045
# epoch 19/50 steps 60/100, |train-loss: 0.7138
# epoch 19/50 steps 65/100, |train-loss: 0.6789
# epoch 19/50 steps 70/100, |train-loss: 0.7303
# epoch 19/50 steps 75/100, |train-loss: 0.6569
# epoch 19/50 steps 80/100, |train-loss: 0.4855
# epoch 19/50 steps 85/100, |train-loss: 0.7180
# epoch 19/50 steps 90/100, |train-loss: 0.3613
# epoch 19/50 steps 95/100, |train-loss: 0.6196
# epoch 19/50 steps 100/100, |train-loss: 0.7689 |avg-loss: 0.6396 dur 50.7s |val-acc: 0.4545 |old-best: 0.5682
# epoch 20/50 steps 5/100, |train-loss: 0.6389
# epoch 20/50 steps 10/100, |train-loss: 0.7359
# epoch 20/50 steps 15/100, |train-loss: 0.7304
# epoch 20/50 steps 20/100, |train-loss: 0.6835
# epoch 20/50 steps 25/100, |train-loss: 0.4930
# epoch 20/50 steps 30/100, |train-loss: 0.7284
# epoch 20/50 steps 35/100, |train-loss: 0.6814
# epoch 20/50 steps 40/100, |train-loss: 0.6568
# epoch 20/50 steps 45/100, |train-loss: 0.6115
# epoch 20/50 steps 50/100, |train-loss: 0.2704
# epoch 20/50 steps 55/100, |train-loss: 0.7793
# epoch 20/50 steps 60/100, |train-loss: 0.2395
# epoch 20/50 steps 65/100, |train-loss: 0.8176
# epoch 20/50 steps 70/100, |train-loss: 0.7484
# epoch 20/50 steps 75/100, |train-loss: 0.4536
# epoch 20/50 steps 80/100, |train-loss: 0.7334
# epoch 20/50 steps 85/100, |train-loss: 0.5237
# epoch 20/50 steps 90/100, |train-loss: 0.6978
# epoch 20/50 steps 95/100, |train-loss: 0.6541
# epoch 20/50 steps 100/100, |train-loss: 1.4135 |avg-loss: 0.6185 dur 50.0s |val-acc: 0.5455 |old-best: 0.5682 |20ep model saved
# epoch 21/50 steps 5/100, |train-loss: 0.4231
# epoch 21/50 steps 10/100, |train-loss: 0.7469
# epoch 21/50 steps 15/100, |train-loss: 1.1033
# epoch 21/50 steps 20/100, |train-loss: 0.7584
# epoch 21/50 steps 25/100, |train-loss: 0.8262
# epoch 21/50 steps 30/100, |train-loss: 0.1328
# epoch 21/50 steps 35/100, |train-loss: 0.7948
# epoch 21/50 steps 40/100, |train-loss: 0.4303
# epoch 21/50 steps 45/100, |train-loss: 0.5802
# epoch 21/50 steps 50/100, |train-loss: 0.7062
# epoch 21/50 steps 55/100, |train-loss: 0.7309
# epoch 21/50 steps 60/100, |train-loss: 0.7695
# epoch 21/50 steps 65/100, |train-loss: 0.7387
# epoch 21/50 steps 70/100, |train-loss: 0.8682
# epoch 21/50 steps 75/100, |train-loss: 0.6790
# epoch 21/50 steps 80/100, |train-loss: 0.3810
# epoch 21/50 steps 85/100, |train-loss: 0.7027
# epoch 21/50 steps 90/100, |train-loss: 0.9142
# epoch 21/50 steps 95/100, |train-loss: 0.8933
# epoch 21/50 steps 100/100, |train-loss: 0.7031 |avg-loss: 0.6309 dur 50.3s |val-acc: 0.5000 |old-best: 0.5682
# epoch 22/50 steps 5/100, |train-loss: 0.3674
# epoch 22/50 steps 10/100, |train-loss: 0.7039
# epoch 22/50 steps 15/100, |train-loss: 1.1463
# epoch 22/50 steps 20/100, |train-loss: 0.6895
# epoch 22/50 steps 25/100, |train-loss: 0.7000
# epoch 22/50 steps 30/100, |train-loss: 0.7055
# epoch 22/50 steps 35/100, |train-loss: 0.6966
# epoch 22/50 steps 40/100, |train-loss: 0.4845
# epoch 22/50 steps 45/100, |train-loss: 0.6048
# epoch 22/50 steps 50/100, |train-loss: 0.8233
# epoch 22/50 steps 55/100, |train-loss: 0.7991
# epoch 22/50 steps 60/100, |train-loss: 0.6369
# epoch 22/50 steps 65/100, |train-loss: 0.5719
# epoch 22/50 steps 70/100, |train-loss: 0.5677
# epoch 22/50 steps 75/100, |train-loss: 0.5182
# epoch 22/50 steps 80/100, |train-loss: 0.6562
# epoch 22/50 steps 85/100, |train-loss: 0.6409
# epoch 22/50 steps 90/100, |train-loss: 0.3219
# epoch 22/50 steps 95/100, |train-loss: 0.3117
# epoch 22/50 steps 100/100, |train-loss: 0.6534 |avg-loss: 0.6321 dur 51.4s |val-acc: 0.5682 |old-best: 0.5682
# epoch 23/50 steps 5/100, |train-loss: 0.3842
# epoch 23/50 steps 10/100, |train-loss: 0.3352
# epoch 23/50 steps 15/100, |train-loss: 0.5726
# epoch 23/50 steps 20/100, |train-loss: 0.5856
# epoch 23/50 steps 25/100, |train-loss: 0.1331
# epoch 23/50 steps 30/100, |train-loss: 0.6152
# epoch 23/50 steps 35/100, |train-loss: 0.7369
# epoch 23/50 steps 40/100, |train-loss: 0.6305
# epoch 23/50 steps 45/100, |train-loss: 0.7514
# epoch 23/50 steps 50/100, |train-loss: 0.7630
# epoch 23/50 steps 55/100, |train-loss: 0.6658
# epoch 23/50 steps 60/100, |train-loss: 0.4494
# epoch 23/50 steps 65/100, |train-loss: 0.4476
# epoch 23/50 steps 70/100, |train-loss: 0.4981
# epoch 23/50 steps 75/100, |train-loss: 0.3980
# epoch 23/50 steps 80/100, |train-loss: 0.4787
# epoch 23/50 steps 85/100, |train-loss: 0.2993
# epoch 23/50 steps 90/100, |train-loss: 1.0918
# epoch 23/50 steps 95/100, |train-loss: 0.7813
# epoch 23/50 steps 100/100, |train-loss: 0.8511 |avg-loss: 0.5986 dur 47.6s |val-acc: 0.4773 |old-best: 0.5682
# epoch 24/50 steps 5/100, |train-loss: 1.0139
# epoch 24/50 steps 10/100, |train-loss: 0.3867
# epoch 24/50 steps 15/100, |train-loss: 0.8138
# epoch 24/50 steps 20/100, |train-loss: 0.6655
# epoch 24/50 steps 25/100, |train-loss: 0.6589
# epoch 24/50 steps 30/100, |train-loss: 0.7661
# epoch 24/50 steps 35/100, |train-loss: 0.7742
# epoch 24/50 steps 40/100, |train-loss: 0.6283
# epoch 24/50 steps 45/100, |train-loss: 0.6315
# epoch 24/50 steps 50/100, |train-loss: 0.6410
# epoch 24/50 steps 55/100, |train-loss: 0.7339
# epoch 24/50 steps 60/100, |train-loss: 0.5164
# epoch 24/50 steps 65/100, |train-loss: 0.5175
# epoch 24/50 steps 70/100, |train-loss: 0.8929
# epoch 24/50 steps 75/100, |train-loss: 0.4144
# epoch 24/50 steps 80/100, |train-loss: 0.2400
# epoch 24/50 steps 85/100, |train-loss: 0.8501
# epoch 24/50 steps 90/100, |train-loss: 0.9216
# epoch 24/50 steps 95/100, |train-loss: 0.2388
# epoch 24/50 steps 100/100, |train-loss: 0.6901 |avg-loss: 0.5977 dur 49.3s |val-acc: 0.4318 |old-best: 0.5682
# epoch 25/50 steps 5/100, |train-loss: 0.7224
# epoch 25/50 steps 10/100, |train-loss: 0.8662
# epoch 25/50 steps 15/100, |train-loss: 0.7183
# epoch 25/50 steps 20/100, |train-loss: 0.6942
# epoch 25/50 steps 25/100, |train-loss: 1.2240
# epoch 25/50 steps 30/100, |train-loss: 0.5773
# epoch 25/50 steps 35/100, |train-loss: 0.8914
# epoch 25/50 steps 40/100, |train-loss: 0.3439
# epoch 25/50 steps 45/100, |train-loss: 0.5939
# epoch 25/50 steps 50/100, |train-loss: 0.2684
# epoch 25/50 steps 55/100, |train-loss: 0.7468
# epoch 25/50 steps 60/100, |train-loss: 0.7280
# epoch 25/50 steps 65/100, |train-loss: 1.1106
# epoch 25/50 steps 70/100, |train-loss: 0.1923
# epoch 25/50 steps 75/100, |train-loss: 0.2969
# epoch 25/50 steps 80/100, |train-loss: 0.8274
# epoch 25/50 steps 85/100, |train-loss: 0.8430
# epoch 25/50 steps 90/100, |train-loss: 1.1227
# epoch 25/50 steps 95/100, |train-loss: 0.7387
# epoch 25/50 steps 100/100, |train-loss: 0.7109 |avg-loss: 0.6173 dur 51.0s |val-acc: 0.6136 |old-best: 0.5682 |best model saved
# epoch 26/50 steps 5/100, |train-loss: 0.2240
# epoch 26/50 steps 10/100, |train-loss: 0.6525
# epoch 26/50 steps 15/100, |train-loss: 0.5492
# epoch 26/50 steps 20/100, |train-loss: 0.6914
# epoch 26/50 steps 25/100, |train-loss: 0.7968
# epoch 26/50 steps 30/100, |train-loss: 0.1324
# epoch 26/50 steps 35/100, |train-loss: 0.8072
# epoch 26/50 steps 40/100, |train-loss: 0.7439
# epoch 26/50 steps 45/100, |train-loss: 0.6595
# epoch 26/50 steps 50/100, |train-loss: 0.6756
# epoch 26/50 steps 55/100, |train-loss: 0.5936
# epoch 26/50 steps 60/100, |train-loss: 0.5216
# epoch 26/50 steps 65/100, |train-loss: 0.2581
# epoch 26/50 steps 70/100, |train-loss: 0.3377
# epoch 26/50 steps 75/100, |train-loss: 0.4355
# epoch 26/50 steps 80/100, |train-loss: 0.7286
# epoch 26/50 steps 85/100, |train-loss: 0.1945
# epoch 26/50 steps 90/100, |train-loss: 0.9790
# epoch 26/50 steps 95/100, |train-loss: 0.8636
# epoch 26/50 steps 100/100, |train-loss: 0.9048 |avg-loss: 0.5800 dur 50.5s |val-acc: 0.4773 |old-best: 0.6136
# epoch 27/50 steps 5/100, |train-loss: 0.2132
# epoch 27/50 steps 10/100, |train-loss: 0.5070
# epoch 27/50 steps 15/100, |train-loss: 0.6462
# epoch 27/50 steps 20/100, |train-loss: 0.7600
# epoch 27/50 steps 25/100, |train-loss: 0.8044
# epoch 27/50 steps 30/100, |train-loss: 0.7631
# epoch 27/50 steps 35/100, |train-loss: 0.3857
# epoch 27/50 steps 40/100, |train-loss: 0.6845
# epoch 27/50 steps 45/100, |train-loss: 0.5348
# epoch 27/50 steps 50/100, |train-loss: 0.6439
# epoch 27/50 steps 55/100, |train-loss: 0.5891
# epoch 27/50 steps 60/100, |train-loss: 0.3334
# epoch 27/50 steps 65/100, |train-loss: 0.6772
# epoch 27/50 steps 70/100, |train-loss: 0.5455
# epoch 27/50 steps 75/100, |train-loss: 0.7215
# epoch 27/50 steps 80/100, |train-loss: 0.2128
# epoch 27/50 steps 85/100, |train-loss: 0.9935
# epoch 27/50 steps 90/100, |train-loss: 0.1967
# epoch 27/50 steps 95/100, |train-loss: 0.7390
# epoch 27/50 steps 100/100, |train-loss: 0.2148 |avg-loss: 0.5763 dur 49.7s |val-acc: 0.5227 |old-best: 0.6136
# epoch 28/50 steps 5/100, |train-loss: 0.6310
# epoch 28/50 steps 10/100, |train-loss: 0.8561
# epoch 28/50 steps 15/100, |train-loss: 0.5437
# epoch 28/50 steps 20/100, |train-loss: 0.3920
# epoch 28/50 steps 25/100, |train-loss: 0.8902
# epoch 28/50 steps 30/100, |train-loss: 0.1753
# epoch 28/50 steps 35/100, |train-loss: 0.6639
# epoch 28/50 steps 40/100, |train-loss: 0.2052
# epoch 28/50 steps 45/100, |train-loss: 0.6946
# epoch 28/50 steps 50/100, |train-loss: 0.7139
# epoch 28/50 steps 55/100, |train-loss: 0.7336
# epoch 28/50 steps 60/100, |train-loss: 0.1918
# epoch 28/50 steps 65/100, |train-loss: 0.4644
# epoch 28/50 steps 70/100, |train-loss: 0.8195
# epoch 28/50 steps 75/100, |train-loss: 0.2144
# epoch 28/50 steps 80/100, |train-loss: 0.5308
# epoch 28/50 steps 85/100, |train-loss: 0.4967
# epoch 28/50 steps 90/100, |train-loss: 0.6151
# epoch 28/50 steps 95/100, |train-loss: 0.7848
# epoch 28/50 steps 100/100, |train-loss: 0.7258 |avg-loss: 0.5468 dur 51.0s |val-acc: 0.4773 |old-best: 0.6136
# epoch 29/50 steps 5/100, |train-loss: 0.6144
# epoch 29/50 steps 10/100, |train-loss: 0.2133
# epoch 29/50 steps 15/100, |train-loss: 0.6723
# epoch 29/50 steps 20/100, |train-loss: 0.6799
# epoch 29/50 steps 25/100, |train-loss: 0.1069
# epoch 29/50 steps 30/100, |train-loss: 0.7882
# epoch 29/50 steps 35/100, |train-loss: 0.8164
# epoch 29/50 steps 40/100, |train-loss: 1.2496
# epoch 29/50 steps 45/100, |train-loss: 0.6357
# epoch 29/50 steps 50/100, |train-loss: 0.3968
# epoch 29/50 steps 55/100, |train-loss: 0.7541
# epoch 29/50 steps 60/100, |train-loss: 0.2006
# epoch 29/50 steps 65/100, |train-loss: 0.2163
# epoch 29/50 steps 70/100, |train-loss: 0.8721
# epoch 29/50 steps 75/100, |train-loss: 0.2336
# epoch 29/50 steps 80/100, |train-loss: 0.7294
# epoch 29/50 steps 85/100, |train-loss: 0.2878
# epoch 29/50 steps 90/100, |train-loss: 1.3771
# epoch 29/50 steps 95/100, |train-loss: 0.6725
# epoch 29/50 steps 100/100, |train-loss: 0.1883 |avg-loss: 0.5219 dur 51.6s |val-acc: 0.4318 |old-best: 0.6136
# epoch 30/50 steps 5/100, |train-loss: 0.7479
# epoch 30/50 steps 10/100, |train-loss: 0.4357
# epoch 30/50 steps 15/100, |train-loss: 0.3408
# epoch 30/50 steps 20/100, |train-loss: 0.7411
# epoch 30/50 steps 25/100, |train-loss: 0.8323
# epoch 30/50 steps 30/100, |train-loss: 0.1671
# epoch 30/50 steps 35/100, |train-loss: 0.2191
# epoch 30/50 steps 40/100, |train-loss: 0.2506
# epoch 30/50 steps 45/100, |train-loss: 0.3362
# epoch 30/50 steps 50/100, |train-loss: 0.3564
# epoch 30/50 steps 55/100, |train-loss: 0.2082
# epoch 30/50 steps 60/100, |train-loss: 0.7127
# epoch 30/50 steps 65/100, |train-loss: 0.3358
# epoch 30/50 steps 70/100, |train-loss: 0.3530
# epoch 30/50 steps 75/100, |train-loss: 0.4746
# epoch 30/50 steps 80/100, |train-loss: 0.8901
# epoch 30/50 steps 85/100, |train-loss: 0.6473
# epoch 30/50 steps 90/100, |train-loss: 0.3177
# epoch 30/50 steps 95/100, |train-loss: 0.1855
# epoch 30/50 steps 100/100, |train-loss: 0.5829 |avg-loss: 0.5098 dur 49.3s |val-acc: 0.3864 |old-best: 0.6136 |30ep model saved
# epoch 31/50 steps 5/100, |train-loss: 0.1610
# epoch 31/50 steps 10/100, |train-loss: 0.2247
# epoch 31/50 steps 15/100, |train-loss: 0.4877
# epoch 31/50 steps 20/100, |train-loss: 0.5124
# epoch 31/50 steps 25/100, |train-loss: 0.1225
# epoch 31/50 steps 30/100, |train-loss: 0.8076
# epoch 31/50 steps 35/100, |train-loss: 0.7179
# epoch 31/50 steps 40/100, |train-loss: 0.1171
# epoch 31/50 steps 45/100, |train-loss: 0.7322
# epoch 31/50 steps 50/100, |train-loss: 0.1264
# epoch 31/50 steps 55/100, |train-loss: 0.2803
# epoch 31/50 steps 60/100, |train-loss: 0.6593
# epoch 31/50 steps 65/100, |train-loss: 0.7199
# epoch 31/50 steps 70/100, |train-loss: 0.5891
# epoch 31/50 steps 75/100, |train-loss: 0.1961
# epoch 31/50 steps 80/100, |train-loss: 0.4294
# epoch 31/50 steps 85/100, |train-loss: 0.1384
# epoch 31/50 steps 90/100, |train-loss: 0.6836
# epoch 31/50 steps 95/100, |train-loss: 0.6414
# epoch 31/50 steps 100/100, |train-loss: 0.7685 |avg-loss: 0.5087 dur 49.3s |val-acc: 0.5000 |old-best: 0.6136
# epoch 32/50 steps 5/100, |train-loss: 0.7336
# epoch 32/50 steps 10/100, |train-loss: 0.6654
# epoch 32/50 steps 15/100, |train-loss: 0.7249
# epoch 32/50 steps 20/100, |train-loss: 0.6134
# epoch 32/50 steps 25/100, |train-loss: 0.7571
# epoch 32/50 steps 30/100, |train-loss: 0.2578
# epoch 32/50 steps 35/100, |train-loss: 0.1550
# epoch 32/50 steps 40/100, |train-loss: 0.6178
# epoch 32/50 steps 45/100, |train-loss: 0.1266
# epoch 32/50 steps 50/100, |train-loss: 0.1418
# epoch 32/50 steps 55/100, |train-loss: 0.2129
# epoch 32/50 steps 60/100, |train-loss: 0.2836
# epoch 32/50 steps 65/100, |train-loss: 0.1557
# epoch 32/50 steps 70/100, |train-loss: 0.6187
# epoch 32/50 steps 75/100, |train-loss: 0.5739
# epoch 32/50 steps 80/100, |train-loss: 0.5545
# epoch 32/50 steps 85/100, |train-loss: 0.6009
# epoch 32/50 steps 90/100, |train-loss: 0.5216
# epoch 32/50 steps 95/100, |train-loss: 0.3029
# epoch 32/50 steps 100/100, |train-loss: 0.1047 |avg-loss: 0.4934 dur 51.0s |val-acc: 0.4773 |old-best: 0.6136
# epoch 33/50 steps 5/100, |train-loss: 0.6354
# epoch 33/50 steps 10/100, |train-loss: 0.1403
# epoch 33/50 steps 15/100, |train-loss: 0.6005
# epoch 33/50 steps 20/100, |train-loss: 0.9109
# epoch 33/50 steps 25/100, |train-loss: 0.8695
# epoch 33/50 steps 30/100, |train-loss: 0.1224
# epoch 33/50 steps 35/100, |train-loss: 0.7410
# epoch 33/50 steps 40/100, |train-loss: 0.6513
# epoch 33/50 steps 45/100, |train-loss: 0.5959
# epoch 33/50 steps 50/100, |train-loss: 0.3125
# epoch 33/50 steps 55/100, |train-loss: 0.9525
# epoch 33/50 steps 60/100, |train-loss: 0.1301
# epoch 33/50 steps 65/100, |train-loss: 0.7401
# epoch 33/50 steps 70/100, |train-loss: 0.0965
# epoch 33/50 steps 75/100, |train-loss: 0.0981
# epoch 33/50 steps 80/100, |train-loss: 0.6533
# epoch 33/50 steps 85/100, |train-loss: 0.1518
# epoch 33/50 steps 90/100, |train-loss: 0.6776
# epoch 33/50 steps 95/100, |train-loss: 0.1090
# epoch 33/50 steps 100/100, |train-loss: 0.6846 |avg-loss: 0.4346 dur 49.3s |val-acc: 0.4318 |old-best: 0.6136
# epoch 34/50 steps 5/100, |train-loss: 0.6786
# epoch 34/50 steps 10/100, |train-loss: 0.1726
# epoch 34/50 steps 15/100, |train-loss: 0.6564
# epoch 34/50 steps 20/100, |train-loss: 0.2615
# epoch 34/50 steps 25/100, |train-loss: 0.1708
# epoch 34/50 steps 30/100, |train-loss: 0.1780
# epoch 34/50 steps 35/100, |train-loss: 0.8867
# epoch 34/50 steps 40/100, |train-loss: 0.6723
# epoch 34/50 steps 45/100, |train-loss: 0.2974
# epoch 34/50 steps 50/100, |train-loss: 0.5773
# epoch 34/50 steps 55/100, |train-loss: 0.6195
# epoch 34/50 steps 60/100, |train-loss: 0.6311
# epoch 34/50 steps 65/100, |train-loss: 0.6355
# epoch 34/50 steps 70/100, |train-loss: 0.6054
# epoch 34/50 steps 75/100, |train-loss: 0.6853
# epoch 34/50 steps 80/100, |train-loss: 0.1553
# epoch 34/50 steps 85/100, |train-loss: 0.6578
# epoch 34/50 steps 90/100, |train-loss: 0.6363
# epoch 34/50 steps 95/100, |train-loss: 0.6393
# epoch 34/50 steps 100/100, |train-loss: 0.1237 |avg-loss: 0.4240 dur 51.1s |val-acc: 0.5227 |old-best: 0.6136
# epoch 35/50 steps 5/100, |train-loss: 0.7273
# epoch 35/50 steps 10/100, |train-loss: 0.7522
# epoch 35/50 steps 15/100, |train-loss: 0.9236
# epoch 35/50 steps 20/100, |train-loss: 0.1128
# epoch 35/50 steps 25/100, |train-loss: 0.2304
# epoch 35/50 steps 30/100, |train-loss: 0.0735
# epoch 35/50 steps 35/100, |train-loss: 0.5596
# epoch 35/50 steps 40/100, |train-loss: 0.1427
# epoch 35/50 steps 45/100, |train-loss: 0.2583
# epoch 35/50 steps 50/100, |train-loss: 0.7714
# epoch 35/50 steps 55/100, |train-loss: 0.5801
# epoch 35/50 steps 60/100, |train-loss: 0.6192
# epoch 35/50 steps 65/100, |train-loss: 0.2971
# epoch 35/50 steps 70/100, |train-loss: 0.5925
# epoch 35/50 steps 75/100, |train-loss: 0.1173
# epoch 35/50 steps 80/100, |train-loss: 0.5957
# epoch 35/50 steps 85/100, |train-loss: 0.1007
# epoch 35/50 steps 90/100, |train-loss: 0.8596
# epoch 35/50 steps 95/100, |train-loss: 0.6342
# epoch 35/50 steps 100/100, |train-loss: 0.5488 |avg-loss: 0.4166 dur 49.4s |val-acc: 0.5909 |old-best: 0.6136
# epoch 36/50 steps 5/100, |train-loss: 0.1410
# epoch 36/50 steps 10/100, |train-loss: 0.3342
# epoch 36/50 steps 15/100, |train-loss: 0.7892
# epoch 36/50 steps 20/100, |train-loss: 0.7338
# epoch 36/50 steps 25/100, |train-loss: 0.1963
# epoch 36/50 steps 30/100, |train-loss: 0.5697
# epoch 36/50 steps 35/100, |train-loss: 0.5464
# epoch 36/50 steps 40/100, |train-loss: 0.1639
# epoch 36/50 steps 45/100, |train-loss: 0.2783
# epoch 36/50 steps 50/100, |train-loss: 0.5898
# epoch 36/50 steps 55/100, |train-loss: 0.1180
# epoch 36/50 steps 60/100, |train-loss: 0.7477
# epoch 36/50 steps 65/100, |train-loss: 0.1224
# epoch 36/50 steps 70/100, |train-loss: 0.5341
# epoch 36/50 steps 75/100, |train-loss: 0.2540
# epoch 36/50 steps 80/100, |train-loss: 0.1388
# epoch 36/50 steps 85/100, |train-loss: 0.1115
# epoch 36/50 steps 90/100, |train-loss: 0.2546
# epoch 36/50 steps 95/100, |train-loss: 0.6785
# epoch 36/50 steps 100/100, |train-loss: 0.0496 |avg-loss: 0.3841 dur 49.3s |val-acc: 0.4318 |old-best: 0.6136
# epoch 37/50 steps 5/100, |train-loss: 0.5846
# epoch 37/50 steps 10/100, |train-loss: 0.6062
# epoch 37/50 steps 15/100, |train-loss: 0.5717
# epoch 37/50 steps 20/100, |train-loss: 0.1190
# epoch 37/50 steps 25/100, |train-loss: 0.1735
# epoch 37/50 steps 30/100, |train-loss: 0.6931
# epoch 37/50 steps 35/100, |train-loss: 0.1213
# epoch 37/50 steps 40/100, |train-loss: 0.6421
# epoch 37/50 steps 45/100, |train-loss: 0.0578
# epoch 37/50 steps 50/100, |train-loss: 0.0695
# epoch 37/50 steps 55/100, |train-loss: 0.1251
# epoch 37/50 steps 60/100, |train-loss: 0.5157
# epoch 37/50 steps 65/100, |train-loss: 0.3962
# epoch 37/50 steps 70/100, |train-loss: 0.0750
# epoch 37/50 steps 75/100, |train-loss: 0.5799
# epoch 37/50 steps 80/100, |train-loss: 0.1948
# epoch 37/50 steps 85/100, |train-loss: 0.1251
# epoch 37/50 steps 90/100, |train-loss: 0.0961
# epoch 37/50 steps 95/100, |train-loss: 0.1773
# epoch 37/50 steps 100/100, |train-loss: 0.8044 |avg-loss: 0.3614 dur 51.1s |val-acc: 0.4545 |old-best: 0.6136
# epoch 38/50 steps 5/100, |train-loss: 0.1150
# epoch 38/50 steps 10/100, |train-loss: 0.8573
# epoch 38/50 steps 15/100, |train-loss: 0.1075
# epoch 38/50 steps 20/100, |train-loss: 0.0555
# epoch 38/50 steps 25/100, |train-loss: 0.6860
# epoch 38/50 steps 30/100, |train-loss: 0.1429
# epoch 38/50 steps 35/100, |train-loss: 0.0983
# epoch 38/50 steps 40/100, |train-loss: 0.5070
# epoch 38/50 steps 45/100, |train-loss: 0.0830
# epoch 38/50 steps 50/100, |train-loss: 0.6110
# epoch 38/50 steps 55/100, |train-loss: 0.0514
# epoch 38/50 steps 60/100, |train-loss: 0.0487
# epoch 38/50 steps 65/100, |train-loss: 0.6290
# epoch 38/50 steps 70/100, |train-loss: 0.1339
# epoch 38/50 steps 75/100, |train-loss: 0.0522
# epoch 38/50 steps 80/100, |train-loss: 0.6584
# epoch 38/50 steps 85/100, |train-loss: 0.0771
# epoch 38/50 steps 90/100, |train-loss: 0.0217
# epoch 38/50 steps 95/100, |train-loss: 0.1561
# epoch 38/50 steps 100/100, |train-loss: 0.8595 |avg-loss: 0.3571 dur 52.0s |val-acc: 0.4091 |old-best: 0.6136
# epoch 39/50 steps 5/100, |train-loss: 0.0664
# epoch 39/50 steps 10/100, |train-loss: 0.4869
# epoch 39/50 steps 15/100, |train-loss: 0.4795
# epoch 39/50 steps 20/100, |train-loss: 0.5262
# epoch 39/50 steps 25/100, |train-loss: 0.6102
# epoch 39/50 steps 30/100, |train-loss: 0.0473
# epoch 39/50 steps 35/100, |train-loss: 0.5485
# epoch 39/50 steps 40/100, |train-loss: 0.4686
# epoch 39/50 steps 45/100, |train-loss: 0.0800
# epoch 39/50 steps 50/100, |train-loss: 0.0715
# epoch 39/50 steps 55/100, |train-loss: 0.1436
# epoch 39/50 steps 60/100, |train-loss: 0.0828
# epoch 39/50 steps 65/100, |train-loss: 0.5560
# epoch 39/50 steps 70/100, |train-loss: 0.0424
# epoch 39/50 steps 75/100, |train-loss: 0.2059
# epoch 39/50 steps 80/100, |train-loss: 0.4490
# epoch 39/50 steps 85/100, |train-loss: 0.0455
# epoch 39/50 steps 90/100, |train-loss: 0.0905
# epoch 39/50 steps 95/100, |train-loss: 0.2331
# epoch 39/50 steps 100/100, |train-loss: 0.5151 |avg-loss: 0.3121 dur 49.6s |val-acc: 0.5227 |old-best: 0.6136
# epoch 40/50 steps 5/100, |train-loss: 0.4486
# epoch 40/50 steps 10/100, |train-loss: 0.4429
# epoch 40/50 steps 15/100, |train-loss: 0.5531
# epoch 40/50 steps 20/100, |train-loss: 0.1341
# epoch 40/50 steps 25/100, |train-loss: 0.5215
# epoch 40/50 steps 30/100, |train-loss: 0.0781
# epoch 40/50 steps 35/100, |train-loss: 0.6298
# epoch 40/50 steps 40/100, |train-loss: 0.4963
# epoch 40/50 steps 45/100, |train-loss: 0.8294
# epoch 40/50 steps 50/100, |train-loss: 0.0549
# epoch 40/50 steps 55/100, |train-loss: 0.5731
# epoch 40/50 steps 60/100, |train-loss: 0.0398
# epoch 40/50 steps 65/100, |train-loss: 0.0586
# epoch 40/50 steps 70/100, |train-loss: 0.6266
# epoch 40/50 steps 75/100, |train-loss: 0.8510
# epoch 40/50 steps 80/100, |train-loss: 0.4203
# epoch 40/50 steps 85/100, |train-loss: 0.5843
# epoch 40/50 steps 90/100, |train-loss: 0.5997
# epoch 40/50 steps 95/100, |train-loss: 0.4629
# epoch 40/50 steps 100/100, |train-loss: 0.0539 |avg-loss: 0.2675 dur 50.5s |val-acc: 0.4545 |old-best: 0.6136 |40ep model saved
# epoch 41/50 steps 5/100, |train-loss: 0.0603
# epoch 41/50 steps 10/100, |train-loss: 0.0602
# epoch 41/50 steps 15/100, |train-loss: 0.0293
# epoch 41/50 steps 20/100, |train-loss: 0.0527
# epoch 41/50 steps 25/100, |train-loss: 0.4495
# epoch 41/50 steps 30/100, |train-loss: 0.3795
# epoch 41/50 steps 35/100, |train-loss: 0.1330
# epoch 41/50 steps 40/100, |train-loss: 0.4916
# epoch 41/50 steps 45/100, |train-loss: 0.0422
# epoch 41/50 steps 50/100, |train-loss: 0.4979
# epoch 41/50 steps 55/100, |train-loss: 0.0459
# epoch 41/50 steps 60/100, |train-loss: 0.0779
# epoch 41/50 steps 65/100, |train-loss: 0.3429
# epoch 41/50 steps 70/100, |train-loss: 0.3664
# epoch 41/50 steps 75/100, |train-loss: 0.0425
# epoch 41/50 steps 80/100, |train-loss: 0.0696
# epoch 41/50 steps 85/100, |train-loss: 0.1366
# epoch 41/50 steps 90/100, |train-loss: 0.4867
# epoch 41/50 steps 95/100, |train-loss: 0.6676
# epoch 41/50 steps 100/100, |train-loss: 0.4400 |avg-loss: 0.3064 dur 49.9s |val-acc: 0.5455 |old-best: 0.6136
# epoch 42/50 steps 5/100, |train-loss: 0.3946
# epoch 42/50 steps 10/100, |train-loss: 0.5823
# epoch 42/50 steps 15/100, |train-loss: 0.0627
# epoch 42/50 steps 20/100, |train-loss: 0.4910
# epoch 42/50 steps 25/100, |train-loss: 0.3895
# epoch 42/50 steps 30/100, |train-loss: 0.4017
# epoch 42/50 steps 35/100, |train-loss: 0.3873
# epoch 42/50 steps 40/100, |train-loss: 0.4840
# epoch 42/50 steps 45/100, |train-loss: 0.0222
# epoch 42/50 steps 50/100, |train-loss: 0.3782
# epoch 42/50 steps 55/100, |train-loss: 0.3335
# epoch 42/50 steps 60/100, |train-loss: 0.3862
# epoch 42/50 steps 65/100, |train-loss: 0.1271
# epoch 42/50 steps 70/100, |train-loss: 0.1505
# epoch 42/50 steps 75/100, |train-loss: 0.0678
# epoch 42/50 steps 80/100, |train-loss: 0.0766
# epoch 42/50 steps 85/100, |train-loss: 0.4426
# epoch 42/50 steps 90/100, |train-loss: 0.3390
# epoch 42/50 steps 95/100, |train-loss: 0.0427
# epoch 42/50 steps 100/100, |train-loss: 0.3172 |avg-loss: 0.2853 dur 50.9s |val-acc: 0.5227 |old-best: 0.6136
# epoch 43/50 steps 5/100, |train-loss: 0.0969
# epoch 43/50 steps 10/100, |train-loss: 0.0378
# epoch 43/50 steps 15/100, |train-loss: 0.1190
# epoch 43/50 steps 20/100, |train-loss: 0.0541
# epoch 43/50 steps 25/100, |train-loss: 0.8702
# epoch 43/50 steps 30/100, |train-loss: 0.5255
# epoch 43/50 steps 35/100, |train-loss: 0.5882
# epoch 43/50 steps 40/100, |train-loss: 0.3906
# epoch 43/50 steps 45/100, |train-loss: 0.3940
# epoch 43/50 steps 50/100, |train-loss: 0.0192
# epoch 43/50 steps 55/100, |train-loss: 0.3451
# epoch 43/50 steps 60/100, |train-loss: 0.8150
# epoch 43/50 steps 65/100, |train-loss: 0.1950
# epoch 43/50 steps 70/100, |train-loss: 0.1217
# epoch 43/50 steps 75/100, |train-loss: 0.5410
# epoch 43/50 steps 80/100, |train-loss: 0.3973
# epoch 43/50 steps 85/100, |train-loss: 0.3715
# epoch 43/50 steps 90/100, |train-loss: 0.4145
# epoch 43/50 steps 95/100, |train-loss: 0.3624
# epoch 43/50 steps 100/100, |train-loss: 0.3782 |avg-loss: 0.2929 dur 49.4s |val-acc: 0.4773 |old-best: 0.6136
# epoch 44/50 steps 5/100, |train-loss: 0.0826
# epoch 44/50 steps 10/100, |train-loss: 0.3661
# epoch 44/50 steps 15/100, |train-loss: 0.0436
# epoch 44/50 steps 20/100, |train-loss: 0.0610
# epoch 44/50 steps 25/100, |train-loss: 1.2288
# epoch 44/50 steps 30/100, |train-loss: 0.1050
# epoch 44/50 steps 35/100, |train-loss: 0.4513
# epoch 44/50 steps 40/100, |train-loss: 0.0994
# epoch 44/50 steps 45/100, |train-loss: 0.2509
# epoch 44/50 steps 50/100, |train-loss: 0.1546
# epoch 44/50 steps 55/100, |train-loss: 0.0806
# epoch 44/50 steps 60/100, |train-loss: 0.3541
# epoch 44/50 steps 65/100, |train-loss: 0.2138
# epoch 44/50 steps 70/100, |train-loss: 1.1256
# epoch 44/50 steps 75/100, |train-loss: 0.1240
# epoch 44/50 steps 80/100, |train-loss: 0.1362
# epoch 44/50 steps 85/100, |train-loss: 0.0337
# epoch 44/50 steps 90/100, |train-loss: 0.4067
# epoch 44/50 steps 95/100, |train-loss: 0.1205
# epoch 44/50 steps 100/100, |train-loss: 0.2817 |avg-loss: 0.2923 dur 50.0s |val-acc: 0.5000 |old-best: 0.6136
# epoch 45/50 steps 5/100, |train-loss: 0.0809
# epoch 45/50 steps 10/100, |train-loss: 0.0716
# epoch 45/50 steps 15/100, |train-loss: 0.0392
# epoch 45/50 steps 20/100, |train-loss: 0.0921
# epoch 45/50 steps 25/100, |train-loss: 0.3757
# epoch 45/50 steps 30/100, |train-loss: 0.0316
# epoch 45/50 steps 35/100, |train-loss: 0.0435
# epoch 45/50 steps 40/100, |train-loss: 0.0352
# epoch 45/50 steps 45/100, |train-loss: 0.1431
# epoch 45/50 steps 50/100, |train-loss: 0.4381
# epoch 45/50 steps 55/100, |train-loss: 0.3226
# epoch 45/50 steps 60/100, |train-loss: 0.0230
# epoch 45/50 steps 65/100, |train-loss: 0.3473
# epoch 45/50 steps 70/100, |train-loss: 0.0240
# epoch 45/50 steps 75/100, |train-loss: 0.0359
# epoch 45/50 steps 80/100, |train-loss: 0.3591
# epoch 45/50 steps 85/100, |train-loss: 0.1876
# epoch 45/50 steps 90/100, |train-loss: 0.0411
# epoch 45/50 steps 95/100, |train-loss: 0.3629
# epoch 45/50 steps 100/100, |train-loss: 0.0615 |avg-loss: 0.1988 dur 50.8s |val-acc: 0.4773 |old-best: 0.6136
# epoch 46/50 steps 5/100, |train-loss: 0.0251
# epoch 46/50 steps 10/100, |train-loss: 0.3109
# epoch 46/50 steps 15/100, |train-loss: 0.0418
# epoch 46/50 steps 20/100, |train-loss: 0.3823
# epoch 46/50 steps 25/100, |train-loss: 0.3342
# epoch 46/50 steps 30/100, |train-loss: 0.0351
# epoch 46/50 steps 35/100, |train-loss: 0.3280
# epoch 46/50 steps 40/100, |train-loss: 0.3847
# epoch 46/50 steps 45/100, |train-loss: 0.0401
# epoch 46/50 steps 50/100, |train-loss: 0.0281
# epoch 46/50 steps 55/100, |train-loss: 0.3003
# epoch 46/50 steps 60/100, |train-loss: 0.0154
# epoch 46/50 steps 65/100, |train-loss: 0.2835
# epoch 46/50 steps 70/100, |train-loss: 0.0288
# epoch 46/50 steps 75/100, |train-loss: 0.0328
# epoch 46/50 steps 80/100, |train-loss: 0.0345
# epoch 46/50 steps 85/100, |train-loss: 0.0336
# epoch 46/50 steps 90/100, |train-loss: 0.3072
# epoch 46/50 steps 95/100, |train-loss: 0.2814
# epoch 46/50 steps 100/100, |train-loss: 0.0262 |avg-loss: 0.1807 dur 45.7s |val-acc: 0.4091 |old-best: 0.6136
# epoch 47/50 steps 5/100, |train-loss: 0.3016
# epoch 47/50 steps 10/100, |train-loss: 0.2816
# epoch 47/50 steps 15/100, |train-loss: 0.0181
# epoch 47/50 steps 20/100, |train-loss: 0.0202
# epoch 47/50 steps 25/100, |train-loss: 0.3198
# epoch 47/50 steps 30/100, |train-loss: 0.0402
# epoch 47/50 steps 35/100, |train-loss: 0.2919
# epoch 47/50 steps 40/100, |train-loss: 0.2418
# epoch 47/50 steps 45/100, |train-loss: 0.2857
# epoch 47/50 steps 50/100, |train-loss: 0.2782
# epoch 47/50 steps 55/100, |train-loss: 0.2858
# epoch 47/50 steps 60/100, |train-loss: 0.0145
# epoch 47/50 steps 65/100, |train-loss: 0.2918
# epoch 47/50 steps 70/100, |train-loss: 0.2781
# epoch 47/50 steps 75/100, |train-loss: 0.2566
# epoch 47/50 steps 80/100, |train-loss: 0.3124
# epoch 47/50 steps 85/100, |train-loss: 0.0187
# epoch 47/50 steps 90/100, |train-loss: 0.0095
# epoch 47/50 steps 95/100, |train-loss: 0.0067
# epoch 47/50 steps 100/100, |train-loss: 0.2601 |avg-loss: 0.1465 dur 49.1s |val-acc: 0.4318 |old-best: 0.6136
# epoch 48/50 steps 5/100, |train-loss: 0.2502
# epoch 48/50 steps 10/100, |train-loss: 0.0195
# epoch 48/50 steps 15/100, |train-loss: 0.0154
# epoch 48/50 steps 20/100, |train-loss: 0.2798
# epoch 48/50 steps 25/100, |train-loss: 0.2383
# epoch 48/50 steps 30/100, |train-loss: 0.0125
# epoch 48/50 steps 35/100, |train-loss: 0.2606
# epoch 48/50 steps 40/100, |train-loss: 0.0128
# epoch 48/50 steps 45/100, |train-loss: 0.0211
# epoch 48/50 steps 50/100, |train-loss: 0.3021
# epoch 48/50 steps 55/100, |train-loss: 0.0105
# epoch 48/50 steps 60/100, |train-loss: 0.0133
# epoch 48/50 steps 65/100, |train-loss: 0.0314
# epoch 48/50 steps 70/100, |train-loss: 0.2812
# epoch 48/50 steps 75/100, |train-loss: 0.0102
# epoch 48/50 steps 80/100, |train-loss: 0.3345
# epoch 48/50 steps 85/100, |train-loss: 1.6782
# epoch 48/50 steps 90/100, |train-loss: 0.0628
# epoch 48/50 steps 95/100, |train-loss: 0.2790
# epoch 48/50 steps 100/100, |train-loss: 0.4440 |avg-loss: 0.1551 dur 51.6s |val-acc: 0.4545 |old-best: 0.6136
# epoch 49/50 steps 5/100, |train-loss: 0.0886
# epoch 49/50 steps 10/100, |train-loss: 0.0464
# epoch 49/50 steps 15/100, |train-loss: 0.0444
# epoch 49/50 steps 20/100, |train-loss: 0.2829
# epoch 49/50 steps 25/100, |train-loss: 0.2583
# epoch 49/50 steps 30/100, |train-loss: 0.2422
# epoch 49/50 steps 35/100, |train-loss: 0.2715
# epoch 49/50 steps 40/100, |train-loss: 0.0095
# epoch 49/50 steps 45/100, |train-loss: 0.2276
# epoch 49/50 steps 50/100, |train-loss: 0.2326
# epoch 49/50 steps 55/100, |train-loss: 0.0212
# epoch 49/50 steps 60/100, |train-loss: 0.7835
# epoch 49/50 steps 65/100, |train-loss: 0.2335
# epoch 49/50 steps 70/100, |train-loss: 0.0484
# epoch 49/50 steps 75/100, |train-loss: 0.3363
# epoch 49/50 steps 80/100, |train-loss: 0.2780
# epoch 49/50 steps 85/100, |train-loss: 0.2895
# epoch 49/50 steps 90/100, |train-loss: 0.5403
# epoch 49/50 steps 95/100, |train-loss: 0.2288
# epoch 49/50 steps 100/100, |train-loss: 0.0730 |avg-loss: 0.2087 dur 49.1s |val-acc: 0.5227 |old-best: 0.6136
# epoch 50/50 steps 5/100, |train-loss: 0.2458
# epoch 50/50 steps 10/100, |train-loss: 0.0574
# epoch 50/50 steps 15/100, |train-loss: 0.0287
# epoch 50/50 steps 20/100, |train-loss: 0.2004
# epoch 50/50 steps 25/100, |train-loss: 0.3652
# epoch 50/50 steps 30/100, |train-loss: 0.0198
# epoch 50/50 steps 35/100, |train-loss: 0.2936
# epoch 50/50 steps 40/100, |train-loss: 0.2218
# epoch 50/50 steps 45/100, |train-loss: 0.0207
# epoch 50/50 steps 50/100, |train-loss: 0.2305
# epoch 50/50 steps 55/100, |train-loss: 0.1929
# epoch 50/50 steps 60/100, |train-loss: 0.0210
# epoch 50/50 steps 65/100, |train-loss: 0.0753
# epoch 50/50 steps 70/100, |train-loss: 0.2211
# epoch 50/50 steps 75/100, |train-loss: 0.6041
# epoch 50/50 steps 80/100, |train-loss: 0.0143
# epoch 50/50 steps 85/100, |train-loss: 0.0200
# epoch 50/50 steps 90/100, |train-loss: 0.0190
# epoch 50/50 steps 95/100, |train-loss: 0.0265
# epoch 50/50 steps 100/100, |train-loss: 0.2828 |avg-loss: 0.1717 dur 50.5s |val-acc: 0.5000 |old-best: 0.6136 |50ep model saved
# train completed, best_metric: 0.6136 at epoch: 25 for 50 epoches
# CPU times: user 21min 41s, sys: 10min 38s, total: 32min 20s
# Wall time: 46min 30s

# %%
# !rm -rf pymp-*

# %%
import matplotlib.pyplot as plt

plt.figure("train", (12, 6))
plt.subplot(1, 2, 1)
plt.title("Epoch Average Loss")
x = [i + 1 for i in range(len(epoch_loss_values))]
y = epoch_loss_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.ylim(0,1)
plt.subplot(1, 2, 2)
plt.title("Val Accuracy")
x = [val_interval * (i + 1) for i in range(len(metric_values))]
y = metric_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.ylim(0,1)
plt.show()
