# %%
# !nvidia-smi
# Out:
# Fri May  5 06:13:41 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 520.61.05    Driver Version: 520.61.05    CUDA Version: 11.8     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:B2:00.0 Off |                  Off |
# | N/A   34C    P0    40W / 300W |      0MiB / 32768MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import sys
sys.path.append('/home/fastmri2/.conda/envs/snumvi/lib/python3.8/site-packages')

import os
import glob

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch

from monai.apps import download_and_extract
from monai.config import print_config
from monai.utils import set_determinism

print_config()
set_determinism(0)

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.filterwarnings("ignore", category=UserWarning)
# Out:
# /home/fastmri2/.conda/envs/snumvi/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# MONAI version: 1.1.0
# Numpy version: 1.23.5
# Pytorch version: 1.7.1+cu110
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: a2ec3752f54bfc3b40e7952234fbeb5452ed63e3
# MONAI __file__: /home/fastmri2/.conda/envs/snumvi/lib/python3.8/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.4.8
# Nibabel version: 5.0.0
# scikit-image version: 0.19.3
# Pillow version: 9.4.0
# Tensorboard version: 2.4.0
# gdown version: 4.6.0
# TorchVision version: 0.8.2+cu110
# tqdm version: 4.65.0
# lmdb version: 1.4.0
# psutil version: 5.9.0
# pandas version: 1.5.2
# einops version: 0.6.0
# transformers version: NOT INSTALLED or UNKNOWN VERSION.
# mlflow version: 2.1.1
# pynrrd version: 1.0.0
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %%
directory = "temp"
if not os.path.exists(directory):
    os.makedirs(directory)
root_dir = tempfile.mkdtemp() if directory is None else directory
data_dir = "cropped/HBP/606030"

# %%
#!pip install openpyxl

patient_data = pd.read_excel("patient_data.xlsx", usecols="A,B")

# %%
import random

train_images = sorted(glob.glob(os.path.join(data_dir, "*.nii.gz")))
train_labels = torch.nn.functional.one_hot(torch.as_tensor(patient_data["MVI"])).float()
data_list = list(zip(train_images, train_labels))
random.shuffle(data_list)
data_dicts = [{"image": image, "label": label} for image, label in data_list]
print(len(data_dicts))
print(data_dicts[0])
# Out:
# 244
# {'image': 'cropped/HBP/606030/0020491.nii.gz', 'label': tensor([0., 1.])}

# %%
train_files, val_files = data_dicts[:200], data_dicts[200:]
target_layer=8
set_determinism(seed=0)

# %%
def nii_loader(filename) :
    import nibabel as nib
    import numpy as np
    import matplotlib.pyplot as plt
    nimg = nib.load( filename )
    return nimg.get_fdata() , nimg.affine, nimg.header 

def visualize(dataset, idx=0, target_layer=10):
    import matplotlib.pyplot as plt    

    image = dataset[idx]['image']
    label = dataset[idx]['label']
    image_data, image_affine, image_header = nii_loader(image)
    
    print('[file path]', image)
    print('[dimension]', image_data.shape)
    print('[label]', label)
    target_image = image_data[:,:,target_layer]

    plt.imshow(target_image, cmap='gray' )
    plt.show()
    return tuple(image_data.shape)

# %%
spatial_size = visualize( val_files, idx=1,  target_layer=target_layer)
# Out:
# [file path] cropped/HBP/606030/0099705.nii.gz
# [dimension] (60, 60, 30)
# [label] tensor([0., 1.])

# %%
from monai.transforms import (
    Compose,
    LoadImaged,
    EnsureChannelFirstd,
    AddChanneld,
    Orientationd,
    ScaleIntensityRanged,
    CropForegroundd,
    RandAffined,
    SpatialPadd,
    EnsureTyped,
)

# %%
# ScaleIntensityRanged min/max differ by organs
# for liver, min = 30 + 150/2 = 105, max = 30 - 150/2 = -45
# see more info here https://radiopaedia.org/articles/windowing-ct

from monai.transforms import Compose

train_transforms = Compose(
    [
        LoadImaged(keys=["image"]),
        EnsureChannelFirstd(keys=["image"]),
        #AddChanneld(keys=["label"]),
        Orientationd(keys=["image"], axcodes="RAS"),
        ScaleIntensityRanged(
            keys=["image"], a_min=-45, a_max=105,
            b_min=0.0, b_max=1.0, clip=True,
        ),
        CropForegroundd(keys=["image"], source_key="image"),
        RandAffined(
            keys=["image"],
            mode=("bilinear"),
            prob=1.0, spatial_size=spatial_size,
            rotate_range=(0, 0, 0),
            scale_range=(0, 0, 0)),
        SpatialPadd(keys=["image"], spatial_size=spatial_size),
        EnsureTyped(keys=["image"]),
    ]
)
val_transforms = Compose(
    [
        LoadImaged(keys=["image"]),
        EnsureChannelFirstd(keys=["image"]),
        #AddChanneld(keys=["label"]),
        Orientationd(keys=["image"], axcodes="RAS"),
        ScaleIntensityRanged(
            keys=["image"], a_min=-45, a_max=105,
            b_min=0.0, b_max=1.0, clip=True,
        ),
        CropForegroundd(keys=["image"], source_key="image"),
        SpatialPadd(keys=["image"], spatial_size=spatial_size),
        EnsureTyped(keys=["image"]),
    ]
)

# %%
from monai.data import CacheDataset, DataLoader, Dataset
from monai.utils import first, set_determinism

check_ds = Dataset(data=train_files, transform=train_transforms)
check_loader = DataLoader(check_ds, batch_size=1)
check_data = first(check_loader)
image, label = (check_data["image"][0][0], check_data["label"][0][0])
print(f"image shape: {image.shape}, label shape: {label.shape}")

plt.imshow(image[:, :, spatial_size[2]//2], cmap="gray")
plt.show()
# Out:
# image shape: torch.Size([60, 60, 30]), label shape: torch.Size([])

# %%
from monai.data import CacheDataset, DataLoader

train_ds = CacheDataset(data=train_files, transform=train_transforms, cache_rate=1.0, num_workers=4, progress=True)
train_loader = DataLoader(train_ds, batch_size=2, shuffle=True, num_workers=10)

val_ds = CacheDataset(data=val_files, transform=val_transforms, cache_rate=1.0, num_workers=4, progress=True)
val_loader = DataLoader(val_ds, batch_size=1, num_workers=10)
# Out:
# Loading dataset: 100%|██████████| 200/200 [00:02<00:00, 79.59it/s]
# Loading dataset: 100%|██████████| 44/44 [00:00<00:00, 74.86it/s]

# %%
from monai.networks.nets import DenseNet121

device = torch.device("cuda:0")
model = DenseNet121(
    spatial_dims=3,
    in_channels=1,
    out_channels=2
).to(device)

# %%
loss_function = torch.nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), 1e-4)
max_epochs = 50
val_interval = 1
save_interval = 10
best_score = -1
best_score_epoch = -1
epoch_loss_values = []
metric_values = []
model_name = 'Densenet'

# %%
# %%time

import time

for epoch in range(max_epochs):
    tic_epoch = time.time()
    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step += 1
        inputs, labels = batch_data["image"].to(device), batch_data["label"].to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        if step % 5 ==0:
            print(f"\nepoch {epoch + 1}/{max_epochs} steps {step}/{len(train_ds) // train_loader.batch_size}, |train-loss: {loss.item():.4f}", end='')
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    toc_epoch = time.time()
    dur_epoch = toc_epoch - tic_epoch
    print(f" |avg-loss: {epoch_loss:.4f} dur {dur_epoch:.1f}s ", end='')

    if (epoch + 1) % val_interval == 0:
        model.eval()
        val_count = 0
        val_correct = 0.0
        
        with torch.no_grad():
            for val_data in val_loader:
                inputs, labels = (
                    val_data["image"].to(device),
                    val_data["label"].to(device),
                )
                outputs = model(inputs)
                val_result = torch.eq(outputs.argmax(dim=1), labels.argmax(dim=1))
                val_count += len(val_result)
                val_correct += val_result.sum().item()
            
            val_score = val_correct / val_count
            metric_values.append(val_score)
            print(f"|val-acc: {val_score:.4f} |old-best: {best_score:.4f} " , end="")
            
            if val_score > best_score:
                best_score = val_score
                best_score_epoch = epoch + 1
                torch.save(model.state_dict(), os.path.join(root_dir, "{}_model_best.pth".format(model_name)))
                torch.save(optimizer.state_dict(), os.path.join(root_dir, "{}_optim_best.pth".format(model_name)))
                print("|best model saved", end="")
    
    if (epoch+1) % save_interval == 0:
        torch.save(model.state_dict(), os.path.join(root_dir, "{}_model_{:04d}.pth".format(model_name, epoch+1)))
        torch.save(optimizer.state_dict(), os.path.join(root_dir, "{}_optim_{:04d}.pth".format(model_name, epoch+1)))
        print("|{}ep model saved".format(epoch+1), end='')
                            
print(f"\ntrain completed, best_metric: {best_score:.4f} at epoch: {best_score_epoch} for {max_epochs} epoches")
# Out:
# epoch 1/50 steps 5/100, |train-loss: 0.6696
# epoch 1/50 steps 10/100, |train-loss: 0.5752
# epoch 1/50 steps 15/100, |train-loss: 0.6015
# epoch 1/50 steps 20/100, |train-loss: 0.6932
# epoch 1/50 steps 25/100, |train-loss: 0.8007
# epoch 1/50 steps 30/100, |train-loss: 0.7238
# epoch 1/50 steps 35/100, |train-loss: 0.9282
# epoch 1/50 steps 40/100, |train-loss: 0.7967
# epoch 1/50 steps 45/100, |train-loss: 0.7688
# epoch 1/50 steps 50/100, |train-loss: 0.7202
# epoch 1/50 steps 55/100, |train-loss: 0.6378
# epoch 1/50 steps 60/100, |train-loss: 0.7322
# epoch 1/50 steps 65/100, |train-loss: 0.7849
# epoch 1/50 steps 70/100, |train-loss: 0.6346
# epoch 1/50 steps 75/100, |train-loss: 0.5991
# epoch 1/50 steps 80/100, |train-loss: 0.7337
# epoch 1/50 steps 85/100, |train-loss: 0.7097
# epoch 1/50 steps 90/100, |train-loss: 0.7465
# epoch 1/50 steps 95/100, |train-loss: 0.9331
# epoch 1/50 steps 100/100, |train-loss: 0.6696 |avg-loss: 0.7210 dur 16.2s |val-acc: 0.5682 |old-best: -1.0000 |best model saved
# epoch 2/50 steps 5/100, |train-loss: 0.6611
# epoch 2/50 steps 10/100, |train-loss: 0.6815
# epoch 2/50 steps 15/100, |train-loss: 0.6382
# epoch 2/50 steps 20/100, |train-loss: 0.7640
# epoch 2/50 steps 25/100, |train-loss: 0.7513
# epoch 2/50 steps 30/100, |train-loss: 0.6972
# epoch 2/50 steps 35/100, |train-loss: 0.6993
# epoch 2/50 steps 40/100, |train-loss: 0.5393
# epoch 2/50 steps 45/100, |train-loss: 0.7020
# epoch 2/50 steps 50/100, |train-loss: 0.7105
# epoch 2/50 steps 55/100, |train-loss: 0.7626
# epoch 2/50 steps 60/100, |train-loss: 0.7350
# epoch 2/50 steps 65/100, |train-loss: 0.6594
# epoch 2/50 steps 70/100, |train-loss: 0.6450
# epoch 2/50 steps 75/100, |train-loss: 0.6443
# epoch 2/50 steps 80/100, |train-loss: 0.7262
# epoch 2/50 steps 85/100, |train-loss: 0.7667
# epoch 2/50 steps 90/100, |train-loss: 0.6756
# epoch 2/50 steps 95/100, |train-loss: 0.7898
# epoch 2/50 steps 100/100, |train-loss: 0.7334 |avg-loss: 0.7104 dur 16.1s |val-acc: 0.5000 |old-best: 0.5682
# epoch 3/50 steps 5/100, |train-loss: 0.7122
# epoch 3/50 steps 10/100, |train-loss: 0.6474
# epoch 3/50 steps 15/100, |train-loss: 0.7432
# epoch 3/50 steps 20/100, |train-loss: 0.8044
# epoch 3/50 steps 25/100, |train-loss: 0.7384
# epoch 3/50 steps 30/100, |train-loss: 0.7535
# epoch 3/50 steps 35/100, |train-loss: 0.5664
# epoch 3/50 steps 40/100, |train-loss: 0.6139
# epoch 3/50 steps 45/100, |train-loss: 0.6623
# epoch 3/50 steps 50/100, |train-loss: 0.6565
# epoch 3/50 steps 55/100, |train-loss: 0.6374
# epoch 3/50 steps 60/100, |train-loss: 0.7443
# epoch 3/50 steps 65/100, |train-loss: 0.7186
# epoch 3/50 steps 70/100, |train-loss: 0.8204
# epoch 3/50 steps 75/100, |train-loss: 0.6762
# epoch 3/50 steps 80/100, |train-loss: 0.7912
# epoch 3/50 steps 85/100, |train-loss: 0.6672
# epoch 3/50 steps 90/100, |train-loss: 0.7431
# epoch 3/50 steps 95/100, |train-loss: 0.6923
# epoch 3/50 steps 100/100, |train-loss: 0.7098 |avg-loss: 0.6993 dur 16.1s |val-acc: 0.4773 |old-best: 0.5682
# epoch 4/50 steps 5/100, |train-loss: 0.7476
# epoch 4/50 steps 10/100, |train-loss: 0.8374
# epoch 4/50 steps 15/100, |train-loss: 0.6325
# epoch 4/50 steps 20/100, |train-loss: 0.7313
# epoch 4/50 steps 25/100, |train-loss: 0.5978
# epoch 4/50 steps 30/100, |train-loss: 0.5952
# epoch 4/50 steps 35/100, |train-loss: 0.7338
# epoch 4/50 steps 40/100, |train-loss: 0.6876
# epoch 4/50 steps 45/100, |train-loss: 0.7372
# epoch 4/50 steps 50/100, |train-loss: 0.6084
# epoch 4/50 steps 55/100, |train-loss: 0.6870
# epoch 4/50 steps 60/100, |train-loss: 0.7010
# epoch 4/50 steps 65/100, |train-loss: 0.5824
# epoch 4/50 steps 70/100, |train-loss: 0.7764
# epoch 4/50 steps 75/100, |train-loss: 0.5553
# epoch 4/50 steps 80/100, |train-loss: 0.7615
# epoch 4/50 steps 85/100, |train-loss: 0.7494
# epoch 4/50 steps 90/100, |train-loss: 0.6757
# epoch 4/50 steps 95/100, |train-loss: 0.7121
# epoch 4/50 steps 100/100, |train-loss: 0.6995 |avg-loss: 0.6958 dur 16.1s |val-acc: 0.5227 |old-best: 0.5682
# epoch 5/50 steps 5/100, |train-loss: 0.8000
# epoch 5/50 steps 10/100, |train-loss: 0.6699
# epoch 5/50 steps 15/100, |train-loss: 0.7430
# epoch 5/50 steps 20/100, |train-loss: 0.7336
# epoch 5/50 steps 25/100, |train-loss: 0.7166
# epoch 5/50 steps 30/100, |train-loss: 0.7647
# epoch 5/50 steps 35/100, |train-loss: 0.6649
# epoch 5/50 steps 40/100, |train-loss: 0.6800
# epoch 5/50 steps 45/100, |train-loss: 0.7087
# epoch 5/50 steps 50/100, |train-loss: 0.6316
# epoch 5/50 steps 55/100, |train-loss: 0.6788
# epoch 5/50 steps 60/100, |train-loss: 0.6612
# epoch 5/50 steps 65/100, |train-loss: 0.7323
# epoch 5/50 steps 70/100, |train-loss: 0.7285
# epoch 5/50 steps 75/100, |train-loss: 0.7227
# epoch 5/50 steps 80/100, |train-loss: 0.6636
# epoch 5/50 steps 85/100, |train-loss: 0.6574
# epoch 5/50 steps 90/100, |train-loss: 0.5982
# epoch 5/50 steps 95/100, |train-loss: 0.5801
# epoch 5/50 steps 100/100, |train-loss: 0.7570 |avg-loss: 0.7060 dur 16.0s |val-acc: 0.5227 |old-best: 0.5682
# epoch 6/50 steps 5/100, |train-loss: 0.6922
# epoch 6/50 steps 10/100, |train-loss: 0.6029
# epoch 6/50 steps 15/100, |train-loss: 0.6908
# epoch 6/50 steps 20/100, |train-loss: 0.7128
# epoch 6/50 steps 25/100, |train-loss: 0.7869
# epoch 6/50 steps 30/100, |train-loss: 0.6860
# epoch 6/50 steps 35/100, |train-loss: 0.7066
# epoch 6/50 steps 40/100, |train-loss: 0.7265
# epoch 6/50 steps 45/100, |train-loss: 0.5567
# epoch 6/50 steps 50/100, |train-loss: 0.7166
# epoch 6/50 steps 55/100, |train-loss: 0.5426
# epoch 6/50 steps 60/100, |train-loss: 0.7956
# epoch 6/50 steps 65/100, |train-loss: 0.7053
# epoch 6/50 steps 70/100, |train-loss: 0.6198
# epoch 6/50 steps 75/100, |train-loss: 0.7273
# epoch 6/50 steps 80/100, |train-loss: 0.5877
# epoch 6/50 steps 85/100, |train-loss: 0.5701
# epoch 6/50 steps 90/100, |train-loss: 0.5414
# epoch 6/50 steps 95/100, |train-loss: 0.7010
# epoch 6/50 steps 100/100, |train-loss: 0.8309 |avg-loss: 0.6957 dur 16.3s |val-acc: 0.5455 |old-best: 0.5682
# epoch 7/50 steps 5/100, |train-loss: 0.6546
# epoch 7/50 steps 10/100, |train-loss: 0.7550
# epoch 7/50 steps 15/100, |train-loss: 0.6678
# epoch 7/50 steps 20/100, |train-loss: 0.7794
# epoch 7/50 steps 25/100, |train-loss: 0.7940
# epoch 7/50 steps 30/100, |train-loss: 0.7067
# epoch 7/50 steps 35/100, |train-loss: 0.6921
# epoch 7/50 steps 40/100, |train-loss: 0.6856
# epoch 7/50 steps 45/100, |train-loss: 0.7371
# epoch 7/50 steps 50/100, |train-loss: 0.6764
# epoch 7/50 steps 55/100, |train-loss: 0.6530
# epoch 7/50 steps 60/100, |train-loss: 0.7665
# epoch 7/50 steps 65/100, |train-loss: 0.8184
# epoch 7/50 steps 70/100, |train-loss: 0.7061
# epoch 7/50 steps 75/100, |train-loss: 0.6825
# epoch 7/50 steps 80/100, |train-loss: 0.8360
# epoch 7/50 steps 85/100, |train-loss: 0.5391
# epoch 7/50 steps 90/100, |train-loss: 0.7097
# epoch 7/50 steps 95/100, |train-loss: 0.7799
# epoch 7/50 steps 100/100, |train-loss: 0.6405 |avg-loss: 0.7123 dur 16.1s |val-acc: 0.5000 |old-best: 0.5682
# epoch 8/50 steps 5/100, |train-loss: 0.8349
# epoch 8/50 steps 10/100, |train-loss: 0.7054
# epoch 8/50 steps 15/100, |train-loss: 0.5641
# epoch 8/50 steps 20/100, |train-loss: 0.8184
# epoch 8/50 steps 25/100, |train-loss: 0.7228
# epoch 8/50 steps 30/100, |train-loss: 0.6830
# epoch 8/50 steps 35/100, |train-loss: 0.7327
# epoch 8/50 steps 40/100, |train-loss: 0.6846
# epoch 8/50 steps 45/100, |train-loss: 0.7208
# epoch 8/50 steps 50/100, |train-loss: 0.7254
# epoch 8/50 steps 55/100, |train-loss: 0.7479
# epoch 8/50 steps 60/100, |train-loss: 0.7294
# epoch 8/50 steps 65/100, |train-loss: 0.7215
# epoch 8/50 steps 70/100, |train-loss: 0.6381
# epoch 8/50 steps 75/100, |train-loss: 0.8000
# epoch 8/50 steps 80/100, |train-loss: 0.6351
# epoch 8/50 steps 85/100, |train-loss: 0.6228
# epoch 8/50 steps 90/100, |train-loss: 0.8476
# epoch 8/50 steps 95/100, |train-loss: 0.6559
# epoch 8/50 steps 100/100, |train-loss: 0.7423 |avg-loss: 0.7125 dur 16.0s |val-acc: 0.3864 |old-best: 0.5682
# epoch 9/50 steps 5/100, |train-loss: 0.7048
# epoch 9/50 steps 10/100, |train-loss: 0.8619
# epoch 9/50 steps 15/100, |train-loss: 0.6240
# epoch 9/50 steps 20/100, |train-loss: 0.6901
# epoch 9/50 steps 25/100, |train-loss: 0.7262
# epoch 9/50 steps 30/100, |train-loss: 0.8023
# epoch 9/50 steps 35/100, |train-loss: 0.7216
# epoch 9/50 steps 40/100, |train-loss: 0.5610
# epoch 9/50 steps 45/100, |train-loss: 0.8401
# epoch 9/50 steps 50/100, |train-loss: 0.5168
# epoch 9/50 steps 55/100, |train-loss: 0.5904
# epoch 9/50 steps 60/100, |train-loss: 0.6049
# epoch 9/50 steps 65/100, |train-loss: 0.6908
# epoch 9/50 steps 70/100, |train-loss: 0.7380
# epoch 9/50 steps 75/100, |train-loss: 0.6996
# epoch 9/50 steps 80/100, |train-loss: 0.7822
# epoch 9/50 steps 85/100, |train-loss: 0.5714
# epoch 9/50 steps 90/100, |train-loss: 0.8032
# epoch 9/50 steps 95/100, |train-loss: 0.6932
# epoch 9/50 steps 100/100, |train-loss: 0.6148 |avg-loss: 0.7027 dur 16.0s |val-acc: 0.4545 |old-best: 0.5682
# epoch 10/50 steps 5/100, |train-loss: 0.6012
# epoch 10/50 steps 10/100, |train-loss: 0.7479
# epoch 10/50 steps 15/100, |train-loss: 0.8633
# epoch 10/50 steps 20/100, |train-loss: 0.8435
# epoch 10/50 steps 25/100, |train-loss: 0.8148
# epoch 10/50 steps 30/100, |train-loss: 0.4835
# epoch 10/50 steps 35/100, |train-loss: 0.7186
# epoch 10/50 steps 40/100, |train-loss: 0.9214
# epoch 10/50 steps 45/100, |train-loss: 0.6190
# epoch 10/50 steps 50/100, |train-loss: 0.9208
# epoch 10/50 steps 55/100, |train-loss: 0.6982
# epoch 10/50 steps 60/100, |train-loss: 0.7674
# epoch 10/50 steps 65/100, |train-loss: 0.6579
# epoch 10/50 steps 70/100, |train-loss: 0.6796
# epoch 10/50 steps 75/100, |train-loss: 0.8833
# epoch 10/50 steps 80/100, |train-loss: 0.6729
# epoch 10/50 steps 85/100, |train-loss: 0.8439
# epoch 10/50 steps 90/100, |train-loss: 0.5057
# epoch 10/50 steps 95/100, |train-loss: 0.7601
# epoch 10/50 steps 100/100, |train-loss: 0.7385 |avg-loss: 0.7069 dur 16.1s |val-acc: 0.3182 |old-best: 0.5682 |10ep model saved
# epoch 11/50 steps 5/100, |train-loss: 0.6673
# epoch 11/50 steps 10/100, |train-loss: 0.6754
# epoch 11/50 steps 15/100, |train-loss: 0.7967
# epoch 11/50 steps 20/100, |train-loss: 0.5873
# epoch 11/50 steps 25/100, |train-loss: 0.5492
# epoch 11/50 steps 30/100, |train-loss: 0.8161
# epoch 11/50 steps 35/100, |train-loss: 0.7238
# epoch 11/50 steps 40/100, |train-loss: 0.8135
# epoch 11/50 steps 45/100, |train-loss: 0.7899
# epoch 11/50 steps 50/100, |train-loss: 0.7035
# epoch 11/50 steps 55/100, |train-loss: 0.6541
# epoch 11/50 steps 60/100, |train-loss: 0.7875
# epoch 11/50 steps 65/100, |train-loss: 0.7171
# epoch 11/50 steps 70/100, |train-loss: 0.6127
# epoch 11/50 steps 75/100, |train-loss: 0.8220
# epoch 11/50 steps 80/100, |train-loss: 0.6415
# epoch 11/50 steps 85/100, |train-loss: 0.5727
# epoch 11/50 steps 90/100, |train-loss: 0.6319
# epoch 11/50 steps 95/100, |train-loss: 0.7559
# epoch 11/50 steps 100/100, |train-loss: 0.6386 |avg-loss: 0.6944 dur 15.9s |val-acc: 0.4091 |old-best: 0.5682
# epoch 12/50 steps 5/100, |train-loss: 0.7439
# epoch 12/50 steps 10/100, |train-loss: 0.5017
# epoch 12/50 steps 15/100, |train-loss: 0.6064
# epoch 12/50 steps 20/100, |train-loss: 0.8214
# epoch 12/50 steps 25/100, |train-loss: 0.6366
# epoch 12/50 steps 30/100, |train-loss: 0.7588
# epoch 12/50 steps 35/100, |train-loss: 0.7292
# epoch 12/50 steps 40/100, |train-loss: 0.6427
# epoch 12/50 steps 45/100, |train-loss: 0.7022
# epoch 12/50 steps 50/100, |train-loss: 0.5916
# epoch 12/50 steps 55/100, |train-loss: 0.5497
# epoch 12/50 steps 60/100, |train-loss: 0.6911
# epoch 12/50 steps 65/100, |train-loss: 0.6931
# epoch 12/50 steps 70/100, |train-loss: 0.7343
# epoch 12/50 steps 75/100, |train-loss: 0.7613
# epoch 12/50 steps 80/100, |train-loss: 0.7461
# epoch 12/50 steps 85/100, |train-loss: 0.7080
# epoch 12/50 steps 90/100, |train-loss: 0.7582
# epoch 12/50 steps 95/100, |train-loss: 0.7233
# epoch 12/50 steps 100/100, |train-loss: 0.7244 |avg-loss: 0.6957 dur 15.8s |val-acc: 0.5227 |old-best: 0.5682
# epoch 13/50 steps 5/100, |train-loss: 0.7339
# epoch 13/50 steps 10/100, |train-loss: 0.5509
# epoch 13/50 steps 15/100, |train-loss: 0.7364
# epoch 13/50 steps 20/100, |train-loss: 0.7545
# epoch 13/50 steps 25/100, |train-loss: 0.7751
# epoch 13/50 steps 30/100, |train-loss: 0.6133
# epoch 13/50 steps 35/100, |train-loss: 0.6316
# epoch 13/50 steps 40/100, |train-loss: 0.5795
# epoch 13/50 steps 45/100, |train-loss: 0.5702
# epoch 13/50 steps 50/100, |train-loss: 0.7524
# epoch 13/50 steps 55/100, |train-loss: 0.6771
# epoch 13/50 steps 60/100, |train-loss: 0.7075
# epoch 13/50 steps 65/100, |train-loss: 0.5491
# epoch 13/50 steps 70/100, |train-loss: 0.6096
# epoch 13/50 steps 75/100, |train-loss: 0.7041
# epoch 13/50 steps 80/100, |train-loss: 1.0157
# epoch 13/50 steps 85/100, |train-loss: 0.7559
# epoch 13/50 steps 90/100, |train-loss: 0.7204
# epoch 13/50 steps 95/100, |train-loss: 0.7250
# epoch 13/50 steps 100/100, |train-loss: 0.4990 |avg-loss: 0.6925 dur 15.9s |val-acc: 0.4773 |old-best: 0.5682
# epoch 14/50 steps 5/100, |train-loss: 0.6969
# epoch 14/50 steps 10/100, |train-loss: 0.8289
# epoch 14/50 steps 15/100, |train-loss: 0.8512
# epoch 14/50 steps 20/100, |train-loss: 0.9014
# epoch 14/50 steps 25/100, |train-loss: 0.5240
# epoch 14/50 steps 30/100, |train-loss: 0.7006
# epoch 14/50 steps 35/100, |train-loss: 0.5211
# epoch 14/50 steps 40/100, |train-loss: 0.5750
# epoch 14/50 steps 45/100, |train-loss: 0.7381
# epoch 14/50 steps 50/100, |train-loss: 0.8412
# epoch 14/50 steps 55/100, |train-loss: 0.5781
# epoch 14/50 steps 60/100, |train-loss: 0.5873
# epoch 14/50 steps 65/100, |train-loss: 0.6354
# epoch 14/50 steps 70/100, |train-loss: 0.7237
# epoch 14/50 steps 75/100, |train-loss: 0.7015
# epoch 14/50 steps 80/100, |train-loss: 0.7169
# epoch 14/50 steps 85/100, |train-loss: 0.8435
# epoch 14/50 steps 90/100, |train-loss: 0.6054
# epoch 14/50 steps 95/100, |train-loss: 0.5714
# epoch 14/50 steps 100/100, |train-loss: 0.6506 |avg-loss: 0.7090 dur 15.9s |val-acc: 0.4773 |old-best: 0.5682
# epoch 15/50 steps 5/100, |train-loss: 0.5928
# epoch 15/50 steps 10/100, |train-loss: 0.6216
# epoch 15/50 steps 15/100, |train-loss: 0.8437
# epoch 15/50 steps 20/100, |train-loss: 0.5114
# epoch 15/50 steps 25/100, |train-loss: 0.6665
# epoch 15/50 steps 30/100, |train-loss: 0.7054
# epoch 15/50 steps 35/100, |train-loss: 0.8209
# epoch 15/50 steps 40/100, |train-loss: 0.7244
# epoch 15/50 steps 45/100, |train-loss: 0.8003
# epoch 15/50 steps 50/100, |train-loss: 0.6476
# epoch 15/50 steps 55/100, |train-loss: 0.6929
# epoch 15/50 steps 60/100, |train-loss: 0.5720
# epoch 15/50 steps 65/100, |train-loss: 0.8439
# epoch 15/50 steps 70/100, |train-loss: 0.8593
# epoch 15/50 steps 75/100, |train-loss: 0.8144
# epoch 15/50 steps 80/100, |train-loss: 0.6507
# epoch 15/50 steps 85/100, |train-loss: 0.6684
# epoch 15/50 steps 90/100, |train-loss: 0.6582
# epoch 15/50 steps 95/100, |train-loss: 0.7830
# epoch 15/50 steps 100/100, |train-loss: 0.7100 |avg-loss: 0.6988 dur 16.2s |val-acc: 0.5227 |old-best: 0.5682
# epoch 16/50 steps 5/100, |train-loss: 0.7608
# epoch 16/50 steps 10/100, |train-loss: 0.7768
# epoch 16/50 steps 15/100, |train-loss: 0.7749
# epoch 16/50 steps 20/100, |train-loss: 0.6909
# epoch 16/50 steps 25/100, |train-loss: 0.7286
# epoch 16/50 steps 30/100, |train-loss: 0.7342
# epoch 16/50 steps 35/100, |train-loss: 0.6645
# epoch 16/50 steps 40/100, |train-loss: 0.6692
# epoch 16/50 steps 45/100, |train-loss: 0.7086
# epoch 16/50 steps 50/100, |train-loss: 0.6599
# epoch 16/50 steps 55/100, |train-loss: 0.7121
# epoch 16/50 steps 60/100, |train-loss: 0.5319
# epoch 16/50 steps 65/100, |train-loss: 0.6343
# epoch 16/50 steps 70/100, |train-loss: 0.6422
# epoch 16/50 steps 75/100, |train-loss: 0.6042
# epoch 16/50 steps 80/100, |train-loss: 0.5869
# epoch 16/50 steps 85/100, |train-loss: 0.7868
# epoch 16/50 steps 90/100, |train-loss: 0.7983
# epoch 16/50 steps 95/100, |train-loss: 0.6539
# epoch 16/50 steps 100/100, |train-loss: 0.6791 |avg-loss: 0.7072 dur 19.6s |val-acc: 0.5909 |old-best: 0.5682 |best model saved
# epoch 17/50 steps 5/100, |train-loss: 0.6787
# epoch 17/50 steps 10/100, |train-loss: 0.7131
# epoch 17/50 steps 15/100, |train-loss: 0.7098
# epoch 17/50 steps 20/100, |train-loss: 0.7288
# epoch 17/50 steps 25/100, |train-loss: 0.6394
# epoch 17/50 steps 30/100, |train-loss: 0.7509
# epoch 17/50 steps 35/100, |train-loss: 0.6483
# epoch 17/50 steps 40/100, |train-loss: 0.6457
# epoch 17/50 steps 45/100, |train-loss: 0.7713
# epoch 17/50 steps 50/100, |train-loss: 0.6932
# epoch 17/50 steps 55/100, |train-loss: 0.6974
# epoch 17/50 steps 60/100, |train-loss: 0.6440
# epoch 17/50 steps 65/100, |train-loss: 0.6911
# epoch 17/50 steps 70/100, |train-loss: 0.7385
# epoch 17/50 steps 75/100, |train-loss: 0.6812
# epoch 17/50 steps 80/100, |train-loss: 0.8193
# epoch 17/50 steps 85/100, |train-loss: 0.5525
# epoch 17/50 steps 90/100, |train-loss: 0.5850
# epoch 17/50 steps 95/100, |train-loss: 0.6205
# epoch 17/50 steps 100/100, |train-loss: 0.8194 |avg-loss: 0.7052 dur 15.9s |val-acc: 0.4545 |old-best: 0.5909
# epoch 18/50 steps 5/100, |train-loss: 0.6296
# epoch 18/50 steps 10/100, |train-loss: 0.7085
# epoch 18/50 steps 15/100, |train-loss: 0.7628
# epoch 18/50 steps 20/100, |train-loss: 0.6073
# epoch 18/50 steps 25/100, |train-loss: 0.6116
# epoch 18/50 steps 30/100, |train-loss: 0.5071
# epoch 18/50 steps 35/100, |train-loss: 0.7076
# epoch 18/50 steps 40/100, |train-loss: 0.6639
# epoch 18/50 steps 45/100, |train-loss: 0.7121
# epoch 18/50 steps 50/100, |train-loss: 0.6683
# epoch 18/50 steps 55/100, |train-loss: 0.6761
# epoch 18/50 steps 60/100, |train-loss: 0.6650
# epoch 18/50 steps 65/100, |train-loss: 0.6525
# epoch 18/50 steps 70/100, |train-loss: 0.6741
# epoch 18/50 steps 75/100, |train-loss: 0.6676
# epoch 18/50 steps 80/100, |train-loss: 0.6584
# epoch 18/50 steps 85/100, |train-loss: 0.7537
# epoch 18/50 steps 90/100, |train-loss: 0.6325
# epoch 18/50 steps 95/100, |train-loss: 0.7314
# epoch 18/50 steps 100/100, |train-loss: 0.6772 |avg-loss: 0.6932 dur 15.9s |val-acc: 0.5000 |old-best: 0.5909
# epoch 19/50 steps 5/100, |train-loss: 0.7774
# epoch 19/50 steps 10/100, |train-loss: 0.7396
# epoch 19/50 steps 15/100, |train-loss: 0.7242
# epoch 19/50 steps 20/100, |train-loss: 0.6063
# epoch 19/50 steps 25/100, |train-loss: 0.6005
# epoch 19/50 steps 30/100, |train-loss: 0.6960
# epoch 19/50 steps 35/100, |train-loss: 0.8692
# epoch 19/50 steps 40/100, |train-loss: 0.8852
# epoch 19/50 steps 45/100, |train-loss: 0.7727
# epoch 19/50 steps 50/100, |train-loss: 0.6706
# epoch 19/50 steps 55/100, |train-loss: 0.6717
# epoch 19/50 steps 60/100, |train-loss: 0.7232
# epoch 19/50 steps 65/100, |train-loss: 0.7360
# epoch 19/50 steps 70/100, |train-loss: 0.6748
# epoch 19/50 steps 75/100, |train-loss: 0.7037
# epoch 19/50 steps 80/100, |train-loss: 0.9603
# epoch 19/50 steps 85/100, |train-loss: 0.7390
# epoch 19/50 steps 90/100, |train-loss: 0.6471
# epoch 19/50 steps 95/100, |train-loss: 0.6919
# epoch 19/50 steps 100/100, |train-loss: 0.7257 |avg-loss: 0.7042 dur 16.0s |val-acc: 0.5227 |old-best: 0.5909
# epoch 20/50 steps 5/100, |train-loss: 0.6840
# epoch 20/50 steps 10/100, |train-loss: 0.7279
# epoch 20/50 steps 15/100, |train-loss: 0.6315
# epoch 20/50 steps 20/100, |train-loss: 0.6872
# epoch 20/50 steps 25/100, |train-loss: 0.6006
# epoch 20/50 steps 30/100, |train-loss: 0.8383
# epoch 20/50 steps 35/100, |train-loss: 0.6973
# epoch 20/50 steps 40/100, |train-loss: 0.6889
# epoch 20/50 steps 45/100, |train-loss: 0.6637
# epoch 20/50 steps 50/100, |train-loss: 0.7148
# epoch 20/50 steps 55/100, |train-loss: 0.7438
# epoch 20/50 steps 60/100, |train-loss: 0.8399
# epoch 20/50 steps 65/100, |train-loss: 0.7720
# epoch 20/50 steps 70/100, |train-loss: 0.6785
# epoch 20/50 steps 75/100, |train-loss: 0.7306
# epoch 20/50 steps 80/100, |train-loss: 0.7141
# epoch 20/50 steps 85/100, |train-loss: 0.6264
# epoch 20/50 steps 90/100, |train-loss: 0.6903
# epoch 20/50 steps 95/100, |train-loss: 0.6065
# epoch 20/50 steps 100/100, |train-loss: 0.7888 |avg-loss: 0.7021 dur 16.2s |val-acc: 0.4773 |old-best: 0.5909 |20ep model saved
# epoch 21/50 steps 5/100, |train-loss: 0.6511
# epoch 21/50 steps 10/100, |train-loss: 0.7475
# epoch 21/50 steps 15/100, |train-loss: 0.7468
# epoch 21/50 steps 20/100, |train-loss: 0.7539
# epoch 21/50 steps 25/100, |train-loss: 0.7296
# epoch 21/50 steps 30/100, |train-loss: 0.5172
# epoch 21/50 steps 35/100, |train-loss: 0.7116
# epoch 21/50 steps 40/100, |train-loss: 0.8827
# epoch 21/50 steps 45/100, |train-loss: 0.6488
# epoch 21/50 steps 50/100, |train-loss: 0.7313
# epoch 21/50 steps 55/100, |train-loss: 0.7101
# epoch 21/50 steps 60/100, |train-loss: 0.7224
# epoch 21/50 steps 65/100, |train-loss: 0.7156
# epoch 21/50 steps 70/100, |train-loss: 0.6967
# epoch 21/50 steps 75/100, |train-loss: 0.7414
# epoch 21/50 steps 80/100, |train-loss: 0.6269
# epoch 21/50 steps 85/100, |train-loss: 0.7261
# epoch 21/50 steps 90/100, |train-loss: 0.5747
# epoch 21/50 steps 95/100, |train-loss: 0.7259
# epoch 21/50 steps 100/100, |train-loss: 0.7325 |avg-loss: 0.7028 dur 15.8s |val-acc: 0.5455 |old-best: 0.5909
# epoch 22/50 steps 5/100, |train-loss: 0.6081
# epoch 22/50 steps 10/100, |train-loss: 0.7177
# epoch 22/50 steps 15/100, |train-loss: 0.6779
# epoch 22/50 steps 20/100, |train-loss: 0.6219
# epoch 22/50 steps 25/100, |train-loss: 0.6987
# epoch 22/50 steps 30/100, |train-loss: 0.7212
# epoch 22/50 steps 35/100, |train-loss: 0.6685
# epoch 22/50 steps 40/100, |train-loss: 0.6499
# epoch 22/50 steps 45/100, |train-loss: 0.6513
# epoch 22/50 steps 50/100, |train-loss: 0.8093
# epoch 22/50 steps 55/100, |train-loss: 0.8226
# epoch 22/50 steps 60/100, |train-loss: 0.7980
# epoch 22/50 steps 65/100, |train-loss: 0.5861
# epoch 22/50 steps 70/100, |train-loss: 0.5918
# epoch 22/50 steps 75/100, |train-loss: 0.6045
# epoch 22/50 steps 80/100, |train-loss: 0.5782
# epoch 22/50 steps 85/100, |train-loss: 0.6724
# epoch 22/50 steps 90/100, |train-loss: 0.7562
# epoch 22/50 steps 95/100, |train-loss: 0.6596
# epoch 22/50 steps 100/100, |train-loss: 0.7571 |avg-loss: 0.6973 dur 15.8s |val-acc: 0.5227 |old-best: 0.5909
# epoch 23/50 steps 5/100, |train-loss: 0.4892
# epoch 23/50 steps 10/100, |train-loss: 0.6262
# epoch 23/50 steps 15/100, |train-loss: 0.6253
# epoch 23/50 steps 20/100, |train-loss: 0.6143
# epoch 23/50 steps 25/100, |train-loss: 0.6991
# epoch 23/50 steps 30/100, |train-loss: 0.7045
# epoch 23/50 steps 35/100, |train-loss: 0.7550
# epoch 23/50 steps 40/100, |train-loss: 0.7373
# epoch 23/50 steps 45/100, |train-loss: 0.7479
# epoch 23/50 steps 50/100, |train-loss: 0.7414
# epoch 23/50 steps 55/100, |train-loss: 0.6846
# epoch 23/50 steps 60/100, |train-loss: 0.7127
# epoch 23/50 steps 65/100, |train-loss: 0.7121
# epoch 23/50 steps 70/100, |train-loss: 0.5929
# epoch 23/50 steps 75/100, |train-loss: 0.7118
# epoch 23/50 steps 80/100, |train-loss: 0.6935
# epoch 23/50 steps 85/100, |train-loss: 0.6440
# epoch 23/50 steps 90/100, |train-loss: 0.6208
# epoch 23/50 steps 95/100, |train-loss: 0.7109
# epoch 23/50 steps 100/100, |train-loss: 0.7192 |avg-loss: 0.6941 dur 15.9s |val-acc: 0.5455 |old-best: 0.5909
# epoch 24/50 steps 5/100, |train-loss: 0.7186
# epoch 24/50 steps 10/100, |train-loss: 0.6236
# epoch 24/50 steps 15/100, |train-loss: 0.7098
# epoch 24/50 steps 20/100, |train-loss: 0.6822
# epoch 24/50 steps 25/100, |train-loss: 0.6390
# epoch 24/50 steps 30/100, |train-loss: 0.7814
# epoch 24/50 steps 35/100, |train-loss: 0.7574
# epoch 24/50 steps 40/100, |train-loss: 0.6708
# epoch 24/50 steps 45/100, |train-loss: 0.7767
# epoch 24/50 steps 50/100, |train-loss: 0.6676
# epoch 24/50 steps 55/100, |train-loss: 0.6302
# epoch 24/50 steps 60/100, |train-loss: 0.5972
# epoch 24/50 steps 65/100, |train-loss: 0.5611
# epoch 24/50 steps 70/100, |train-loss: 0.8849
# epoch 24/50 steps 75/100, |train-loss: 0.6750
# epoch 24/50 steps 80/100, |train-loss: 0.8523
# epoch 24/50 steps 85/100, |train-loss: 0.8203
# epoch 24/50 steps 90/100, |train-loss: 0.7653
# epoch 24/50 steps 95/100, |train-loss: 0.8878
# epoch 24/50 steps 100/100, |train-loss: 0.6967 |avg-loss: 0.7089 dur 16.0s |val-acc: 0.5682 |old-best: 0.5909
# epoch 25/50 steps 5/100, |train-loss: 0.6939
# epoch 25/50 steps 10/100, |train-loss: 0.6409
# epoch 25/50 steps 15/100, |train-loss: 0.6914
# epoch 25/50 steps 20/100, |train-loss: 0.6711
# epoch 25/50 steps 25/100, |train-loss: 0.6413
# epoch 25/50 steps 30/100, |train-loss: 0.6108
# epoch 25/50 steps 35/100, |train-loss: 0.8363
# epoch 25/50 steps 40/100, |train-loss: 0.6522
# epoch 25/50 steps 45/100, |train-loss: 0.5978
# epoch 25/50 steps 50/100, |train-loss: 0.7482
# epoch 25/50 steps 55/100, |train-loss: 0.6420
# epoch 25/50 steps 60/100, |train-loss: 0.7211
# epoch 25/50 steps 65/100, |train-loss: 0.4378
# epoch 25/50 steps 70/100, |train-loss: 0.7655
# epoch 25/50 steps 75/100, |train-loss: 0.7520
# epoch 25/50 steps 80/100, |train-loss: 0.7198
# epoch 25/50 steps 85/100, |train-loss: 0.5959
# epoch 25/50 steps 90/100, |train-loss: 0.5446
# epoch 25/50 steps 95/100, |train-loss: 0.7188
# epoch 25/50 steps 100/100, |train-loss: 0.7210 |avg-loss: 0.6966 dur 15.9s |val-acc: 0.5455 |old-best: 0.5909
# epoch 26/50 steps 5/100, |train-loss: 0.7112
# epoch 26/50 steps 10/100, |train-loss: 0.4952
# epoch 26/50 steps 15/100, |train-loss: 0.9269
# epoch 26/50 steps 20/100, |train-loss: 0.5839
# epoch 26/50 steps 25/100, |train-loss: 0.7751
# epoch 26/50 steps 30/100, |train-loss: 0.8075
# epoch 26/50 steps 35/100, |train-loss: 0.6597
# epoch 26/50 steps 40/100, |train-loss: 0.7237
# epoch 26/50 steps 45/100, |train-loss: 0.7259
# epoch 26/50 steps 50/100, |train-loss: 0.7034
# epoch 26/50 steps 55/100, |train-loss: 0.7341
# epoch 26/50 steps 60/100, |train-loss: 0.7568
# epoch 26/50 steps 65/100, |train-loss: 0.7735
# epoch 26/50 steps 70/100, |train-loss: 0.7989
# epoch 26/50 steps 75/100, |train-loss: 0.6730
# epoch 26/50 steps 80/100, |train-loss: 0.6489
# epoch 26/50 steps 85/100, |train-loss: 0.6565
# epoch 26/50 steps 90/100, |train-loss: 0.8874
# epoch 26/50 steps 95/100, |train-loss: 0.7813
# epoch 26/50 steps 100/100, |train-loss: 0.7551 |avg-loss: 0.7139 dur 15.8s |val-acc: 0.5227 |old-best: 0.5909
# epoch 27/50 steps 5/100, |train-loss: 0.6509
# epoch 27/50 steps 10/100, |train-loss: 0.6466
# epoch 27/50 steps 15/100, |train-loss: 0.6986
# epoch 27/50 steps 20/100, |train-loss: 0.6565
# epoch 27/50 steps 25/100, |train-loss: 0.7620
# epoch 27/50 steps 30/100, |train-loss: 0.6440
# epoch 27/50 steps 35/100, |train-loss: 0.6960
# epoch 27/50 steps 40/100, |train-loss: 0.5969
# epoch 27/50 steps 45/100, |train-loss: 0.6033
# epoch 27/50 steps 50/100, |train-loss: 0.6253
# epoch 27/50 steps 55/100, |train-loss: 0.7235
# epoch 27/50 steps 60/100, |train-loss: 0.6027
# epoch 27/50 steps 65/100, |train-loss: 0.7086
# epoch 27/50 steps 70/100, |train-loss: 0.7003
# epoch 27/50 steps 75/100, |train-loss: 0.7018
# epoch 27/50 steps 80/100, |train-loss: 0.6610
# epoch 27/50 steps 85/100, |train-loss: 0.7001
# epoch 27/50 steps 90/100, |train-loss: 0.6924
# epoch 27/50 steps 95/100, |train-loss: 0.6579
# epoch 27/50 steps 100/100, |train-loss: 0.6972 |avg-loss: 0.7075 dur 15.8s |val-acc: 0.4318 |old-best: 0.5909
# epoch 28/50 steps 5/100, |train-loss: 0.6515
# epoch 28/50 steps 10/100, |train-loss: 0.8075
# epoch 28/50 steps 15/100, |train-loss: 0.5879
# epoch 28/50 steps 20/100, |train-loss: 0.5888
# epoch 28/50 steps 25/100, |train-loss: 0.8185
# epoch 28/50 steps 30/100, |train-loss: 0.7058
# epoch 28/50 steps 35/100, |train-loss: 0.6451
# epoch 28/50 steps 40/100, |train-loss: 0.6225
# epoch 28/50 steps 45/100, |train-loss: 0.7586
# epoch 28/50 steps 50/100, |train-loss: 0.7460
# epoch 28/50 steps 55/100, |train-loss: 0.7169
# epoch 28/50 steps 60/100, |train-loss: 0.7917
# epoch 28/50 steps 65/100, |train-loss: 0.7125
# epoch 28/50 steps 70/100, |train-loss: 0.7329
# epoch 28/50 steps 75/100, |train-loss: 0.8307
# epoch 28/50 steps 80/100, |train-loss: 0.6700
# epoch 28/50 steps 85/100, |train-loss: 0.5798
# epoch 28/50 steps 90/100, |train-loss: 0.6570
# epoch 28/50 steps 95/100, |train-loss: 0.7557
# epoch 28/50 steps 100/100, |train-loss: 0.7630 |avg-loss: 0.7027 dur 15.9s |val-acc: 0.5000 |old-best: 0.5909
# epoch 29/50 steps 5/100, |train-loss: 0.6899
# epoch 29/50 steps 10/100, |train-loss: 0.6082
# epoch 29/50 steps 15/100, |train-loss: 0.7261
# epoch 29/50 steps 20/100, |train-loss: 0.7207
# epoch 29/50 steps 25/100, |train-loss: 0.8434
# epoch 29/50 steps 30/100, |train-loss: 0.7117
# epoch 29/50 steps 35/100, |train-loss: 0.7066
# epoch 29/50 steps 40/100, |train-loss: 0.7059
# epoch 29/50 steps 45/100, |train-loss: 0.7353
# epoch 29/50 steps 50/100, |train-loss: 0.7267
# epoch 29/50 steps 55/100, |train-loss: 0.6940
# epoch 29/50 steps 60/100, |train-loss: 0.6223
# epoch 29/50 steps 65/100, |train-loss: 0.5778
# epoch 29/50 steps 70/100, |train-loss: 0.6902
# epoch 29/50 steps 75/100, |train-loss: 0.5796
# epoch 29/50 steps 80/100, |train-loss: 0.6806
# epoch 29/50 steps 85/100, |train-loss: 1.0004
# epoch 29/50 steps 90/100, |train-loss: 0.7425
# epoch 29/50 steps 95/100, |train-loss: 0.6821
# epoch 29/50 steps 100/100, |train-loss: 0.6188 |avg-loss: 0.7030 dur 15.8s |val-acc: 0.5227 |old-best: 0.5909
# epoch 30/50 steps 5/100, |train-loss: 0.7389
# epoch 30/50 steps 10/100, |train-loss: 0.5373
# epoch 30/50 steps 15/100, |train-loss: 0.8249
# epoch 30/50 steps 20/100, |train-loss: 0.6520
# epoch 30/50 steps 25/100, |train-loss: 0.6399
# epoch 30/50 steps 30/100, |train-loss: 0.8604
# epoch 30/50 steps 35/100, |train-loss: 0.7630
# epoch 30/50 steps 40/100, |train-loss: 0.6374
# epoch 30/50 steps 45/100, |train-loss: 0.6945
# epoch 30/50 steps 50/100, |train-loss: 0.6256
# epoch 30/50 steps 55/100, |train-loss: 0.6021
# epoch 30/50 steps 60/100, |train-loss: 0.7894
# epoch 30/50 steps 65/100, |train-loss: 0.6902
# epoch 30/50 steps 70/100, |train-loss: 0.9624
# epoch 30/50 steps 75/100, |train-loss: 0.7700
# epoch 30/50 steps 80/100, |train-loss: 0.7078
# epoch 30/50 steps 85/100, |train-loss: 0.7185
# epoch 30/50 steps 90/100, |train-loss: 0.7445
# epoch 30/50 steps 95/100, |train-loss: 0.5304
# epoch 30/50 steps 100/100, |train-loss: 0.6806 |avg-loss: 0.6936 dur 15.8s |val-acc: 0.5227 |old-best: 0.5909 |30ep model saved
# epoch 31/50 steps 5/100, |train-loss: 0.7746
# epoch 31/50 steps 10/100, |train-loss: 0.6786
# epoch 31/50 steps 15/100, |train-loss: 0.6988
# epoch 31/50 steps 20/100, |train-loss: 0.6997
# epoch 31/50 steps 25/100, |train-loss: 0.6587
# epoch 31/50 steps 30/100, |train-loss: 0.7605
# epoch 31/50 steps 35/100, |train-loss: 0.7148
# epoch 31/50 steps 40/100, |train-loss: 0.5383
# epoch 31/50 steps 45/100, |train-loss: 0.6791
# epoch 31/50 steps 50/100, |train-loss: 0.6184
# epoch 31/50 steps 55/100, |train-loss: 0.5692
# epoch 31/50 steps 60/100, |train-loss: 0.6789
# epoch 31/50 steps 65/100, |train-loss: 0.6848
# epoch 31/50 steps 70/100, |train-loss: 0.6817
# epoch 31/50 steps 75/100, |train-loss: 0.7262
# epoch 31/50 steps 80/100, |train-loss: 0.7418
# epoch 31/50 steps 85/100, |train-loss: 0.8440
# epoch 31/50 steps 90/100, |train-loss: 0.6697
# epoch 31/50 steps 95/100, |train-loss: 0.7026
# epoch 31/50 steps 100/100, |train-loss: 0.7351 |avg-loss: 0.7074 dur 15.9s |val-acc: 0.4773 |old-best: 0.5909
# epoch 32/50 steps 5/100, |train-loss: 0.7178
# epoch 32/50 steps 10/100, |train-loss: 0.7157
# epoch 32/50 steps 15/100, |train-loss: 0.6985
# epoch 32/50 steps 20/100, |train-loss: 0.6957
# epoch 32/50 steps 25/100, |train-loss: 0.7326
# epoch 32/50 steps 30/100, |train-loss: 0.6297
# epoch 32/50 steps 35/100, |train-loss: 0.6937
# epoch 32/50 steps 40/100, |train-loss: 0.7294
# epoch 32/50 steps 45/100, |train-loss: 0.5796
# epoch 32/50 steps 50/100, |train-loss: 0.6017
# epoch 32/50 steps 55/100, |train-loss: 0.7231
# epoch 32/50 steps 60/100, |train-loss: 0.5975
# epoch 32/50 steps 65/100, |train-loss: 0.7898
# epoch 32/50 steps 70/100, |train-loss: 0.7232
# epoch 32/50 steps 75/100, |train-loss: 0.6303
# epoch 32/50 steps 80/100, |train-loss: 0.6353
# epoch 32/50 steps 85/100, |train-loss: 0.6692
# epoch 32/50 steps 90/100, |train-loss: 0.6720
# epoch 32/50 steps 95/100, |train-loss: 0.7275
# epoch 32/50 steps 100/100, |train-loss: 0.7659 |avg-loss: 0.7002 dur 15.9s |val-acc: 0.5682 |old-best: 0.5909
# epoch 33/50 steps 5/100, |train-loss: 0.7100
# epoch 33/50 steps 10/100, |train-loss: 0.8200
# epoch 33/50 steps 15/100, |train-loss: 0.6972
# epoch 33/50 steps 20/100, |train-loss: 0.6920
# epoch 33/50 steps 25/100, |train-loss: 0.7213
# epoch 33/50 steps 30/100, |train-loss: 0.7569
# epoch 33/50 steps 35/100, |train-loss: 0.6708
# epoch 33/50 steps 40/100, |train-loss: 0.7599
# epoch 33/50 steps 45/100, |train-loss: 0.6762
# epoch 33/50 steps 50/100, |train-loss: 0.7576
# epoch 33/50 steps 55/100, |train-loss: 0.7298
# epoch 33/50 steps 60/100, |train-loss: 0.6795
# epoch 33/50 steps 65/100, |train-loss: 0.7319
# epoch 33/50 steps 70/100, |train-loss: 0.7887
# epoch 33/50 steps 75/100, |train-loss: 0.6064
# epoch 33/50 steps 80/100, |train-loss: 0.7559
# epoch 33/50 steps 85/100, |train-loss: 0.6560
# epoch 33/50 steps 90/100, |train-loss: 0.7209
# epoch 33/50 steps 95/100, |train-loss: 0.5431
# epoch 33/50 steps 100/100, |train-loss: 0.7474 |avg-loss: 0.6946 dur 15.9s |val-acc: 0.5909 |old-best: 0.5909
# epoch 34/50 steps 5/100, |train-loss: 0.7018
# epoch 34/50 steps 10/100, |train-loss: 0.6352
# epoch 34/50 steps 15/100, |train-loss: 0.6829
# epoch 34/50 steps 20/100, |train-loss: 0.6155
# epoch 34/50 steps 25/100, |train-loss: 0.4663
# epoch 34/50 steps 30/100, |train-loss: 0.7635
# epoch 34/50 steps 35/100, |train-loss: 0.7091
# epoch 34/50 steps 40/100, |train-loss: 0.7335
# epoch 34/50 steps 45/100, |train-loss: 0.6284
# epoch 34/50 steps 50/100, |train-loss: 0.6986
# epoch 34/50 steps 55/100, |train-loss: 0.7015
# epoch 34/50 steps 60/100, |train-loss: 0.6886
# epoch 34/50 steps 65/100, |train-loss: 0.6778
# epoch 34/50 steps 70/100, |train-loss: 0.6570
# epoch 34/50 steps 75/100, |train-loss: 0.7541
# epoch 34/50 steps 80/100, |train-loss: 0.7855
# epoch 34/50 steps 85/100, |train-loss: 0.7433
# epoch 34/50 steps 90/100, |train-loss: 0.7481
# epoch 34/50 steps 95/100, |train-loss: 0.7260
# epoch 34/50 steps 100/100, |train-loss: 0.8209 |avg-loss: 0.7009 dur 15.9s |val-acc: 0.3636 |old-best: 0.5909
# epoch 35/50 steps 5/100, |train-loss: 0.7036
# epoch 35/50 steps 10/100, |train-loss: 0.7209
# epoch 35/50 steps 15/100, |train-loss: 0.7417
# epoch 35/50 steps 20/100, |train-loss: 0.7874
# epoch 35/50 steps 25/100, |train-loss: 0.6350
# epoch 35/50 steps 30/100, |train-loss: 0.7440
# epoch 35/50 steps 35/100, |train-loss: 0.6835
# epoch 35/50 steps 40/100, |train-loss: 0.7403
# epoch 35/50 steps 45/100, |train-loss: 0.6564
# epoch 35/50 steps 50/100, |train-loss: 0.7031
# epoch 35/50 steps 55/100, |train-loss: 0.7218
# epoch 35/50 steps 60/100, |train-loss: 0.7108
# epoch 35/50 steps 65/100, |train-loss: 0.6407
# epoch 35/50 steps 70/100, |train-loss: 0.7040
# epoch 35/50 steps 75/100, |train-loss: 0.7629
# epoch 35/50 steps 80/100, |train-loss: 0.7013
# epoch 35/50 steps 85/100, |train-loss: 0.6589
# epoch 35/50 steps 90/100, |train-loss: 0.7224
# epoch 35/50 steps 95/100, |train-loss: 0.7168
# epoch 35/50 steps 100/100, |train-loss: 0.7421 |avg-loss: 0.7001 dur 15.8s |val-acc: 0.4091 |old-best: 0.5909
# epoch 36/50 steps 5/100, |train-loss: 0.7952
# epoch 36/50 steps 10/100, |train-loss: 0.6706
# epoch 36/50 steps 15/100, |train-loss: 0.7929
# epoch 36/50 steps 20/100, |train-loss: 0.8251
# epoch 36/50 steps 25/100, |train-loss: 0.9220
# epoch 36/50 steps 30/100, |train-loss: 0.7889
# epoch 36/50 steps 35/100, |train-loss: 0.6589
# epoch 36/50 steps 40/100, |train-loss: 0.7172
# epoch 36/50 steps 45/100, |train-loss: 0.6991
# epoch 36/50 steps 50/100, |train-loss: 0.7025
# epoch 36/50 steps 55/100, |train-loss: 0.7773
# epoch 36/50 steps 60/100, |train-loss: 0.6792
# epoch 36/50 steps 65/100, |train-loss: 0.7594
# epoch 36/50 steps 70/100, |train-loss: 0.7035
# epoch 36/50 steps 75/100, |train-loss: 0.6642
# epoch 36/50 steps 80/100, |train-loss: 0.5419
# epoch 36/50 steps 85/100, |train-loss: 0.5014
# epoch 36/50 steps 90/100, |train-loss: 0.5779
# epoch 36/50 steps 95/100, |train-loss: 0.6958
# epoch 36/50 steps 100/100, |train-loss: 0.8388 |avg-loss: 0.6977 dur 15.9s |val-acc: 0.5455 |old-best: 0.5909
# epoch 37/50 steps 5/100, |train-loss: 0.7133
# epoch 37/50 steps 10/100, |train-loss: 0.6454
# epoch 37/50 steps 15/100, |train-loss: 0.6314
# epoch 37/50 steps 20/100, |train-loss: 0.9647
# epoch 37/50 steps 25/100, |train-loss: 0.6171
# epoch 37/50 steps 30/100, |train-loss: 0.8227
# epoch 37/50 steps 35/100, |train-loss: 0.7818
# epoch 37/50 steps 40/100, |train-loss: 0.7798
# epoch 37/50 steps 45/100, |train-loss: 0.7379
# epoch 37/50 steps 50/100, |train-loss: 0.8168
# epoch 37/50 steps 55/100, |train-loss: 0.6668
# epoch 37/50 steps 60/100, |train-loss: 0.7116
# epoch 37/50 steps 65/100, |train-loss: 0.7832
# epoch 37/50 steps 70/100, |train-loss: 0.7379
# epoch 37/50 steps 75/100, |train-loss: 0.6617
# epoch 37/50 steps 80/100, |train-loss: 0.6134
# epoch 37/50 steps 85/100, |train-loss: 0.6698
# epoch 37/50 steps 90/100, |train-loss: 0.6344
# epoch 37/50 steps 95/100, |train-loss: 0.7386
# epoch 37/50 steps 100/100, |train-loss: 0.6413 |avg-loss: 0.7112 dur 15.9s |val-acc: 0.4773 |old-best: 0.5909
# epoch 38/50 steps 5/100, |train-loss: 0.7138
# epoch 38/50 steps 10/100, |train-loss: 0.7323
# epoch 38/50 steps 15/100, |train-loss: 0.6676
# epoch 38/50 steps 20/100, |train-loss: 0.5819
# epoch 38/50 steps 25/100, |train-loss: 0.6529
# epoch 38/50 steps 30/100, |train-loss: 1.0524
# epoch 38/50 steps 35/100, |train-loss: 0.6335
# epoch 38/50 steps 40/100, |train-loss: 0.6501
# epoch 38/50 steps 45/100, |train-loss: 0.6833
# epoch 38/50 steps 50/100, |train-loss: 0.4963
# epoch 38/50 steps 55/100, |train-loss: 0.6020
# epoch 38/50 steps 60/100, |train-loss: 0.5434
# epoch 38/50 steps 65/100, |train-loss: 0.6894
# epoch 38/50 steps 70/100, |train-loss: 0.8214
# epoch 38/50 steps 75/100, |train-loss: 0.6591
# epoch 38/50 steps 80/100, |train-loss: 0.6974
# epoch 38/50 steps 85/100, |train-loss: 0.6831
# epoch 38/50 steps 90/100, |train-loss: 0.7355
# epoch 38/50 steps 95/100, |train-loss: 0.7146
# epoch 38/50 steps 100/100, |train-loss: 0.7488 |avg-loss: 0.7018 dur 15.9s |val-acc: 0.5227 |old-best: 0.5909
# epoch 39/50 steps 5/100, |train-loss: 0.7558
# epoch 39/50 steps 10/100, |train-loss: 0.6785
# epoch 39/50 steps 15/100, |train-loss: 0.6941
# epoch 39/50 steps 20/100, |train-loss: 0.7130
# epoch 39/50 steps 25/100, |train-loss: 0.7312
# epoch 39/50 steps 30/100, |train-loss: 0.6990
# epoch 39/50 steps 35/100, |train-loss: 0.6799
# epoch 39/50 steps 40/100, |train-loss: 0.6464
# epoch 39/50 steps 45/100, |train-loss: 0.7303
# epoch 39/50 steps 50/100, |train-loss: 0.8135
# epoch 39/50 steps 55/100, |train-loss: 0.6078
# epoch 39/50 steps 60/100, |train-loss: 0.8495
# epoch 39/50 steps 65/100, |train-loss: 0.6917
# epoch 39/50 steps 70/100, |train-loss: 0.6174
# epoch 39/50 steps 75/100, |train-loss: 0.7695
# epoch 39/50 steps 80/100, |train-loss: 0.6468
# epoch 39/50 steps 85/100, |train-loss: 0.7429
# epoch 39/50 steps 90/100, |train-loss: 0.6193
# epoch 39/50 steps 95/100, |train-loss: 0.8161
# epoch 39/50 steps 100/100, |train-loss: 0.7470 |avg-loss: 0.6991 dur 15.9s |val-acc: 0.4773 |old-best: 0.5909
# epoch 40/50 steps 5/100, |train-loss: 0.7357
# epoch 40/50 steps 10/100, |train-loss: 0.7286
# epoch 40/50 steps 15/100, |train-loss: 0.6468
# epoch 40/50 steps 20/100, |train-loss: 0.6113
# epoch 40/50 steps 25/100, |train-loss: 0.7779
# epoch 40/50 steps 30/100, |train-loss: 0.7334
# epoch 40/50 steps 35/100, |train-loss: 0.7574
# epoch 40/50 steps 40/100, |train-loss: 0.7621
# epoch 40/50 steps 45/100, |train-loss: 0.6721
# epoch 40/50 steps 50/100, |train-loss: 0.6290
# epoch 40/50 steps 55/100, |train-loss: 0.7071
# epoch 40/50 steps 60/100, |train-loss: 0.6439
# epoch 40/50 steps 65/100, |train-loss: 0.9407
# epoch 40/50 steps 70/100, |train-loss: 0.7218
# epoch 40/50 steps 75/100, |train-loss: 0.6621
# epoch 40/50 steps 80/100, |train-loss: 0.6490
# epoch 40/50 steps 85/100, |train-loss: 0.7925
# epoch 40/50 steps 90/100, |train-loss: 0.7829
# epoch 40/50 steps 95/100, |train-loss: 0.7748
# epoch 40/50 steps 100/100, |train-loss: 0.7219 |avg-loss: 0.7000 dur 15.8s |val-acc: 0.5227 |old-best: 0.5909 |40ep model saved
# epoch 41/50 steps 5/100, |train-loss: 0.6903
# epoch 41/50 steps 10/100, |train-loss: 0.9251
# epoch 41/50 steps 15/100, |train-loss: 0.7819
# epoch 41/50 steps 20/100, |train-loss: 0.4954
# epoch 41/50 steps 25/100, |train-loss: 0.7938
# epoch 41/50 steps 30/100, |train-loss: 0.6257
# epoch 41/50 steps 35/100, |train-loss: 0.6664
# epoch 41/50 steps 40/100, |train-loss: 0.7518
# epoch 41/50 steps 45/100, |train-loss: 0.6914
# epoch 41/50 steps 50/100, |train-loss: 0.7062
# epoch 41/50 steps 55/100, |train-loss: 0.7314
# epoch 41/50 steps 60/100, |train-loss: 0.7828
# epoch 41/50 steps 65/100, |train-loss: 0.6698
# epoch 41/50 steps 70/100, |train-loss: 0.6638
# epoch 41/50 steps 75/100, |train-loss: 0.8160
# epoch 41/50 steps 80/100, |train-loss: 0.6807
# epoch 41/50 steps 85/100, |train-loss: 0.7862
# epoch 41/50 steps 90/100, |train-loss: 0.6999
# epoch 41/50 steps 95/100, |train-loss: 0.7015
# epoch 41/50 steps 100/100, |train-loss: 0.6985 |avg-loss: 0.7060 dur 15.8s |val-acc: 0.4545 |old-best: 0.5909
# epoch 42/50 steps 5/100, |train-loss: 0.7235
# epoch 42/50 steps 10/100, |train-loss: 0.7230
# epoch 42/50 steps 15/100, |train-loss: 0.8148
# epoch 42/50 steps 20/100, |train-loss: 0.6981
# epoch 42/50 steps 25/100, |train-loss: 0.7008
# epoch 42/50 steps 30/100, |train-loss: 0.7239
# epoch 42/50 steps 35/100, |train-loss: 0.7081
# epoch 42/50 steps 40/100, |train-loss: 0.6861
# epoch 42/50 steps 45/100, |train-loss: 0.6736
# epoch 42/50 steps 50/100, |train-loss: 0.7090
# epoch 42/50 steps 55/100, |train-loss: 0.6930
# epoch 42/50 steps 60/100, |train-loss: 0.6941
# epoch 42/50 steps 65/100, |train-loss: 0.6862
# epoch 42/50 steps 70/100, |train-loss: 0.5626
# epoch 42/50 steps 75/100, |train-loss: 0.5242
# epoch 42/50 steps 80/100, |train-loss: 0.7337
# epoch 42/50 steps 85/100, |train-loss: 0.7584
# epoch 42/50 steps 90/100, |train-loss: 0.6478
# epoch 42/50 steps 95/100, |train-loss: 0.7061
# epoch 42/50 steps 100/100, |train-loss: 0.6637 |avg-loss: 0.6890 dur 15.9s |val-acc: 0.4318 |old-best: 0.5909
# epoch 43/50 steps 5/100, |train-loss: 0.5066
# epoch 43/50 steps 10/100, |train-loss: 0.5475
# epoch 43/50 steps 15/100, |train-loss: 0.6481
# epoch 43/50 steps 20/100, |train-loss: 0.7496
# epoch 43/50 steps 25/100, |train-loss: 0.7341
# epoch 43/50 steps 30/100, |train-loss: 0.7264
# epoch 43/50 steps 35/100, |train-loss: 0.7181
# epoch 43/50 steps 40/100, |train-loss: 0.6999
# epoch 43/50 steps 45/100, |train-loss: 0.6889
# epoch 43/50 steps 50/100, |train-loss: 0.7274
# epoch 43/50 steps 55/100, |train-loss: 0.6806
# epoch 43/50 steps 60/100, |train-loss: 0.7371
# epoch 43/50 steps 65/100, |train-loss: 0.6650
# epoch 43/50 steps 70/100, |train-loss: 0.7446
# epoch 43/50 steps 75/100, |train-loss: 0.7398
# epoch 43/50 steps 80/100, |train-loss: 0.7305
# epoch 43/50 steps 85/100, |train-loss: 0.7358
# epoch 43/50 steps 90/100, |train-loss: 0.7291
# epoch 43/50 steps 95/100, |train-loss: 0.6758
# epoch 43/50 steps 100/100, |train-loss: 0.7221 |avg-loss: 0.6856 dur 15.9s |val-acc: 0.5455 |old-best: 0.5909
# epoch 44/50 steps 5/100, |train-loss: 0.5702
# epoch 44/50 steps 10/100, |train-loss: 0.6917
# epoch 44/50 steps 15/100, |train-loss: 0.6512
# epoch 44/50 steps 20/100, |train-loss: 0.6930
# epoch 44/50 steps 25/100, |train-loss: 0.7876
# epoch 44/50 steps 30/100, |train-loss: 0.7816
# epoch 44/50 steps 35/100, |train-loss: 0.8102
# epoch 44/50 steps 40/100, |train-loss: 0.6119
# epoch 44/50 steps 45/100, |train-loss: 0.5665
# epoch 44/50 steps 50/100, |train-loss: 0.6044
# epoch 44/50 steps 55/100, |train-loss: 0.6630
# epoch 44/50 steps 60/100, |train-loss: 0.6917
# epoch 44/50 steps 65/100, |train-loss: 0.7314
# epoch 44/50 steps 70/100, |train-loss: 0.6642
# epoch 44/50 steps 75/100, |train-loss: 0.6637
# epoch 44/50 steps 80/100, |train-loss: 0.5908
# epoch 44/50 steps 85/100, |train-loss: 0.6551
# epoch 44/50 steps 90/100, |train-loss: 0.7078
# epoch 44/50 steps 95/100, |train-loss: 0.7172
# epoch 44/50 steps 100/100, |train-loss: 0.6947 |avg-loss: 0.7062 dur 15.8s |val-acc: 0.5227 |old-best: 0.5909
# epoch 45/50 steps 5/100, |train-loss: 0.6026
# epoch 45/50 steps 10/100, |train-loss: 0.7270
# epoch 45/50 steps 15/100, |train-loss: 0.6656
# epoch 45/50 steps 20/100, |train-loss: 0.6359
# epoch 45/50 steps 25/100, |train-loss: 0.6918
# epoch 45/50 steps 30/100, |train-loss: 0.8501
# epoch 45/50 steps 35/100, |train-loss: 0.5983
# epoch 45/50 steps 40/100, |train-loss: 0.5830
# epoch 45/50 steps 45/100, |train-loss: 0.6838
# epoch 45/50 steps 50/100, |train-loss: 0.7017
# epoch 45/50 steps 55/100, |train-loss: 0.7105
# epoch 45/50 steps 60/100, |train-loss: 0.8409
# epoch 45/50 steps 65/100, |train-loss: 0.7502
# epoch 45/50 steps 70/100, |train-loss: 0.5296
# epoch 45/50 steps 75/100, |train-loss: 0.5679
# epoch 45/50 steps 80/100, |train-loss: 0.7104
# epoch 45/50 steps 85/100, |train-loss: 0.5979
# epoch 45/50 steps 90/100, |train-loss: 0.8263
# epoch 45/50 steps 95/100, |train-loss: 0.7234
# epoch 45/50 steps 100/100, |train-loss: 0.7261 |avg-loss: 0.6993 dur 15.9s |val-acc: 0.5455 |old-best: 0.5909
# epoch 46/50 steps 5/100, |train-loss: 0.6639
# epoch 46/50 steps 10/100, |train-loss: 0.7525
# epoch 46/50 steps 15/100, |train-loss: 0.7093
# epoch 46/50 steps 20/100, |train-loss: 0.6664
# epoch 46/50 steps 25/100, |train-loss: 0.7433
# epoch 46/50 steps 30/100, |train-loss: 0.9632
# epoch 46/50 steps 35/100, |train-loss: 0.6883
# epoch 46/50 steps 40/100, |train-loss: 0.6997
# epoch 46/50 steps 45/100, |train-loss: 0.5400
# epoch 46/50 steps 50/100, |train-loss: 0.7183
# epoch 46/50 steps 55/100, |train-loss: 0.6867
# epoch 46/50 steps 60/100, |train-loss: 0.6345
# epoch 46/50 steps 65/100, |train-loss: 0.6342
# epoch 46/50 steps 70/100, |train-loss: 0.6117
# epoch 46/50 steps 75/100, |train-loss: 0.6269
# epoch 46/50 steps 80/100, |train-loss: 0.7129
# epoch 46/50 steps 85/100, |train-loss: 0.5630
# epoch 46/50 steps 90/100, |train-loss: 0.7541
# epoch 46/50 steps 95/100, |train-loss: 0.6958
# epoch 46/50 steps 100/100, |train-loss: 0.7818 |avg-loss: 0.6925 dur 15.8s |val-acc: 0.4773 |old-best: 0.5909
# epoch 47/50 steps 5/100, |train-loss: 0.7092
# epoch 47/50 steps 10/100, |train-loss: 0.6724
# epoch 47/50 steps 15/100, |train-loss: 0.5723
# epoch 47/50 steps 20/100, |train-loss: 0.5637
# epoch 47/50 steps 25/100, |train-loss: 0.7351
# epoch 47/50 steps 30/100, |train-loss: 0.6268
# epoch 47/50 steps 35/100, |train-loss: 0.7082
# epoch 47/50 steps 40/100, |train-loss: 0.6805
# epoch 47/50 steps 45/100, |train-loss: 0.7594
# epoch 47/50 steps 50/100, |train-loss: 0.7404
# epoch 47/50 steps 55/100, |train-loss: 0.6713
# epoch 47/50 steps 60/100, |train-loss: 0.5799
# epoch 47/50 steps 65/100, |train-loss: 0.6708
# epoch 47/50 steps 70/100, |train-loss: 0.7369
# epoch 47/50 steps 75/100, |train-loss: 0.6982
# epoch 47/50 steps 80/100, |train-loss: 0.7107
# epoch 47/50 steps 85/100, |train-loss: 0.8166
# epoch 47/50 steps 90/100, |train-loss: 0.7901
# epoch 47/50 steps 95/100, |train-loss: 0.6289
# epoch 47/50 steps 100/100, |train-loss: 0.6653 |avg-loss: 0.6965 dur 15.8s |val-acc: 0.5227 |old-best: 0.5909
# epoch 48/50 steps 5/100, |train-loss: 0.6492
# epoch 48/50 steps 10/100, |train-loss: 0.6167
# epoch 48/50 steps 15/100, |train-loss: 0.7501
# epoch 48/50 steps 20/100, |train-loss: 0.7630
# epoch 48/50 steps 25/100, |train-loss: 0.6775
# epoch 48/50 steps 30/100, |train-loss: 0.7084
# epoch 48/50 steps 35/100, |train-loss: 0.6961
# epoch 48/50 steps 40/100, |train-loss: 0.6791
# epoch 48/50 steps 45/100, |train-loss: 0.5865
# epoch 48/50 steps 50/100, |train-loss: 0.7312
# epoch 48/50 steps 55/100, |train-loss: 0.6595
# epoch 48/50 steps 60/100, |train-loss: 0.7562
# epoch 48/50 steps 65/100, |train-loss: 0.6730
# epoch 48/50 steps 70/100, |train-loss: 0.7671
# epoch 48/50 steps 75/100, |train-loss: 0.4731
# epoch 48/50 steps 80/100, |train-loss: 0.7309
# epoch 48/50 steps 85/100, |train-loss: 0.7240
# epoch 48/50 steps 90/100, |train-loss: 0.8169
# epoch 48/50 steps 95/100, |train-loss: 0.7271
# epoch 48/50 steps 100/100, |train-loss: 0.7106 |avg-loss: 0.6963 dur 15.9s |val-acc: 0.5682 |old-best: 0.5909
# epoch 49/50 steps 5/100, |train-loss: 0.7317
# epoch 49/50 steps 10/100, |train-loss: 0.6609
# epoch 49/50 steps 15/100, |train-loss: 0.7670
# epoch 49/50 steps 20/100, |train-loss: 0.7198
# epoch 49/50 steps 25/100, |train-loss: 0.7040
# epoch 49/50 steps 30/100, |train-loss: 0.6632
# epoch 49/50 steps 35/100, |train-loss: 0.6524
# epoch 49/50 steps 40/100, |train-loss: 0.5993
# epoch 49/50 steps 45/100, |train-loss: 0.6465
# epoch 49/50 steps 50/100, |train-loss: 0.6233
# epoch 49/50 steps 55/100, |train-loss: 0.8126
# epoch 49/50 steps 60/100, |train-loss: 0.6255
# epoch 49/50 steps 65/100, |train-loss: 0.6493
# epoch 49/50 steps 70/100, |train-loss: 0.7231
# epoch 49/50 steps 75/100, |train-loss: 0.7749
# epoch 49/50 steps 80/100, |train-loss: 0.7830
# epoch 49/50 steps 85/100, |train-loss: 0.6182
# epoch 49/50 steps 90/100, |train-loss: 0.7632
# epoch 49/50 steps 95/100, |train-loss: 0.7130
# epoch 49/50 steps 100/100, |train-loss: 0.7894 |avg-loss: 0.6968 dur 16.0s |val-acc: 0.4773 |old-best: 0.5909
# epoch 50/50 steps 5/100, |train-loss: 0.6385
# epoch 50/50 steps 10/100, |train-loss: 0.4768
# epoch 50/50 steps 15/100, |train-loss: 0.6673
# epoch 50/50 steps 20/100, |train-loss: 0.5730
# epoch 50/50 steps 25/100, |train-loss: 0.8128
# epoch 50/50 steps 30/100, |train-loss: 0.5642
# epoch 50/50 steps 35/100, |train-loss: 0.7837
# epoch 50/50 steps 40/100, |train-loss: 0.6381
# epoch 50/50 steps 45/100, |train-loss: 0.8174
# epoch 50/50 steps 50/100, |train-loss: 0.7118
# epoch 50/50 steps 55/100, |train-loss: 0.5117
# epoch 50/50 steps 60/100, |train-loss: 0.6398
# epoch 50/50 steps 65/100, |train-loss: 0.4700
# epoch 50/50 steps 70/100, |train-loss: 0.6504
# epoch 50/50 steps 75/100, |train-loss: 0.8227
# epoch 50/50 steps 80/100, |train-loss: 0.6542
# epoch 50/50 steps 85/100, |train-loss: 0.5977
# epoch 50/50 steps 90/100, |train-loss: 0.6559
# epoch 50/50 steps 95/100, |train-loss: 0.6250
# epoch 50/50 steps 100/100, |train-loss: 0.6549 |avg-loss: 0.6921 dur 15.8s |val-acc: 0.4318 |old-best: 0.5909 |50ep model saved
# train completed, best_metric: 0.5909 at epoch: 16 for 50 epoches
# CPU times: user 13min 53s, sys: 1min 50s, total: 15min 43s
# Wall time: 16min 21s

# %%
# !rm -rf pymp-*

# %%
import matplotlib.pyplot as plt

plt.figure("train", (12, 6))
plt.subplot(1, 2, 1)
plt.title("Epoch Average Loss")
x = [i + 1 for i in range(len(epoch_loss_values))]
y = epoch_loss_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.ylim(0,1)
plt.subplot(1, 2, 2)
plt.title("Val Accuracy")
x = [val_interval * (i + 1) for i in range(len(metric_values))]
y = metric_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.ylim(0,1)
plt.show()
