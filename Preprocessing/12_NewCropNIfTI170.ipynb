# %%
# !nvidia-smi
# Out:
# Fri May  5 09:31:04 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 520.61.05    Driver Version: 520.61.05    CUDA Version: 11.8     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:B2:00.0 Off |                  Off |
# | N/A   32C    P0    40W / 300W |      0MiB / 32768MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import glob

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import nibabel as nib

from monai.apps import download_and_extract
from monai.config import print_config
from monai.utils import set_determinism

print_config()
set_determinism(0)

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.filterwarnings("ignore", category=UserWarning)
# Out:
# /home/fastmri2/.conda/envs/snumvi/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# MONAI version: 1.1.0
# Numpy version: 1.23.5
# Pytorch version: 1.7.1+cu110
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: a2ec3752f54bfc3b40e7952234fbeb5452ed63e3
# MONAI __file__: /home/fastmri2/.conda/envs/snumvi/lib/python3.8/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.4.8
# Nibabel version: 5.0.0
# scikit-image version: 0.19.3
# Pillow version: 9.4.0
# Tensorboard version: 2.4.0
# gdown version: 4.6.0
# TorchVision version: 0.8.2+cu110
# tqdm version: 4.65.0
# lmdb version: 1.4.0
# psutil version: 5.9.0
# pandas version: 1.5.2
# einops version: 0.6.0
# transformers version: NOT INSTALLED or UNKNOWN VERSION.
# mlflow version: 2.1.1
# pynrrd version: 1.0.0
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %%
directory = "temp"
if not os.path.exists(directory):
    os.makedirs(directory)
root_dir = tempfile.mkdtemp() if directory is None else directory
data_dir = "cropped/HBP/"
uncropped_dir = "nifti/HBP"

# %%
patients = sorted(glob.glob(os.path.join(uncropped_dir, "*.nii.gz")))
print(len(patients))
# Out:
# 244

# %%
patient_data = pd.read_excel("new_nifti_center.xlsx").set_index("patID")
print(patient_data)
# Out:
#         front  end  left  right  top  bottom  v_center  h_center  l_center
# patID
# 7739      102  199   185    117   45      45     111.5     126.0      50.0
# 20491     112  184   174    119   74      12     124.0     132.5      81.0
# 50368      80  227   180    127   71      22      86.5     133.5      74.5
# 59047     151  342   271    225   63      15     160.5     233.0      66.0
# 63193     116  191   170    137   70      23     122.5     143.5      73.5
# ...       ...  ...   ...    ...  ...     ...       ...       ...       ...
# 100139     85  213   140    157   48      40      96.0     168.5      54.0
# 100140     77  255   137    116   50      30     103.0     139.5      62.0
# 100157     64  221   172    115   66      15      81.5     131.5      75.5
# 100158    182  176    78    197   73      20     195.0     209.5      78.5
# 100164    108  186   219     77   43      43     121.0      89.0      50.0
#
# [244 rows x 9 columns]

# %%
def crop_nifti(input_file, output_dir, centre_coords, crop_size):
    image = nib.load(input_file)
    image_data = image.get_fdata()
    padding = tuple((crop, crop) for crop in crop_size)
    image_data = np.pad(image_data, padding, 'constant', constant_values=0)
    padded_center = tuple(centre + crop for centre, crop in zip(centre_coords, crop_size))
    start_coords = tuple(int(center - 0.5 * crop) for center, crop in zip(padded_center, crop_size))
    end_coords = tuple(start + crop for start, crop in zip(start_coords, crop_size))
    cropped_data = image_data[start_coords[0]:end_coords[0],
                              start_coords[1]:end_coords[1],
                              start_coords[2]:end_coords[2]]
    cropped_img = nib.Nifti1Image(cropped_data, image.affine, image.header)
    output_path = os.path.join(output_dir, ''.join(map(str, crop_size)), input_file.split('/')[-1])
    nib.save(cropped_img, output_path)
    print("Saved as", output_path)

# %%
# %%time
# !mkdir cropped/HBP/17017085
crop_size = (170, 170, 85)

for patient in patients:
    patient_int = int(os.path.basename(patient).split('.')[0])
    crop_nifti(patient, data_dir, tuple(patient_data.loc[patient_int, "v_center":"l_center"]), crop_size)
# Out:
# Saved as cropped/HBP/17017085/0007739.nii.gz
# Saved as cropped/HBP/17017085/0020491.nii.gz
# Saved as cropped/HBP/17017085/0050368.nii.gz
# Saved as cropped/HBP/17017085/0059047.nii.gz
# Saved as cropped/HBP/17017085/0063193.nii.gz
# Saved as cropped/HBP/17017085/0066509.nii.gz
# Saved as cropped/HBP/17017085/0074922.nii.gz
# Saved as cropped/HBP/17017085/0085260.nii.gz
# Saved as cropped/HBP/17017085/0085262.nii.gz
# Saved as cropped/HBP/17017085/0085265.nii.gz
# Saved as cropped/HBP/17017085/0085266.nii.gz
# Saved as cropped/HBP/17017085/0085268.nii.gz
# Saved as cropped/HBP/17017085/0085269.nii.gz
# Saved as cropped/HBP/17017085/0085287.nii.gz
# Saved as cropped/HBP/17017085/0085288.nii.gz
# Saved as cropped/HBP/17017085/0085289.nii.gz
# Saved as cropped/HBP/17017085/0085298.nii.gz
# Saved as cropped/HBP/17017085/0085299.nii.gz
# Saved as cropped/HBP/17017085/0085300.nii.gz
# Saved as cropped/HBP/17017085/0085301.nii.gz
# Saved as cropped/HBP/17017085/0085303.nii.gz
# Saved as cropped/HBP/17017085/0085310.nii.gz
# Saved as cropped/HBP/17017085/0085313.nii.gz
# Saved as cropped/HBP/17017085/0085314.nii.gz
# Saved as cropped/HBP/17017085/0085317.nii.gz
# Saved as cropped/HBP/17017085/0085319.nii.gz
# Saved as cropped/HBP/17017085/0085324.nii.gz
# Saved as cropped/HBP/17017085/0085327.nii.gz
# Saved as cropped/HBP/17017085/0085328.nii.gz
# Saved as cropped/HBP/17017085/0085346.nii.gz
# Saved as cropped/HBP/17017085/0085373.nii.gz
# Saved as cropped/HBP/17017085/0085374.nii.gz
# Saved as cropped/HBP/17017085/0085376.nii.gz
# Saved as cropped/HBP/17017085/0085393.nii.gz
# Saved as cropped/HBP/17017085/0085425.nii.gz
# Saved as cropped/HBP/17017085/0085430.nii.gz
# Saved as cropped/HBP/17017085/0085441.nii.gz
# Saved as cropped/HBP/17017085/0088124.nii.gz
# Saved as cropped/HBP/17017085/0088192.nii.gz
# Saved as cropped/HBP/17017085/0088911.nii.gz
# Saved as cropped/HBP/17017085/0088914.nii.gz
# Saved as cropped/HBP/17017085/0090246.nii.gz
# Saved as cropped/HBP/17017085/0099065.nii.gz
# Saved as cropped/HBP/17017085/0099645.nii.gz
# Saved as cropped/HBP/17017085/0099647.nii.gz
# Saved as cropped/HBP/17017085/0099648.nii.gz
# Saved as cropped/HBP/17017085/0099649.nii.gz
# Saved as cropped/HBP/17017085/0099650.nii.gz
# Saved as cropped/HBP/17017085/0099651.nii.gz
# Saved as cropped/HBP/17017085/0099652.nii.gz
# Saved as cropped/HBP/17017085/0099653.nii.gz
# Saved as cropped/HBP/17017085/0099654.nii.gz
# Saved as cropped/HBP/17017085/0099655.nii.gz
# Saved as cropped/HBP/17017085/0099656.nii.gz
# Saved as cropped/HBP/17017085/0099657.nii.gz
# Saved as cropped/HBP/17017085/0099658.nii.gz
# Saved as cropped/HBP/17017085/0099659.nii.gz
# Saved as cropped/HBP/17017085/0099660.nii.gz
# Saved as cropped/HBP/17017085/0099661.nii.gz
# Saved as cropped/HBP/17017085/0099662.nii.gz
# Saved as cropped/HBP/17017085/0099663.nii.gz
# Saved as cropped/HBP/17017085/0099664.nii.gz
# Saved as cropped/HBP/17017085/0099668.nii.gz
# Saved as cropped/HBP/17017085/0099669.nii.gz
# Saved as cropped/HBP/17017085/0099670.nii.gz
# Saved as cropped/HBP/17017085/0099672.nii.gz
# Saved as cropped/HBP/17017085/0099674.nii.gz
# Saved as cropped/HBP/17017085/0099675.nii.gz
# Saved as cropped/HBP/17017085/0099677.nii.gz
# Saved as cropped/HBP/17017085/0099681.nii.gz
# Saved as cropped/HBP/17017085/0099683.nii.gz
# Saved as cropped/HBP/17017085/0099684.nii.gz
# Saved as cropped/HBP/17017085/0099688.nii.gz
# Saved as cropped/HBP/17017085/0099689.nii.gz
# Saved as cropped/HBP/17017085/0099690.nii.gz
# Saved as cropped/HBP/17017085/0099694.nii.gz
# Saved as cropped/HBP/17017085/0099697.nii.gz
# Saved as cropped/HBP/17017085/0099701.nii.gz
# Saved as cropped/HBP/17017085/0099703.nii.gz
# Saved as cropped/HBP/17017085/0099704.nii.gz
# Saved as cropped/HBP/17017085/0099705.nii.gz
# Saved as cropped/HBP/17017085/0099708.nii.gz
# Saved as cropped/HBP/17017085/0099710.nii.gz
# Saved as cropped/HBP/17017085/0099711.nii.gz
# Saved as cropped/HBP/17017085/0099715.nii.gz
# Saved as cropped/HBP/17017085/0099717.nii.gz
# Saved as cropped/HBP/17017085/0099721.nii.gz
# Saved as cropped/HBP/17017085/0099724.nii.gz
# Saved as cropped/HBP/17017085/0099725.nii.gz
# Saved as cropped/HBP/17017085/0099726.nii.gz
# Saved as cropped/HBP/17017085/0099728.nii.gz
# Saved as cropped/HBP/17017085/0099732.nii.gz
# Saved as cropped/HBP/17017085/0099735.nii.gz
# Saved as cropped/HBP/17017085/0099736.nii.gz
# Saved as cropped/HBP/17017085/0099738.nii.gz
# Saved as cropped/HBP/17017085/0099740.nii.gz
# Saved as cropped/HBP/17017085/0099741.nii.gz
# Saved as cropped/HBP/17017085/0099742.nii.gz
# Saved as cropped/HBP/17017085/0099744.nii.gz
# Saved as cropped/HBP/17017085/0099748.nii.gz
# Saved as cropped/HBP/17017085/0099749.nii.gz
# Saved as cropped/HBP/17017085/0099752.nii.gz
# Saved as cropped/HBP/17017085/0099753.nii.gz
# Saved as cropped/HBP/17017085/0099755.nii.gz
# Saved as cropped/HBP/17017085/0099757.nii.gz
# Saved as cropped/HBP/17017085/0099762.nii.gz
# Saved as cropped/HBP/17017085/0099767.nii.gz
# Saved as cropped/HBP/17017085/0099768.nii.gz
# Saved as cropped/HBP/17017085/0099769.nii.gz
# Saved as cropped/HBP/17017085/0099773.nii.gz
# Saved as cropped/HBP/17017085/0099775.nii.gz
# Saved as cropped/HBP/17017085/0099776.nii.gz
# Saved as cropped/HBP/17017085/0099777.nii.gz
# Saved as cropped/HBP/17017085/0099780.nii.gz
# Saved as cropped/HBP/17017085/0099781.nii.gz
# Saved as cropped/HBP/17017085/0099782.nii.gz
# Saved as cropped/HBP/17017085/0099784.nii.gz
# Saved as cropped/HBP/17017085/0099785.nii.gz
# Saved as cropped/HBP/17017085/0099786.nii.gz
# Saved as cropped/HBP/17017085/0099787.nii.gz
# Saved as cropped/HBP/17017085/0099790.nii.gz
# Saved as cropped/HBP/17017085/0099791.nii.gz
# Saved as cropped/HBP/17017085/0099793.nii.gz
# Saved as cropped/HBP/17017085/0099794.nii.gz
# Saved as cropped/HBP/17017085/0099795.nii.gz
# Saved as cropped/HBP/17017085/0099796.nii.gz
# Saved as cropped/HBP/17017085/0099801.nii.gz
# Saved as cropped/HBP/17017085/0099812.nii.gz
# Saved as cropped/HBP/17017085/0099847.nii.gz
# Saved as cropped/HBP/17017085/0099865.nii.gz
# Saved as cropped/HBP/17017085/0099959.nii.gz
# Saved as cropped/HBP/17017085/0099961.nii.gz
# Saved as cropped/HBP/17017085/0099965.nii.gz
# Saved as cropped/HBP/17017085/0099967.nii.gz
# Saved as cropped/HBP/17017085/0099968.nii.gz
# Saved as cropped/HBP/17017085/0099969.nii.gz
# Saved as cropped/HBP/17017085/0099972.nii.gz
# Saved as cropped/HBP/17017085/0099973.nii.gz
# Saved as cropped/HBP/17017085/0099976.nii.gz
# Saved as cropped/HBP/17017085/0099977.nii.gz
# Saved as cropped/HBP/17017085/0099980.nii.gz
# Saved as cropped/HBP/17017085/0099981.nii.gz
# Saved as cropped/HBP/17017085/0099983.nii.gz
# Saved as cropped/HBP/17017085/0099985.nii.gz
# Saved as cropped/HBP/17017085/0099986.nii.gz
# Saved as cropped/HBP/17017085/0099987.nii.gz
# Saved as cropped/HBP/17017085/0099989.nii.gz
# Saved as cropped/HBP/17017085/0099991.nii.gz
# Saved as cropped/HBP/17017085/0099992.nii.gz
# Saved as cropped/HBP/17017085/0099993.nii.gz
# Saved as cropped/HBP/17017085/0099994.nii.gz
# Saved as cropped/HBP/17017085/0099995.nii.gz
# Saved as cropped/HBP/17017085/0099996.nii.gz
# Saved as cropped/HBP/17017085/0099997.nii.gz
# Saved as cropped/HBP/17017085/0099998.nii.gz
# Saved as cropped/HBP/17017085/0100000.nii.gz
# Saved as cropped/HBP/17017085/0100001.nii.gz
# Saved as cropped/HBP/17017085/0100002.nii.gz
# Saved as cropped/HBP/17017085/0100003.nii.gz
# Saved as cropped/HBP/17017085/0100005.nii.gz
# Saved as cropped/HBP/17017085/0100006.nii.gz
# Saved as cropped/HBP/17017085/0100007.nii.gz
# Saved as cropped/HBP/17017085/0100008.nii.gz
# Saved as cropped/HBP/17017085/0100010.nii.gz
# Saved as cropped/HBP/17017085/0100011.nii.gz
# Saved as cropped/HBP/17017085/0100012.nii.gz
# Saved as cropped/HBP/17017085/0100013.nii.gz
# Saved as cropped/HBP/17017085/0100017.nii.gz
# Saved as cropped/HBP/17017085/0100019.nii.gz
# Saved as cropped/HBP/17017085/0100020.nii.gz
# Saved as cropped/HBP/17017085/0100022.nii.gz
# Saved as cropped/HBP/17017085/0100023.nii.gz
# Saved as cropped/HBP/17017085/0100029.nii.gz
# Saved as cropped/HBP/17017085/0100031.nii.gz
# Saved as cropped/HBP/17017085/0100032.nii.gz
# Saved as cropped/HBP/17017085/0100034.nii.gz
# Saved as cropped/HBP/17017085/0100035.nii.gz
# Saved as cropped/HBP/17017085/0100037.nii.gz
# Saved as cropped/HBP/17017085/0100039.nii.gz
# Saved as cropped/HBP/17017085/0100040.nii.gz
# Saved as cropped/HBP/17017085/0100041.nii.gz
# Saved as cropped/HBP/17017085/0100044.nii.gz
# Saved as cropped/HBP/17017085/0100046.nii.gz
# Saved as cropped/HBP/17017085/0100048.nii.gz
# Saved as cropped/HBP/17017085/0100049.nii.gz
# Saved as cropped/HBP/17017085/0100050.nii.gz
# Saved as cropped/HBP/17017085/0100051.nii.gz
# Saved as cropped/HBP/17017085/0100052.nii.gz
# Saved as cropped/HBP/17017085/0100053.nii.gz
# Saved as cropped/HBP/17017085/0100055.nii.gz
# Saved as cropped/HBP/17017085/0100056.nii.gz
# Saved as cropped/HBP/17017085/0100059.nii.gz
# Saved as cropped/HBP/17017085/0100060.nii.gz
# Saved as cropped/HBP/17017085/0100062.nii.gz
# Saved as cropped/HBP/17017085/0100063.nii.gz
# Saved as cropped/HBP/17017085/0100065.nii.gz
# Saved as cropped/HBP/17017085/0100066.nii.gz
# Saved as cropped/HBP/17017085/0100068.nii.gz
# Saved as cropped/HBP/17017085/0100071.nii.gz
# Saved as cropped/HBP/17017085/0100073.nii.gz
# Saved as cropped/HBP/17017085/0100076.nii.gz
# Saved as cropped/HBP/17017085/0100082.nii.gz
# Saved as cropped/HBP/17017085/0100083.nii.gz
# Saved as cropped/HBP/17017085/0100084.nii.gz
# Saved as cropped/HBP/17017085/0100085.nii.gz
# Saved as cropped/HBP/17017085/0100088.nii.gz
# Saved as cropped/HBP/17017085/0100089.nii.gz
# Saved as cropped/HBP/17017085/0100090.nii.gz
# Saved as cropped/HBP/17017085/0100091.nii.gz
# Saved as cropped/HBP/17017085/0100092.nii.gz
# Saved as cropped/HBP/17017085/0100094.nii.gz
# Saved as cropped/HBP/17017085/0100096.nii.gz
# Saved as cropped/HBP/17017085/0100097.nii.gz
# Saved as cropped/HBP/17017085/0100098.nii.gz
# Saved as cropped/HBP/17017085/0100100.nii.gz
# Saved as cropped/HBP/17017085/0100101.nii.gz
# Saved as cropped/HBP/17017085/0100102.nii.gz
# Saved as cropped/HBP/17017085/0100103.nii.gz
# Saved as cropped/HBP/17017085/0100107.nii.gz
# Saved as cropped/HBP/17017085/0100108.nii.gz
# Saved as cropped/HBP/17017085/0100110.nii.gz
# Saved as cropped/HBP/17017085/0100111.nii.gz
# Saved as cropped/HBP/17017085/0100112.nii.gz
# Saved as cropped/HBP/17017085/0100115.nii.gz
# Saved as cropped/HBP/17017085/0100117.nii.gz
# Saved as cropped/HBP/17017085/0100118.nii.gz
# Saved as cropped/HBP/17017085/0100119.nii.gz
# Saved as cropped/HBP/17017085/0100120.nii.gz
# Saved as cropped/HBP/17017085/0100121.nii.gz
# Saved as cropped/HBP/17017085/0100122.nii.gz
# Saved as cropped/HBP/17017085/0100123.nii.gz
# Saved as cropped/HBP/17017085/0100124.nii.gz
# Saved as cropped/HBP/17017085/0100126.nii.gz
# Saved as cropped/HBP/17017085/0100127.nii.gz
# Saved as cropped/HBP/17017085/0100128.nii.gz
# Saved as cropped/HBP/17017085/0100130.nii.gz
# Saved as cropped/HBP/17017085/0100134.nii.gz
# Saved as cropped/HBP/17017085/0100136.nii.gz
# Saved as cropped/HBP/17017085/0100138.nii.gz
# Saved as cropped/HBP/17017085/0100139.nii.gz
# Saved as cropped/HBP/17017085/0100140.nii.gz
# Saved as cropped/HBP/17017085/0100157.nii.gz
# Saved as cropped/HBP/17017085/0100158.nii.gz
# Saved as cropped/HBP/17017085/0100164.nii.gz
# CPU times: user 1min 45s, sys: 1min 15s, total: 3min
# Wall time: 3min 3s

# %%
new_data_dir = os.path.join(data_dir, ''.join(map(str, crop_size)))
new_patients = sorted(glob.glob(os.path.join(new_data_dir, "*.nii.gz")))
print(len(new_patients))
# Out:
# 244

# %%
def nii_loader(filename) :
    nimg = nib.load(filename)
    return nimg.get_fdata() , nimg.affine, nimg.header

def visualize_all(dataset, cols, idxs, target_layer=10):
    import random
    fig = plt.figure()
    rows = len(idxs)//cols + 1
    i = 1
    for idx in idxs:
        image = dataset[idx]
        print(idx + 1, image)
        image_data, image_affine, image_header = nii_loader(image)
        target_image = image_data[:,:,target_layer]
        sub_fig = fig.add_subplot(rows, cols, i)
        sub_fig.get_xaxis().set_visible(False)
        sub_fig.get_yaxis().set_visible(False)
        sub_fig.imshow(target_image, cmap='gray')
        i += 1
    plt.show()

# %%
visualize_all(new_patients, 10, list(range(0, 50)), target_layer=crop_size[2]//2)
# Out:
# 1 cropped/HBP/17017085/0007739.nii.gz
# 2 cropped/HBP/17017085/0020491.nii.gz
# 3 cropped/HBP/17017085/0050368.nii.gz
# 4 cropped/HBP/17017085/0059047.nii.gz
# 5 cropped/HBP/17017085/0063193.nii.gz
# 6 cropped/HBP/17017085/0066509.nii.gz
# 7 cropped/HBP/17017085/0074922.nii.gz
# 8 cropped/HBP/17017085/0085260.nii.gz
# 9 cropped/HBP/17017085/0085262.nii.gz
# 10 cropped/HBP/17017085/0085265.nii.gz
# 11 cropped/HBP/17017085/0085266.nii.gz
# 12 cropped/HBP/17017085/0085268.nii.gz
# 13 cropped/HBP/17017085/0085269.nii.gz
# 14 cropped/HBP/17017085/0085287.nii.gz
# 15 cropped/HBP/17017085/0085288.nii.gz
# 16 cropped/HBP/17017085/0085289.nii.gz
# 17 cropped/HBP/17017085/0085298.nii.gz
# 18 cropped/HBP/17017085/0085299.nii.gz
# 19 cropped/HBP/17017085/0085300.nii.gz
# 20 cropped/HBP/17017085/0085301.nii.gz
# 21 cropped/HBP/17017085/0085303.nii.gz
# 22 cropped/HBP/17017085/0085310.nii.gz
# 23 cropped/HBP/17017085/0085313.nii.gz
# 24 cropped/HBP/17017085/0085314.nii.gz
# 25 cropped/HBP/17017085/0085317.nii.gz
# 190 cropped/HBP/17017085/0100055.nii.gz
# 191 cropped/HBP/17017085/0100056.nii.gz
# 192 cropped/HBP/17017085/0100059.nii.gz
# 193 cropped/HBP/17017085/0100060.nii.gz
# 194 cropped/HBP/17017085/0100062.nii.gz
# 195 cropped/HBP/17017085/0100063.nii.gz
# 196 cropped/HBP/17017085/0100065.nii.gz
# 197 cropped/HBP/17017085/0100066.nii.gz
# 198 cropped/HBP/17017085/0100068.nii.gz
# 199 cropped/HBP/17017085/0100071.nii.gz
# 200 cropped/HBP/17017085/0100073.nii.gz

# %%
visualize_all(new_patients, 10, list(range(200, 244)), target_layer=crop_size[2]//2)
# Out:
# 201 cropped/HBP/17017085/0100076.nii.gz
# 202 cropped/HBP/17017085/0100082.nii.gz
# 203 cropped/HBP/17017085/0100083.nii.gz
# 204 cropped/HBP/17017085/0100084.nii.gz
# 205 cropped/HBP/17017085/0100085.nii.gz
# 206 cropped/HBP/17017085/0100088.nii.gz
# 207 cropped/HBP/17017085/0100089.nii.gz
# 208 cropped/HBP/17017085/0100090.nii.gz
# 209 cropped/HBP/17017085/0100091.nii.gz
# 210 cropped/HBP/17017085/0100092.nii.gz
# 211 cropped/HBP/17017085/0100094.nii.gz
# 212 cropped/HBP/17017085/0100096.nii.gz
# 213 cropped/HBP/17017085/0100097.nii.gz
# 214 cropped/HBP/17017085/0100098.nii.gz
# 215 cropped/HBP/17017085/0100100.nii.gz
# 216 cropped/HBP/17017085/0100101.nii.gz
# 217 cropped/HBP/17017085/0100102.nii.gz
# 218 cropped/HBP/17017085/0100103.nii.gz
# 219 cropped/HBP/17017085/0100107.nii.gz
# 220 cropped/HBP/17017085/0100108.nii.gz
# 221 cropped/HBP/17017085/0100110.nii.gz
# 222 cropped/HBP/17017085/0100111.nii.gz
# 223 cropped/HBP/17017085/0100112.nii.gz
# 224 cropped/HBP/17017085/0100115.nii.gz
# 225 cropped/HBP/17017085/0100117.nii.gz
# 226 cropped/HBP/17017085/0100118.nii.gz
# 227 cropped/HBP/17017085/0100119.nii.gz
# 228 cropped/HBP/17017085/0100120.nii.gz
# 229 cropped/HBP/17017085/0100121.nii.gz
# 230 cropped/HBP/17017085/0100122.nii.gz
# 231 cropped/HBP/17017085/0100123.nii.gz
# 232 cropped/HBP/17017085/0100124.nii.gz
# 233 cropped/HBP/17017085/0100126.nii.gz
# 234 cropped/HBP/17017085/0100127.nii.gz
# 235 cropped/HBP/17017085/0100128.nii.gz
# 236 cropped/HBP/17017085/0100130.nii.gz
# 237 cropped/HBP/17017085/0100134.nii.gz
# 238 cropped/HBP/17017085/0100136.nii.gz
# 239 cropped/HBP/17017085/0100138.nii.gz
# 240 cropped/HBP/17017085/0100139.nii.gz
# 241 cropped/HBP/17017085/0100140.nii.gz
# 242 cropped/HBP/17017085/0100157.nii.gz
# 243 cropped/HBP/17017085/0100158.nii.gz
# 244 cropped/HBP/17017085/0100164.nii.gz
