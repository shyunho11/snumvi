# %%
# !nvidia-smi
# Out:
# Mon Jul  3 08:13:07 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:8A:00.0 Off |                  Off |
# | N/A   33C    P0    41W / 300W |      0MiB / 32768MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch

from monai.apps import download_and_extract
from monai.config import print_config
from monai.utils import set_determinism

print_config()
set_determinism(0)

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.filterwarnings("ignore", category=UserWarning)

#pip install torch==1.12.1+cu113 torchvision==0.13.1+cu113 torchaudio==0.12.1 --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# MONAI version: 1.1.0
# Numpy version: 1.22.3
# Pytorch version: 1.12.1+cu113
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: a2ec3752f54bfc3b40e7952234fbeb5452ed63e3
# MONAI __file__: /home/fastmri2/.conda/envs/snumvi/lib/python3.8/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.4.8
# Nibabel version: 5.0.0
# scikit-image version: 0.19.3
# Pillow version: 9.5.0
# Tensorboard version: 2.11.0
# gdown version: 4.6.0
# TorchVision version: 0.13.1+cu113
# tqdm version: 4.64.1
# lmdb version: 1.4.0
# psutil version: 5.9.5
# pandas version: 1.5.2
# einops version: 0.6.0
# transformers version: 4.25.1
# mlflow version: 2.1.1
# pynrrd version: 1.0.0
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %%
directory = "temp"
if not os.path.exists(directory):
    os.makedirs(directory)
root_dir = tempfile.mkdtemp() if directory is None else directory
data_dir = "cropped/909045"

# %%
#!pip install openpyxl

patient_data = pd.read_excel("new_dataload.xlsx", usecols=['File_Name', 'MVI']).set_index('File_Name')
print(patient_data)
# Out:
#                 MVI
# File_Name
# 0007739.nii.gz    1
# 0020491.nii.gz    1
# 0050368.nii.gz    0
# 0059047.nii.gz    0
# 0063193.nii.gz    1
# ...             ...
# 349.nii.gz        0
# 350.nii.gz        1
# 351.nii.gz        1
# 352.nii.gz        1
# 355.nii.gz        1
#
# [494 rows x 1 columns]

# %%
import random

train_images = sorted(glob.glob(os.path.join(data_dir, "*.nii.gz")))
train_labels = [patient_data.loc[os.path.basename(x), "MVI"] for x in train_images]
#train_labels = torch.nn.functional.one_hot(torch.as_tensor(train_labels)).float()
train_labels = torch.as_tensor(train_labels)
data_list = list(zip(train_images, train_labels))
random.shuffle(data_list)
data_dicts = [{"image": image, "label": label} for image, label in data_list]
print(len(data_dicts))
print(data_dicts[0])
# Out:
# 475
# {'image': 'cropped/909045/0100051.nii.gz', 'label': tensor(0)}

# %%
train_files, val_files = data_dicts[:400], data_dicts[400:]
set_determinism(seed=0)

# %%
def nii_loader(filename) :
    import nibabel as nib
    import numpy as np
    import matplotlib.pyplot as plt
    nimg = nib.load( filename )
    return nimg.get_fdata() , nimg.affine, nimg.header 

def visualize(dataset, idx=0):
    import matplotlib.pyplot as plt    

    image = dataset[idx]['image']
    label = dataset[idx]['label']
    image_data, image_affine, image_header = nii_loader(image)
    
    print('[file path]', image)
    print('[dimension]', image_data.shape)
    print('[label]', label)
    target_image = image_data[:,:,image_data.shape[2]//2]

    plt.imshow(target_image, cmap='gray' )
    plt.show()
    return tuple(image_data.shape)

# %%
spatial_size = visualize(val_files, idx=1)
# Out:
# [file path] cropped/909045/0099742.nii.gz
# [dimension] (90, 90, 45)
# [label] tensor(1)

# %%
from monai.transforms import (
    Compose,
    LoadImaged,
    EnsureChannelFirstd,
    AddChanneld,
    Orientationd,
    ScaleIntensityRanged,
    CropForegroundd,
    RandAffined,
    SpatialPadd,
    EnsureTyped,
)

# %%
# ScaleIntensityRanged min/max differ by organs
# for liver, min = 30 + 150/2 = 105, max = 30 - 150/2 = -45
# see more info here https://radiopaedia.org/articles/windowing-ct

from monai.transforms import Compose

train_transforms = Compose(
    [
        LoadImaged(keys=["image"]),
        EnsureChannelFirstd(keys=["image"]),
        #AddChanneld(keys=["label"]),
        Orientationd(keys=["image"], axcodes="RAS"),
        #ScaleIntensityRanged(keys=["image"], a_min=-45, a_max=105, b_min=0.0, b_max=1.0, clip=True),
        CropForegroundd(keys=["image"], source_key="image"),
        RandAffined(
            keys=["image"],
            mode=("bilinear"),
            prob=1.0, spatial_size=spatial_size,
            rotate_range=(0, 0, 0),
            scale_range=(0, 0, 0)),
        SpatialPadd(keys=["image"], spatial_size=spatial_size),
        EnsureTyped(keys=["image"]),
    ]
)
val_transforms = Compose(
    [
        LoadImaged(keys=["image"]),
        EnsureChannelFirstd(keys=["image"]),
        #AddChanneld(keys=["label"]),
        Orientationd(keys=["image"], axcodes="RAS"),
        #ScaleIntensityRanged(keys=["image"], a_min=-45, a_max=105, b_min=0.0, b_max=1.0, clip=True),
        CropForegroundd(keys=["image"], source_key="image"),
        SpatialPadd(keys=["image"], spatial_size=spatial_size),
        EnsureTyped(keys=["image"]),
    ]
)

# %%
from monai.data import CacheDataset, DataLoader, Dataset
from monai.utils import first, set_determinism

check_ds = Dataset(data=train_files, transform=train_transforms)
check_loader = DataLoader(check_ds, batch_size=1)
check_data = first(check_loader)
image, label = (check_data["image"][0][0], check_data["label"])
print(f"image shape: {image.shape}, label shape: {label.shape}")

plt.imshow(image[:, :, spatial_size[2]//2], cmap="gray")
plt.show()
# Out:
# image shape: torch.Size([90, 90, 45]), label shape: torch.Size([1])

# %%
from monai.data import CacheDataset, DataLoader

train_ds = CacheDataset(data=train_files, transform=train_transforms, cache_rate=1.0, num_workers=4, progress=True)
train_loader = DataLoader(train_ds, batch_size=4, shuffle=True, num_workers=10)

val_ds = CacheDataset(data=val_files, transform=val_transforms, cache_rate=1.0, num_workers=4, progress=True)
val_loader = DataLoader(val_ds, batch_size=1, num_workers=10)
# Out:
# Loading dataset: 100%|███████████████████████| 400/400 [00:03<00:00, 102.26it/s]
# Loading dataset: 100%|█████████████████████████| 75/75 [00:00<00:00, 106.21it/s]

# %%
from monai.networks.nets import ViT

divisor = 5

device = torch.device("cuda:0")
model = ViT(
    in_channels=1,
    img_size=spatial_size,
    patch_size=tuple([int(x/divisor) for x in spatial_size]),
    pos_embed='conv',
    classification=True
).to(device)

# %%
from monai.metrics import ROCAUCMetric
from torch.utils.tensorboard import SummaryWriter

loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), 1e-6)
auc_metric = ROCAUCMetric()
writer = SummaryWriter()
max_epochs = 100
save_interval = 10
val_interval = 1
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
metric_values = []
acc_values = []
model_name = 'ViT' + f'{divisor}x{divisor}'

# %%
# %%time

import time
from monai.data import decollate_batch
from monai.transforms import EnsureType, Activations, AsDiscrete

epoch_len = len(train_ds) // train_loader.batch_size
post_pred = Compose([EnsureType(), Activations(softmax=True)])
post_label = Compose([EnsureType(), AsDiscrete(to_onehot=2)])

for epoch in range(max_epochs):
    tic_epoch = time.time()
    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step += 1
        inputs, labels = batch_data["image"].to(device), batch_data["label"].to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs[0], labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        if step % 5 ==0:
            print(f"\nepoch {epoch + 1}/{max_epochs} steps {step}/{len(train_ds) // train_loader.batch_size}, |train-loss: {loss.item():.4f}", end='')
        writer.add_scalar("train_loss", loss.item(), epoch_len * epoch + step)
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    toc_epoch = time.time()
    dur_epoch = toc_epoch - tic_epoch
    print(f" |avg-loss: {epoch_loss:.4f} dur {dur_epoch:.1f}s ", end='')

    if (epoch + 1) % val_interval == 0:
        model.eval()
        val_count = 0
        val_correct = 0.0
        
        with torch.no_grad():
            y_pred = torch.tensor([], dtype=torch.float32, device=device)
            y = torch.tensor([], dtype=torch.long, device=device)
            for val_data in val_loader:
                val_images, val_labels = val_data["image"].to(device), val_data["label"].to(device)
                y_pred = torch.cat([y_pred, model(val_images)[0]], dim=0)
                y = torch.cat([y, val_labels], dim=0)
            
            acc_value = torch.eq(y_pred.argmax(dim=1), y)
            acc_metric = acc_value.sum().item() / len(acc_value)
            y_onehot = [post_label(i) for i in decollate_batch(y)]
            y_pred_act = [post_pred(i) for i in decollate_batch(y_pred)]
            auc_metric(y_pred_act, y_onehot)
            auc_result = auc_metric.aggregate()
            auc_metric.reset()
            del y_pred_act, y_onehot
            metric_values.append(auc_result)
            
            if acc_metric > best_metric:
                best_metric = acc_metric
                best_metric_epoch = epoch + 1
                torch.save(model.state_dict(), os.path.join(root_dir, "{}_model_best.pth".format(model_name)))
                torch.save(optimizer.state_dict(), os.path.join(root_dir, "{}_optim_best.pth".format(model_name)))
                print("|best model saved", end="")
            print("\nval-acc: {:.4f} val-AUC: {:.4f} |best-acc: {:.4f} at epoch {}".format(
                acc_metric, auc_result, best_metric, best_metric_epoch
            ), end='')
    
    if (epoch+1) % save_interval == 0:
        torch.save(model.state_dict(), os.path.join(root_dir, "{}_model_{:04d}.pth".format(model_name, epoch+1)))
        torch.save(optimizer.state_dict(), os.path.join(root_dir, "{}_optim_{:04d}.pth".format(model_name, epoch+1)))
        print("|{}ep model saved".format(epoch+1), end='')
                            
print(f"\ntrain completed, best_metric: {best_metric:.4f} at epoch: {best_metric_epoch} for {max_epochs} epoches")
# Out:
# epoch 1/100 steps 5/100, |train-loss: 0.5843
# epoch 1/100 steps 10/100, |train-loss: 0.8480
# epoch 1/100 steps 15/100, |train-loss: 0.6013
# epoch 1/100 steps 20/100, |train-loss: 0.8504
# epoch 1/100 steps 25/100, |train-loss: 0.6789
# epoch 1/100 steps 30/100, |train-loss: 0.7176
# epoch 1/100 steps 35/100, |train-loss: 0.7007
# epoch 1/100 steps 40/100, |train-loss: 0.6901
# epoch 1/100 steps 45/100, |train-loss: 0.6943
# epoch 1/100 steps 50/100, |train-loss: 0.7029
# epoch 1/100 steps 55/100, |train-loss: 0.6998
# epoch 1/100 steps 60/100, |train-loss: 0.6943
# epoch 1/100 steps 65/100, |train-loss: 0.6990
# epoch 1/100 steps 70/100, |train-loss: 0.6965
# epoch 1/100 steps 75/100, |train-loss: 0.6911
# epoch 1/100 steps 80/100, |train-loss: 0.6925
# epoch 1/100 steps 85/100, |train-loss: 0.6931
# epoch 1/100 steps 90/100, |train-loss: 0.6917
# epoch 1/100 steps 95/100, |train-loss: 0.6892
# epoch 1/100 steps 100/100, |train-loss: 0.6836 |avg-loss: 0.7051 dur 18.2s |best model saved
# val-acc: 0.6400 val-AUC: 0.5131 |best-acc: 0.6400 at epoch 1
# epoch 2/100 steps 5/100, |train-loss: 0.6932
# epoch 2/100 steps 10/100, |train-loss: 0.6943
# epoch 2/100 steps 15/100, |train-loss: 0.6918
# epoch 2/100 steps 20/100, |train-loss: 0.6920
# epoch 2/100 steps 25/100, |train-loss: 0.6924
# epoch 2/100 steps 30/100, |train-loss: 0.6812
# epoch 2/100 steps 35/100, |train-loss: 0.6764
# epoch 2/100 steps 40/100, |train-loss: 0.6939
# epoch 2/100 steps 45/100, |train-loss: 0.6370
# epoch 2/100 steps 50/100, |train-loss: 0.6307
# epoch 2/100 steps 55/100, |train-loss: 0.6360
# epoch 2/100 steps 60/100, |train-loss: 0.6994
# epoch 2/100 steps 65/100, |train-loss: 0.7062
# epoch 2/100 steps 70/100, |train-loss: 0.7430
# epoch 2/100 steps 75/100, |train-loss: 0.7627
# epoch 2/100 steps 80/100, |train-loss: 0.6504
# epoch 2/100 steps 85/100, |train-loss: 0.6591
# epoch 2/100 steps 90/100, |train-loss: 0.6902
# epoch 2/100 steps 95/100, |train-loss: 0.6869
# epoch 2/100 steps 100/100, |train-loss: 0.6855 |avg-loss: 0.6896 dur 12.6s
# val-acc: 0.6400 val-AUC: 0.5008 |best-acc: 0.6400 at epoch 1
# epoch 3/100 steps 5/100, |train-loss: 0.7593
# epoch 3/100 steps 10/100, |train-loss: 0.7797
# epoch 3/100 steps 15/100, |train-loss: 0.6975
# epoch 3/100 steps 20/100, |train-loss: 0.6628
# epoch 3/100 steps 25/100, |train-loss: 0.6510
# epoch 3/100 steps 30/100, |train-loss: 0.6248
# epoch 3/100 steps 35/100, |train-loss: 0.6118
# epoch 3/100 steps 40/100, |train-loss: 0.7753
# epoch 3/100 steps 45/100, |train-loss: 0.6333
# epoch 3/100 steps 50/100, |train-loss: 0.7400
# epoch 3/100 steps 55/100, |train-loss: 0.7190
# epoch 3/100 steps 60/100, |train-loss: 0.6754
# epoch 3/100 steps 65/100, |train-loss: 0.6910
# epoch 3/100 steps 70/100, |train-loss: 0.6935
# epoch 3/100 steps 75/100, |train-loss: 0.6853
# epoch 3/100 steps 80/100, |train-loss: 0.6677
# epoch 3/100 steps 85/100, |train-loss: 0.7100
# epoch 3/100 steps 90/100, |train-loss: 0.6806
# epoch 3/100 steps 95/100, |train-loss: 0.6930
# epoch 3/100 steps 100/100, |train-loss: 0.6739 |avg-loss: 0.6886 dur 12.7s
# val-acc: 0.6400 val-AUC: 0.4992 |best-acc: 0.6400 at epoch 1
# epoch 4/100 steps 5/100, |train-loss: 0.6752
# epoch 4/100 steps 10/100, |train-loss: 0.6924
# epoch 4/100 steps 15/100, |train-loss: 0.6982
# epoch 4/100 steps 20/100, |train-loss: 0.6573
# epoch 4/100 steps 25/100, |train-loss: 0.6966
# epoch 4/100 steps 30/100, |train-loss: 0.7043
# epoch 4/100 steps 35/100, |train-loss: 0.8158
# epoch 4/100 steps 40/100, |train-loss: 0.6923
# epoch 4/100 steps 45/100, |train-loss: 0.6899
# epoch 4/100 steps 50/100, |train-loss: 0.6779
# epoch 4/100 steps 55/100, |train-loss: 0.7040
# epoch 4/100 steps 60/100, |train-loss: 0.6755
# epoch 4/100 steps 65/100, |train-loss: 0.6931
# epoch 4/100 steps 70/100, |train-loss: 0.6505
# epoch 4/100 steps 75/100, |train-loss: 0.6981
# epoch 4/100 steps 80/100, |train-loss: 0.6905
# epoch 4/100 steps 85/100, |train-loss: 0.6961
# epoch 4/100 steps 90/100, |train-loss: 0.7470
# epoch 4/100 steps 95/100, |train-loss: 0.6499
# epoch 4/100 steps 100/100, |train-loss: 0.6403 |avg-loss: 0.6892 dur 12.7s
# val-acc: 0.6400 val-AUC: 0.4938 |best-acc: 0.6400 at epoch 1
# epoch 5/100 steps 5/100, |train-loss: 0.7089
# epoch 5/100 steps 10/100, |train-loss: 0.8266
# epoch 5/100 steps 15/100, |train-loss: 0.5824
# epoch 5/100 steps 20/100, |train-loss: 0.5912
# epoch 5/100 steps 25/100, |train-loss: 0.6387
# epoch 5/100 steps 30/100, |train-loss: 0.6887
# epoch 5/100 steps 35/100, |train-loss: 0.6938
# epoch 5/100 steps 40/100, |train-loss: 0.7036
# epoch 5/100 steps 45/100, |train-loss: 0.6925
# epoch 5/100 steps 50/100, |train-loss: 0.6895
# epoch 5/100 steps 55/100, |train-loss: 0.6899
# epoch 5/100 steps 60/100, |train-loss: 0.6992
# epoch 5/100 steps 65/100, |train-loss: 0.6933
# epoch 5/100 steps 70/100, |train-loss: 0.6900
# epoch 5/100 steps 75/100, |train-loss: 0.6926
# epoch 5/100 steps 80/100, |train-loss: 0.6908
# epoch 5/100 steps 85/100, |train-loss: 0.6930
# epoch 5/100 steps 90/100, |train-loss: 0.6932
# epoch 5/100 steps 95/100, |train-loss: 0.6865
# epoch 5/100 steps 100/100, |train-loss: 0.6863 |avg-loss: 0.6907 dur 12.9s
# val-acc: 0.6400 val-AUC: 0.5046 |best-acc: 0.6400 at epoch 1
# epoch 6/100 steps 5/100, |train-loss: 0.6802
# epoch 6/100 steps 10/100, |train-loss: 0.6916
# epoch 6/100 steps 15/100, |train-loss: 0.7100
# epoch 6/100 steps 20/100, |train-loss: 0.6935
# epoch 6/100 steps 25/100, |train-loss: 0.7044
# epoch 6/100 steps 30/100, |train-loss: 0.7073
# epoch 6/100 steps 35/100, |train-loss: 0.6918
# epoch 6/100 steps 40/100, |train-loss: 0.6813
# epoch 6/100 steps 45/100, |train-loss: 0.6902
# epoch 6/100 steps 50/100, |train-loss: 0.6755
# epoch 6/100 steps 55/100, |train-loss: 0.6528
# epoch 6/100 steps 60/100, |train-loss: 0.6687
# epoch 6/100 steps 65/100, |train-loss: 0.6891
# epoch 6/100 steps 70/100, |train-loss: 0.6927
# epoch 6/100 steps 75/100, |train-loss: 0.6941
# epoch 6/100 steps 80/100, |train-loss: 0.6966
# epoch 6/100 steps 85/100, |train-loss: 0.6648
# epoch 6/100 steps 90/100, |train-loss: 0.5825
# epoch 6/100 steps 95/100, |train-loss: 0.5994
# epoch 6/100 steps 100/100, |train-loss: 0.5685 |avg-loss: 0.6859 dur 12.3s
# val-acc: 0.6400 val-AUC: 0.4954 |best-acc: 0.6400 at epoch 1
# epoch 7/100 steps 5/100, |train-loss: 0.5895
# epoch 7/100 steps 10/100, |train-loss: 0.5988
# epoch 7/100 steps 15/100, |train-loss: 0.6023
# epoch 7/100 steps 20/100, |train-loss: 0.9779
# epoch 7/100 steps 25/100, |train-loss: 0.7059
# epoch 7/100 steps 30/100, |train-loss: 0.6767
# epoch 7/100 steps 35/100, |train-loss: 0.6893
# epoch 7/100 steps 40/100, |train-loss: 0.6928
# epoch 7/100 steps 45/100, |train-loss: 0.6886
# epoch 7/100 steps 50/100, |train-loss: 0.6923
# epoch 7/100 steps 55/100, |train-loss: 0.6926
# epoch 7/100 steps 60/100, |train-loss: 0.6929
# epoch 7/100 steps 65/100, |train-loss: 0.6995
# epoch 7/100 steps 70/100, |train-loss: 0.6937
# epoch 7/100 steps 75/100, |train-loss: 0.6983
# epoch 7/100 steps 80/100, |train-loss: 0.6879
# epoch 7/100 steps 85/100, |train-loss: 0.6830
# epoch 7/100 steps 90/100, |train-loss: 0.6975
# epoch 7/100 steps 95/100, |train-loss: 0.6945
# epoch 7/100 steps 100/100, |train-loss: 0.6908 |avg-loss: 0.6900 dur 12.7s
# val-acc: 0.6400 val-AUC: 0.4892 |best-acc: 0.6400 at epoch 1
# epoch 8/100 steps 5/100, |train-loss: 0.6867
# epoch 8/100 steps 10/100, |train-loss: 0.6929
# epoch 8/100 steps 15/100, |train-loss: 0.6927
# epoch 8/100 steps 20/100, |train-loss: 0.7026
# epoch 8/100 steps 25/100, |train-loss: 0.6908
# epoch 8/100 steps 30/100, |train-loss: 0.6770
# epoch 8/100 steps 35/100, |train-loss: 0.7115
# epoch 8/100 steps 40/100, |train-loss: 0.6799
# epoch 8/100 steps 45/100, |train-loss: 0.6996
# epoch 8/100 steps 50/100, |train-loss: 0.6336
# epoch 8/100 steps 55/100, |train-loss: 0.6498
# epoch 8/100 steps 60/100, |train-loss: 0.6176
# epoch 8/100 steps 65/100, |train-loss: 0.8893
# epoch 8/100 steps 70/100, |train-loss: 0.7155
# epoch 8/100 steps 75/100, |train-loss: 0.5249
# epoch 8/100 steps 80/100, |train-loss: 0.5890
# epoch 8/100 steps 85/100, |train-loss: 0.4498
# epoch 8/100 steps 90/100, |train-loss: 0.6401
# epoch 8/100 steps 95/100, |train-loss: 0.6412
# epoch 8/100 steps 100/100, |train-loss: 0.7199 |avg-loss: 0.6868 dur 12.8s
# val-acc: 0.6400 val-AUC: 0.4931 |best-acc: 0.6400 at epoch 1
# epoch 9/100 steps 5/100, |train-loss: 0.7026
# epoch 9/100 steps 10/100, |train-loss: 0.6896
# epoch 9/100 steps 15/100, |train-loss: 0.6940
# epoch 9/100 steps 20/100, |train-loss: 0.6926
# epoch 9/100 steps 25/100, |train-loss: 0.6909
# epoch 9/100 steps 30/100, |train-loss: 0.6919
# epoch 9/100 steps 35/100, |train-loss: 0.6917
# epoch 9/100 steps 40/100, |train-loss: 0.6929
# epoch 9/100 steps 45/100, |train-loss: 0.6925
# epoch 9/100 steps 50/100, |train-loss: 0.6931
# epoch 9/100 steps 55/100, |train-loss: 0.6934
# epoch 9/100 steps 60/100, |train-loss: 0.6918
# epoch 9/100 steps 65/100, |train-loss: 0.6905
# epoch 9/100 steps 70/100, |train-loss: 0.6942
# epoch 9/100 steps 75/100, |train-loss: 0.6922
# epoch 9/100 steps 80/100, |train-loss: 0.6908
# epoch 9/100 steps 85/100, |train-loss: 0.6946
# epoch 9/100 steps 90/100, |train-loss: 0.6931
# epoch 9/100 steps 95/100, |train-loss: 0.6933
# epoch 9/100 steps 100/100, |train-loss: 0.6933 |avg-loss: 0.6926 dur 12.4s
# val-acc: 0.6400 val-AUC: 0.5000 |best-acc: 0.6400 at epoch 1
# epoch 10/100 steps 5/100, |train-loss: 0.6929
# epoch 10/100 steps 10/100, |train-loss: 0.6926
# epoch 10/100 steps 15/100, |train-loss: 0.6905
# epoch 10/100 steps 20/100, |train-loss: 0.6907
# epoch 10/100 steps 25/100, |train-loss: 0.6951
# epoch 10/100 steps 30/100, |train-loss: 0.6953
# epoch 10/100 steps 35/100, |train-loss: 0.6904
# epoch 10/100 steps 40/100, |train-loss: 0.6926
# epoch 10/100 steps 45/100, |train-loss: 0.6892
# epoch 10/100 steps 50/100, |train-loss: 0.6926
# epoch 10/100 steps 55/100, |train-loss: 0.6935
# epoch 10/100 steps 60/100, |train-loss: 0.6999
# epoch 10/100 steps 65/100, |train-loss: 0.6931
# epoch 10/100 steps 70/100, |train-loss: 0.6874
# epoch 10/100 steps 75/100, |train-loss: 0.6987
# epoch 10/100 steps 80/100, |train-loss: 0.6975
# epoch 10/100 steps 85/100, |train-loss: 0.6801
# epoch 10/100 steps 90/100, |train-loss: 0.7039
# epoch 10/100 steps 95/100, |train-loss: 0.6715
# epoch 10/100 steps 100/100, |train-loss: 0.6907 |avg-loss: 0.6916 dur 13.3s
# val-acc: 0.6400 val-AUC: 0.4946 |best-acc: 0.6400 at epoch 1|10ep model saved
# epoch 11/100 steps 5/100, |train-loss: 0.7166
# epoch 11/100 steps 10/100, |train-loss: 0.6830
# epoch 11/100 steps 15/100, |train-loss: 0.6926
# epoch 11/100 steps 20/100, |train-loss: 0.6801
# epoch 11/100 steps 25/100, |train-loss: 0.6917
# epoch 11/100 steps 30/100, |train-loss: 0.6858
# epoch 11/100 steps 35/100, |train-loss: 0.7249
# epoch 11/100 steps 40/100, |train-loss: 0.6283
# epoch 11/100 steps 45/100, |train-loss: 0.7490
# epoch 11/100 steps 50/100, |train-loss: 0.6402
# epoch 11/100 steps 55/100, |train-loss: 0.7020
# epoch 11/100 steps 60/100, |train-loss: 0.6191
# epoch 11/100 steps 65/100, |train-loss: 0.5443
# epoch 11/100 steps 70/100, |train-loss: 0.3296
# epoch 11/100 steps 75/100, |train-loss: 0.7694
# epoch 11/100 steps 80/100, |train-loss: 0.6775
# epoch 11/100 steps 85/100, |train-loss: 0.6883
# epoch 11/100 steps 90/100, |train-loss: 0.6929
# epoch 11/100 steps 95/100, |train-loss: 0.6931
# epoch 11/100 steps 100/100, |train-loss: 0.6929 |avg-loss: 0.6901 dur 12.4s
# val-acc: 0.6400 val-AUC: 0.5085 |best-acc: 0.6400 at epoch 1
# epoch 12/100 steps 5/100, |train-loss: 0.6931
# epoch 12/100 steps 10/100, |train-loss: 0.6931
# epoch 12/100 steps 15/100, |train-loss: 0.6932
# epoch 12/100 steps 20/100, |train-loss: 0.6932
# epoch 12/100 steps 25/100, |train-loss: 0.6931
# epoch 12/100 steps 30/100, |train-loss: 0.6931
# epoch 12/100 steps 35/100, |train-loss: 0.6932
# epoch 12/100 steps 40/100, |train-loss: 0.6931
# epoch 12/100 steps 45/100, |train-loss: 0.6930
# epoch 12/100 steps 50/100, |train-loss: 0.6930
# epoch 12/100 steps 55/100, |train-loss: 0.6931
# epoch 12/100 steps 60/100, |train-loss: 0.6931
# epoch 12/100 steps 65/100, |train-loss: 0.6930
# epoch 12/100 steps 70/100, |train-loss: 0.6931
# epoch 12/100 steps 75/100, |train-loss: 0.6930
# epoch 12/100 steps 80/100, |train-loss: 0.6929
# epoch 12/100 steps 85/100, |train-loss: 0.6930
# epoch 12/100 steps 90/100, |train-loss: 0.6931
# epoch 12/100 steps 95/100, |train-loss: 0.6930
# epoch 12/100 steps 100/100, |train-loss: 0.6931 |avg-loss: 0.6931 dur 12.8s
# val-acc: 0.6400 val-AUC: 0.5085 |best-acc: 0.6400 at epoch 1
# epoch 13/100 steps 5/100, |train-loss: 0.6934
# epoch 13/100 steps 10/100, |train-loss: 0.6928
# epoch 13/100 steps 15/100, |train-loss: 0.6931
# epoch 13/100 steps 20/100, |train-loss: 0.6932
# epoch 13/100 steps 25/100, |train-loss: 0.6931
# epoch 13/100 steps 30/100, |train-loss: 0.6931
# epoch 13/100 steps 35/100, |train-loss: 0.6931
# epoch 13/100 steps 40/100, |train-loss: 0.6928
# epoch 13/100 steps 45/100, |train-loss: 0.6931
# epoch 13/100 steps 50/100, |train-loss: 0.6931
# epoch 13/100 steps 55/100, |train-loss: 0.6926
# epoch 13/100 steps 60/100, |train-loss: 0.6931
# epoch 13/100 steps 65/100, |train-loss: 0.6928
# epoch 13/100 steps 70/100, |train-loss: 0.6934
# epoch 13/100 steps 75/100, |train-loss: 0.6932
# epoch 13/100 steps 80/100, |train-loss: 0.6931
# epoch 13/100 steps 85/100, |train-loss: 0.6932
# epoch 13/100 steps 90/100, |train-loss: 0.6933
# epoch 13/100 steps 95/100, |train-loss: 0.6931
# epoch 13/100 steps 100/100, |train-loss: 0.6930 |avg-loss: 0.6931 dur 12.5s
# val-acc: 0.6400 val-AUC: 0.5000 |best-acc: 0.6400 at epoch 1
# epoch 14/100 steps 5/100, |train-loss: 0.6925
# epoch 14/100 steps 10/100, |train-loss: 0.6927
# epoch 14/100 steps 15/100, |train-loss: 0.6928
# epoch 14/100 steps 20/100, |train-loss: 0.6928
# epoch 14/100 steps 25/100, |train-loss: 0.6928
# epoch 14/100 steps 30/100, |train-loss: 0.6926
# epoch 14/100 steps 35/100, |train-loss: 0.6928
# epoch 14/100 steps 40/100, |train-loss: 0.6929
# epoch 14/100 steps 45/100, |train-loss: 0.6931
# epoch 14/100 steps 50/100, |train-loss: 0.6939
# epoch 14/100 steps 55/100, |train-loss: 0.6937
# epoch 14/100 steps 60/100, |train-loss: 0.6929
# epoch 14/100 steps 65/100, |train-loss: 0.6930
# epoch 14/100 steps 70/100, |train-loss: 0.6930
# epoch 14/100 steps 75/100, |train-loss: 0.6936
# epoch 14/100 steps 80/100, |train-loss: 0.6927
# epoch 14/100 steps 85/100, |train-loss: 0.6922
# epoch 14/100 steps 90/100, |train-loss: 0.6930
# epoch 14/100 steps 95/100, |train-loss: 0.6932
# epoch 14/100 steps 100/100, |train-loss: 0.6926 |avg-loss: 0.6930 dur 12.5s
# val-acc: 0.6400 val-AUC: 0.4946 |best-acc: 0.6400 at epoch 1
# epoch 15/100 steps 5/100, |train-loss: 0.6926
# epoch 15/100 steps 10/100, |train-loss: 0.6933
# epoch 15/100 steps 15/100, |train-loss: 0.6922
# epoch 15/100 steps 20/100, |train-loss: 0.6926
# epoch 15/100 steps 25/100, |train-loss: 0.6933
# epoch 15/100 steps 30/100, |train-loss: 0.6932
# epoch 15/100 steps 35/100, |train-loss: 0.6923
# epoch 15/100 steps 40/100, |train-loss: 0.6931
# epoch 15/100 steps 45/100, |train-loss: 0.6926
# epoch 15/100 steps 50/100, |train-loss: 0.6924
# epoch 15/100 steps 55/100, |train-loss: 0.6925
# epoch 15/100 steps 60/100, |train-loss: 0.6936
# epoch 15/100 steps 65/100, |train-loss: 0.6925
# epoch 15/100 steps 70/100, |train-loss: 0.6915
# epoch 15/100 steps 75/100, |train-loss: 0.6925
# epoch 15/100 steps 80/100, |train-loss: 0.6937
# epoch 15/100 steps 85/100, |train-loss: 0.6931
# epoch 15/100 steps 90/100, |train-loss: 0.6936
# epoch 15/100 steps 95/100, |train-loss: 0.6912
# epoch 15/100 steps 100/100, |train-loss: 0.6929 |avg-loss: 0.6929 dur 12.6s
# val-acc: 0.6400 val-AUC: 0.4954 |best-acc: 0.6400 at epoch 1
# epoch 16/100 steps 5/100, |train-loss: 0.6915
# epoch 16/100 steps 10/100, |train-loss: 0.6952
# epoch 16/100 steps 15/100, |train-loss: 0.6936
# epoch 16/100 steps 20/100, |train-loss: 0.6925
# epoch 16/100 steps 25/100, |train-loss: 0.6932
# epoch 16/100 steps 30/100, |train-loss: 0.6918
# epoch 16/100 steps 35/100, |train-loss: 0.6919
# epoch 16/100 steps 40/100, |train-loss: 0.6928
# epoch 16/100 steps 45/100, |train-loss: 0.6923
# epoch 16/100 steps 50/100, |train-loss: 0.6917
# epoch 16/100 steps 55/100, |train-loss: 0.6928
# epoch 16/100 steps 60/100, |train-loss: 0.6931
# epoch 16/100 steps 65/100, |train-loss: 0.6917
# epoch 16/100 steps 70/100, |train-loss: 0.6914
# epoch 16/100 steps 75/100, |train-loss: 0.6930
# epoch 16/100 steps 80/100, |train-loss: 0.6919
# epoch 16/100 steps 85/100, |train-loss: 0.6953
# epoch 16/100 steps 90/100, |train-loss: 0.6902
# epoch 16/100 steps 95/100, |train-loss: 0.6939
# epoch 16/100 steps 100/100, |train-loss: 0.6901 |avg-loss: 0.6927 dur 12.4s
# val-acc: 0.6400 val-AUC: 0.4846 |best-acc: 0.6400 at epoch 1
# epoch 17/100 steps 5/100, |train-loss: 0.6898
# epoch 17/100 steps 10/100, |train-loss: 0.6913
# epoch 17/100 steps 15/100, |train-loss: 0.6926
# epoch 17/100 steps 20/100, |train-loss: 0.6946
# epoch 17/100 steps 25/100, |train-loss: 0.6908
# epoch 17/100 steps 30/100, |train-loss: 0.6931
# epoch 17/100 steps 35/100, |train-loss: 0.6928
# epoch 17/100 steps 40/100, |train-loss: 0.6922
# epoch 17/100 steps 45/100, |train-loss: 0.6872
# epoch 17/100 steps 50/100, |train-loss: 0.6899
# epoch 17/100 steps 55/100, |train-loss: 0.6972
# epoch 17/100 steps 60/100, |train-loss: 0.6927
# epoch 17/100 steps 65/100, |train-loss: 0.6888
# epoch 17/100 steps 70/100, |train-loss: 0.6895
# epoch 17/100 steps 75/100, |train-loss: 0.6896
# epoch 17/100 steps 80/100, |train-loss: 0.6977
# epoch 17/100 steps 85/100, |train-loss: 0.6859
# epoch 17/100 steps 90/100, |train-loss: 0.6916
# epoch 17/100 steps 95/100, |train-loss: 0.6867
# epoch 17/100 steps 100/100, |train-loss: 0.7033 |avg-loss: 0.6923 dur 12.3s
# val-acc: 0.6400 val-AUC: 0.4877 |best-acc: 0.6400 at epoch 1
# epoch 18/100 steps 5/100, |train-loss: 0.6914
# epoch 18/100 steps 10/100, |train-loss: 0.6912
# epoch 18/100 steps 15/100, |train-loss: 0.6934
# epoch 18/100 steps 20/100, |train-loss: 0.6934
# epoch 18/100 steps 25/100, |train-loss: 0.6865
# epoch 18/100 steps 30/100, |train-loss: 0.6913
# epoch 18/100 steps 35/100, |train-loss: 0.6771
# epoch 18/100 steps 40/100, |train-loss: 0.6889
# epoch 18/100 steps 45/100, |train-loss: 0.6903
# epoch 18/100 steps 50/100, |train-loss: 0.6966
# epoch 18/100 steps 55/100, |train-loss: 0.7146
# epoch 18/100 steps 60/100, |train-loss: 0.6989
# epoch 18/100 steps 65/100, |train-loss: 0.6454
# epoch 18/100 steps 70/100, |train-loss: 0.6588
# epoch 18/100 steps 75/100, |train-loss: 0.7538
# epoch 18/100 steps 80/100, |train-loss: 0.6939
# epoch 18/100 steps 85/100, |train-loss: 0.6903
# epoch 18/100 steps 90/100, |train-loss: 0.6638
# epoch 18/100 steps 95/100, |train-loss: 0.6198
# epoch 18/100 steps 100/100, |train-loss: 0.8235 |avg-loss: 0.6900 dur 12.3s
# val-acc: 0.6400 val-AUC: 0.4923 |best-acc: 0.6400 at epoch 1
# epoch 19/100 steps 5/100, |train-loss: 0.6421
# epoch 19/100 steps 10/100, |train-loss: 0.7389
# epoch 19/100 steps 15/100, |train-loss: 0.5862
# epoch 19/100 steps 20/100, |train-loss: 0.7967
# epoch 19/100 steps 25/100, |train-loss: 0.6424
# epoch 19/100 steps 30/100, |train-loss: 0.6849
# epoch 19/100 steps 35/100, |train-loss: 0.6956
# epoch 19/100 steps 40/100, |train-loss: 0.7269
# epoch 19/100 steps 45/100, |train-loss: 0.6417
# epoch 19/100 steps 50/100, |train-loss: 0.7843
# epoch 19/100 steps 55/100, |train-loss: 0.7170
# epoch 19/100 steps 60/100, |train-loss: 0.7102
# epoch 19/100 steps 65/100, |train-loss: 0.6992
# epoch 19/100 steps 70/100, |train-loss: 0.6918
# epoch 19/100 steps 75/100, |train-loss: 0.6916
# epoch 19/100 steps 80/100, |train-loss: 0.6950
# epoch 19/100 steps 85/100, |train-loss: 0.6915
# epoch 19/100 steps 90/100, |train-loss: 0.6915
# epoch 19/100 steps 95/100, |train-loss: 0.6945
# epoch 19/100 steps 100/100, |train-loss: 0.6917 |avg-loss: 0.6887 dur 12.4s
# val-acc: 0.6400 val-AUC: 0.4977 |best-acc: 0.6400 at epoch 1
# epoch 20/100 steps 5/100, |train-loss: 0.6931
# epoch 20/100 steps 10/100, |train-loss: 0.6929
# epoch 20/100 steps 15/100, |train-loss: 0.6916
# epoch 20/100 steps 20/100, |train-loss: 0.6917
# epoch 20/100 steps 25/100, |train-loss: 0.6928
# epoch 20/100 steps 30/100, |train-loss: 0.6934
# epoch 20/100 steps 35/100, |train-loss: 0.6915
# epoch 20/100 steps 40/100, |train-loss: 0.6930
# epoch 20/100 steps 45/100, |train-loss: 0.6908
# epoch 20/100 steps 50/100, |train-loss: 0.6916
# epoch 20/100 steps 55/100, |train-loss: 0.6931
# epoch 20/100 steps 60/100, |train-loss: 0.6907
# epoch 20/100 steps 65/100, |train-loss: 0.6930
# epoch 20/100 steps 70/100, |train-loss: 0.6867
# epoch 20/100 steps 75/100, |train-loss: 0.6923
# epoch 20/100 steps 80/100, |train-loss: 0.6922
# epoch 20/100 steps 85/100, |train-loss: 0.6931
# epoch 20/100 steps 90/100, |train-loss: 0.6904
# epoch 20/100 steps 95/100, |train-loss: 0.6931
# epoch 20/100 steps 100/100, |train-loss: 0.6885 |avg-loss: 0.6924 dur 12.4s
# val-acc: 0.6400 val-AUC: 0.4938 |best-acc: 0.6400 at epoch 1|20ep model saved
# epoch 21/100 steps 5/100, |train-loss: 0.6967
# epoch 21/100 steps 10/100, |train-loss: 0.6931
# epoch 21/100 steps 15/100, |train-loss: 0.7008
# epoch 21/100 steps 20/100, |train-loss: 0.7020
# epoch 21/100 steps 25/100, |train-loss: 0.6940
# epoch 21/100 steps 30/100, |train-loss: 0.6924
# epoch 21/100 steps 35/100, |train-loss: 0.6924
# epoch 21/100 steps 40/100, |train-loss: 0.6841
# epoch 21/100 steps 45/100, |train-loss: 0.6814
# epoch 21/100 steps 50/100, |train-loss: 0.7000
# epoch 21/100 steps 55/100, |train-loss: 0.6932
# epoch 21/100 steps 60/100, |train-loss: 0.6942
# epoch 21/100 steps 65/100, |train-loss: 0.6935
# epoch 21/100 steps 70/100, |train-loss: 0.6703
# epoch 21/100 steps 75/100, |train-loss: 0.6934
# epoch 21/100 steps 80/100, |train-loss: 0.6882
# epoch 21/100 steps 85/100, |train-loss: 0.6927
# epoch 21/100 steps 90/100, |train-loss: 0.6845
# epoch 21/100 steps 95/100, |train-loss: 0.7227
# epoch 21/100 steps 100/100, |train-loss: 0.6931 |avg-loss: 0.6891 dur 13.0s
# val-acc: 0.6400 val-AUC: 0.4954 |best-acc: 0.6400 at epoch 1
# epoch 22/100 steps 5/100, |train-loss: 0.6613
# epoch 22/100 steps 10/100, |train-loss: 0.8975
# epoch 22/100 steps 15/100, |train-loss: 0.7504
# epoch 22/100 steps 20/100, |train-loss: 0.6916
# epoch 22/100 steps 25/100, |train-loss: 0.6802
# epoch 22/100 steps 30/100, |train-loss: 0.6818
# epoch 22/100 steps 35/100, |train-loss: 0.7089
# epoch 22/100 steps 40/100, |train-loss: 0.6916
# epoch 22/100 steps 45/100, |train-loss: 0.7067
# epoch 22/100 steps 50/100, |train-loss: 0.7216
# epoch 22/100 steps 55/100, |train-loss: 0.6839
# epoch 22/100 steps 60/100, |train-loss: 0.7016
# epoch 22/100 steps 65/100, |train-loss: 0.6833
# epoch 22/100 steps 70/100, |train-loss: 0.6792
# epoch 22/100 steps 75/100, |train-loss: 0.6789
# epoch 22/100 steps 80/100, |train-loss: 0.6931
# epoch 22/100 steps 85/100, |train-loss: 0.6931
# epoch 22/100 steps 90/100, |train-loss: 0.6426
# epoch 22/100 steps 95/100, |train-loss: 0.7713
# epoch 22/100 steps 100/100, |train-loss: 0.6058 |avg-loss: 0.6896 dur 12.5s
# val-acc: 0.6400 val-AUC: 0.4931 |best-acc: 0.6400 at epoch 1
# epoch 23/100 steps 5/100, |train-loss: 0.8690
# epoch 23/100 steps 10/100, |train-loss: 0.6017
# epoch 23/100 steps 15/100, |train-loss: 0.6261
# epoch 23/100 steps 20/100, |train-loss: 0.7657
# epoch 23/100 steps 25/100, |train-loss: 0.6535
# epoch 23/100 steps 30/100, |train-loss: 0.7075
# epoch 23/100 steps 35/100, |train-loss: 0.7283
# epoch 23/100 steps 40/100, |train-loss: 0.7994
# epoch 23/100 steps 45/100, |train-loss: 0.6910
# epoch 23/100 steps 50/100, |train-loss: 0.6957
# epoch 23/100 steps 55/100, |train-loss: 0.6934
# epoch 23/100 steps 60/100, |train-loss: 0.6930
# epoch 23/100 steps 65/100, |train-loss: 0.6947
# epoch 23/100 steps 70/100, |train-loss: 0.6889
# epoch 23/100 steps 75/100, |train-loss: 0.6879
# epoch 23/100 steps 80/100, |train-loss: 0.6973
# epoch 23/100 steps 85/100, |train-loss: 0.6847
# epoch 23/100 steps 90/100, |train-loss: 0.6888
# epoch 23/100 steps 95/100, |train-loss: 0.6868
# epoch 23/100 steps 100/100, |train-loss: 0.6919 |avg-loss: 0.6915 dur 12.3s
# val-acc: 0.6400 val-AUC: 0.4946 |best-acc: 0.6400 at epoch 1
# epoch 24/100 steps 5/100, |train-loss: 0.6773
# epoch 24/100 steps 10/100, |train-loss: 0.6850
# epoch 24/100 steps 15/100, |train-loss: 0.6909
# epoch 24/100 steps 20/100, |train-loss: 0.6637
# epoch 24/100 steps 25/100, |train-loss: 0.7239
# epoch 24/100 steps 30/100, |train-loss: 0.6732
# epoch 24/100 steps 35/100, |train-loss: 0.6941
# epoch 24/100 steps 40/100, |train-loss: 0.6522
# epoch 24/100 steps 45/100, |train-loss: 0.6267
# epoch 24/100 steps 50/100, |train-loss: 0.4598
# epoch 24/100 steps 55/100, |train-loss: 0.5492
# epoch 24/100 steps 60/100, |train-loss: 0.7216
# epoch 24/100 steps 65/100, |train-loss: 0.6576
# epoch 24/100 steps 70/100, |train-loss: 0.7028
# epoch 24/100 steps 75/100, |train-loss: 0.6920
# epoch 24/100 steps 80/100, |train-loss: 0.6860
# epoch 24/100 steps 85/100, |train-loss: 0.6920
# epoch 24/100 steps 90/100, |train-loss: 0.6911
# epoch 24/100 steps 95/100, |train-loss: 0.6934
# epoch 24/100 steps 100/100, |train-loss: 0.7057 |avg-loss: 0.6890 dur 12.7s
# val-acc: 0.6400 val-AUC: 0.4985 |best-acc: 0.6400 at epoch 1
# epoch 25/100 steps 5/100, |train-loss: 0.6944
# epoch 25/100 steps 10/100, |train-loss: 0.7002
# epoch 25/100 steps 15/100, |train-loss: 0.6833
# epoch 25/100 steps 20/100, |train-loss: 0.7003
# epoch 25/100 steps 25/100, |train-loss: 0.6847
# epoch 25/100 steps 30/100, |train-loss: 0.6907
# epoch 25/100 steps 35/100, |train-loss: 0.7035
# epoch 25/100 steps 40/100, |train-loss: 0.6812
# epoch 25/100 steps 45/100, |train-loss: 0.6818
# epoch 25/100 steps 50/100, |train-loss: 0.7043
# epoch 25/100 steps 55/100, |train-loss: 0.6749
# epoch 25/100 steps 60/100, |train-loss: 0.6913
# epoch 25/100 steps 65/100, |train-loss: 0.7445
# epoch 25/100 steps 70/100, |train-loss: 0.5946
# epoch 25/100 steps 75/100, |train-loss: 0.6668
# epoch 25/100 steps 80/100, |train-loss: 0.6915
# epoch 25/100 steps 85/100, |train-loss: 0.6822
# epoch 25/100 steps 90/100, |train-loss: 0.7371
# epoch 25/100 steps 95/100, |train-loss: 0.6614
# epoch 25/100 steps 100/100, |train-loss: 0.6342 |avg-loss: 0.6872 dur 12.6s
# val-acc: 0.6400 val-AUC: 0.5085 |best-acc: 0.6400 at epoch 1
# epoch 26/100 steps 5/100, |train-loss: 0.7102
# epoch 26/100 steps 10/100, |train-loss: 0.7601
# epoch 26/100 steps 15/100, |train-loss: 0.6725
# epoch 26/100 steps 20/100, |train-loss: 0.6523
# epoch 26/100 steps 25/100, |train-loss: 0.6489
# epoch 26/100 steps 30/100, |train-loss: 0.6637
# epoch 26/100 steps 35/100, |train-loss: 0.6190
# epoch 26/100 steps 40/100, |train-loss: 0.8006
# epoch 26/100 steps 45/100, |train-loss: 0.5206
# epoch 26/100 steps 50/100, |train-loss: 0.7600
# epoch 26/100 steps 55/100, |train-loss: 0.6321
# epoch 26/100 steps 60/100, |train-loss: 0.6949
# epoch 26/100 steps 65/100, |train-loss: 0.6846
# epoch 26/100 steps 70/100, |train-loss: 0.7212
# epoch 26/100 steps 75/100, |train-loss: 0.6332
# epoch 26/100 steps 80/100, |train-loss: 0.6522
# epoch 26/100 steps 85/100, |train-loss: 0.5895
# epoch 26/100 steps 90/100, |train-loss: 0.6971
# epoch 26/100 steps 95/100, |train-loss: 0.6884
# epoch 26/100 steps 100/100, |train-loss: 0.7356 |avg-loss: 0.6861 dur 12.1s
# val-acc: 0.6400 val-AUC: 0.5139 |best-acc: 0.6400 at epoch 1
# epoch 27/100 steps 5/100, |train-loss: 0.7158
# epoch 27/100 steps 10/100, |train-loss: 0.7109
# epoch 27/100 steps 15/100, |train-loss: 0.7029
# epoch 27/100 steps 20/100, |train-loss: 0.7099
# epoch 27/100 steps 25/100, |train-loss: 0.7198
# epoch 27/100 steps 30/100, |train-loss: 0.6691
# epoch 27/100 steps 35/100, |train-loss: 0.6586
# epoch 27/100 steps 40/100, |train-loss: 0.6781
# epoch 27/100 steps 45/100, |train-loss: 0.6828
# epoch 27/100 steps 50/100, |train-loss: 0.6762
# epoch 27/100 steps 55/100, |train-loss: 0.6930
# epoch 27/100 steps 60/100, |train-loss: 0.6936
# epoch 27/100 steps 65/100, |train-loss: 0.6922
# epoch 27/100 steps 70/100, |train-loss: 0.6741
# epoch 27/100 steps 75/100, |train-loss: 0.6995
# epoch 27/100 steps 80/100, |train-loss: 0.6929
# epoch 27/100 steps 85/100, |train-loss: 0.7308
# epoch 27/100 steps 90/100, |train-loss: 0.6348
# epoch 27/100 steps 95/100, |train-loss: 0.6099
# epoch 27/100 steps 100/100, |train-loss: 0.5925 |avg-loss: 0.6838 dur 12.4s
# val-acc: 0.6400 val-AUC: 0.5162 |best-acc: 0.6400 at epoch 1
# epoch 28/100 steps 5/100, |train-loss: 0.6667
# epoch 28/100 steps 10/100, |train-loss: 0.6784
# epoch 28/100 steps 15/100, |train-loss: 0.6793
# epoch 28/100 steps 20/100, |train-loss: 0.6527
# epoch 28/100 steps 25/100, |train-loss: 0.6666
# epoch 28/100 steps 30/100, |train-loss: 0.6423
# epoch 28/100 steps 35/100, |train-loss: 0.8156
# epoch 28/100 steps 40/100, |train-loss: 0.8982
# epoch 28/100 steps 45/100, |train-loss: 0.6958
# epoch 28/100 steps 50/100, |train-loss: 0.7014
# epoch 28/100 steps 55/100, |train-loss: 0.6737
# epoch 28/100 steps 60/100, |train-loss: 0.6840
# epoch 28/100 steps 65/100, |train-loss: 0.7234
# epoch 28/100 steps 70/100, |train-loss: 0.7145
# epoch 28/100 steps 75/100, |train-loss: 0.7144
# epoch 28/100 steps 80/100, |train-loss: 0.6806
# epoch 28/100 steps 85/100, |train-loss: 0.7030
# epoch 28/100 steps 90/100, |train-loss: 0.7119
# epoch 28/100 steps 95/100, |train-loss: 0.6878
# epoch 28/100 steps 100/100, |train-loss: 0.6876 |avg-loss: 0.6930 dur 12.3s
# val-acc: 0.6400 val-AUC: 0.5162 |best-acc: 0.6400 at epoch 1
# epoch 29/100 steps 5/100, |train-loss: 0.6275
# epoch 29/100 steps 10/100, |train-loss: 0.6817
# epoch 29/100 steps 15/100, |train-loss: 0.7235
# epoch 29/100 steps 20/100, |train-loss: 0.8319
# epoch 29/100 steps 25/100, |train-loss: 0.6443
# epoch 29/100 steps 30/100, |train-loss: 0.6429
# epoch 29/100 steps 35/100, |train-loss: 0.7447
# epoch 29/100 steps 40/100, |train-loss: 0.6552
# epoch 29/100 steps 45/100, |train-loss: 0.6905
# epoch 29/100 steps 50/100, |train-loss: 0.6978
# epoch 29/100 steps 55/100, |train-loss: 0.8408
# epoch 29/100 steps 60/100, |train-loss: 0.5360
# epoch 29/100 steps 65/100, |train-loss: 0.7759
# epoch 29/100 steps 70/100, |train-loss: 0.7179
# epoch 29/100 steps 75/100, |train-loss: 0.6503
# epoch 29/100 steps 80/100, |train-loss: 0.6440
# epoch 29/100 steps 85/100, |train-loss: 0.6917
# epoch 29/100 steps 90/100, |train-loss: 0.6745
# epoch 29/100 steps 95/100, |train-loss: 0.6888
# epoch 29/100 steps 100/100, |train-loss: 0.7008 |avg-loss: 0.6839 dur 13.3s
# val-acc: 0.6400 val-AUC: 0.5139 |best-acc: 0.6400 at epoch 1
# epoch 30/100 steps 5/100, |train-loss: 0.6955
# epoch 30/100 steps 10/100, |train-loss: 0.8052
# epoch 30/100 steps 15/100, |train-loss: 0.6753
# epoch 30/100 steps 20/100, |train-loss: 0.6768
# epoch 30/100 steps 25/100, |train-loss: 0.7076
# epoch 30/100 steps 30/100, |train-loss: 0.6556
# epoch 30/100 steps 35/100, |train-loss: 0.6509
# epoch 30/100 steps 40/100, |train-loss: 0.7422
# epoch 30/100 steps 45/100, |train-loss: 0.6839
# epoch 30/100 steps 50/100, |train-loss: 0.5780
# epoch 30/100 steps 55/100, |train-loss: 0.6671
# epoch 30/100 steps 60/100, |train-loss: 0.6763
# epoch 30/100 steps 65/100, |train-loss: 0.8164
# epoch 30/100 steps 70/100, |train-loss: 0.5211
# epoch 30/100 steps 75/100, |train-loss: 0.8989
# epoch 30/100 steps 80/100, |train-loss: 0.5614
# epoch 30/100 steps 85/100, |train-loss: 0.7372
# epoch 30/100 steps 90/100, |train-loss: 0.6707
# epoch 30/100 steps 95/100, |train-loss: 0.7253
# epoch 30/100 steps 100/100, |train-loss: 0.6899 |avg-loss: 0.6831 dur 12.6s
# val-acc: 0.6400 val-AUC: 0.5116 |best-acc: 0.6400 at epoch 1|30ep model saved
# epoch 31/100 steps 5/100, |train-loss: 0.6593
# epoch 31/100 steps 10/100, |train-loss: 0.6910
# epoch 31/100 steps 15/100, |train-loss: 0.6983
# epoch 31/100 steps 20/100, |train-loss: 0.6591
# epoch 31/100 steps 25/100, |train-loss: 0.6663
# epoch 31/100 steps 30/100, |train-loss: 0.6937
# epoch 31/100 steps 35/100, |train-loss: 0.6495
# epoch 31/100 steps 40/100, |train-loss: 0.6591
# epoch 31/100 steps 45/100, |train-loss: 0.6247
# epoch 31/100 steps 50/100, |train-loss: 0.7008
# epoch 31/100 steps 55/100, |train-loss: 0.5849
# epoch 31/100 steps 60/100, |train-loss: 0.6270
# epoch 31/100 steps 65/100, |train-loss: 0.5760
# epoch 31/100 steps 70/100, |train-loss: 0.8752
# epoch 31/100 steps 75/100, |train-loss: 0.7159
# epoch 31/100 steps 80/100, |train-loss: 0.7097
# epoch 31/100 steps 85/100, |train-loss: 0.6917
# epoch 31/100 steps 90/100, |train-loss: 0.6893
# epoch 31/100 steps 95/100, |train-loss: 0.6956
# epoch 31/100 steps 100/100, |train-loss: 0.6880 |avg-loss: 0.6835 dur 12.4s
# val-acc: 0.6400 val-AUC: 0.5131 |best-acc: 0.6400 at epoch 1
# epoch 32/100 steps 5/100, |train-loss: 0.6999
# epoch 32/100 steps 10/100, |train-loss: 0.6970
# epoch 32/100 steps 15/100, |train-loss: 0.6788
# epoch 32/100 steps 20/100, |train-loss: 0.6877
# epoch 32/100 steps 25/100, |train-loss: 0.6769
# epoch 32/100 steps 30/100, |train-loss: 0.6926
# epoch 32/100 steps 35/100, |train-loss: 0.6874
# epoch 32/100 steps 40/100, |train-loss: 0.6982
# epoch 32/100 steps 45/100, |train-loss: 0.6822
# epoch 32/100 steps 50/100, |train-loss: 0.6592
# epoch 32/100 steps 55/100, |train-loss: 0.6509
# epoch 32/100 steps 60/100, |train-loss: 0.6303
# epoch 32/100 steps 65/100, |train-loss: 0.7295
# epoch 32/100 steps 70/100, |train-loss: 0.6780
# epoch 32/100 steps 75/100, |train-loss: 0.7073
# epoch 32/100 steps 80/100, |train-loss: 0.7008
# epoch 32/100 steps 85/100, |train-loss: 0.6457
# epoch 32/100 steps 90/100, |train-loss: 0.7288
# epoch 32/100 steps 95/100, |train-loss: 0.5739
# epoch 32/100 steps 100/100, |train-loss: 0.7488 |avg-loss: 0.6864 dur 12.4s
# val-acc: 0.6400 val-AUC: 0.5085 |best-acc: 0.6400 at epoch 1
# epoch 33/100 steps 5/100, |train-loss: 0.6243
# epoch 33/100 steps 10/100, |train-loss: 0.5997
# epoch 33/100 steps 15/100, |train-loss: 0.7506
# epoch 33/100 steps 20/100, |train-loss: 0.6337
# epoch 33/100 steps 25/100, |train-loss: 0.6713
# epoch 33/100 steps 30/100, |train-loss: 0.7450
# epoch 33/100 steps 35/100, |train-loss: 0.7246
# epoch 33/100 steps 40/100, |train-loss: 0.7796
# epoch 33/100 steps 45/100, |train-loss: 0.6675
# epoch 33/100 steps 50/100, |train-loss: 0.6944
# epoch 33/100 steps 55/100, |train-loss: 0.6634
# epoch 33/100 steps 60/100, |train-loss: 0.6963
# epoch 33/100 steps 65/100, |train-loss: 0.6959
# epoch 33/100 steps 70/100, |train-loss: 0.7578
# epoch 33/100 steps 75/100, |train-loss: 0.6390
# epoch 33/100 steps 80/100, |train-loss: 0.6274
# epoch 33/100 steps 85/100, |train-loss: 0.6485
# epoch 33/100 steps 90/100, |train-loss: 0.8172
# epoch 33/100 steps 95/100, |train-loss: 0.7670
# epoch 33/100 steps 100/100, |train-loss: 0.7008 |avg-loss: 0.6799 dur 12.4s
# val-acc: 0.6400 val-AUC: 0.5123 |best-acc: 0.6400 at epoch 1
# epoch 34/100 steps 5/100, |train-loss: 0.8262
# epoch 34/100 steps 10/100, |train-loss: 0.8033
# epoch 34/100 steps 15/100, |train-loss: 0.5882
# epoch 34/100 steps 20/100, |train-loss: 0.7281
# epoch 34/100 steps 25/100, |train-loss: 0.9191
# epoch 34/100 steps 30/100, |train-loss: 0.6822
# epoch 34/100 steps 35/100, |train-loss: 0.6861
# epoch 34/100 steps 40/100, |train-loss: 0.6759
# epoch 34/100 steps 45/100, |train-loss: 0.6835
# epoch 34/100 steps 50/100, |train-loss: 0.6929
# epoch 34/100 steps 55/100, |train-loss: 0.6862
# epoch 34/100 steps 60/100, |train-loss: 0.6749
# epoch 34/100 steps 65/100, |train-loss: 0.7027
# epoch 34/100 steps 70/100, |train-loss: 0.6963
# epoch 34/100 steps 75/100, |train-loss: 0.6835
# epoch 34/100 steps 80/100, |train-loss: 0.6939
# epoch 34/100 steps 85/100, |train-loss: 0.6930
# epoch 34/100 steps 90/100, |train-loss: 0.6821
# epoch 34/100 steps 95/100, |train-loss: 0.6831
# epoch 34/100 steps 100/100, |train-loss: 0.6745 |avg-loss: 0.6796 dur 12.2s
# val-acc: 0.6400 val-AUC: 0.5093 |best-acc: 0.6400 at epoch 1
# epoch 35/100 steps 5/100, |train-loss: 0.6934
# epoch 35/100 steps 10/100, |train-loss: 0.6885
# epoch 35/100 steps 15/100, |train-loss: 0.7135
# epoch 35/100 steps 20/100, |train-loss: 0.6835
# epoch 35/100 steps 25/100, |train-loss: 0.6290
# epoch 35/100 steps 30/100, |train-loss: 0.7624
# epoch 35/100 steps 35/100, |train-loss: 0.7921
# epoch 35/100 steps 40/100, |train-loss: 0.6514
# epoch 35/100 steps 45/100, |train-loss: 0.7584
# epoch 35/100 steps 50/100, |train-loss: 0.7256
# epoch 35/100 steps 55/100, |train-loss: 0.7221
# epoch 35/100 steps 60/100, |train-loss: 0.7212
# epoch 35/100 steps 65/100, |train-loss: 0.6812
# epoch 35/100 steps 70/100, |train-loss: 0.6342
# epoch 35/100 steps 75/100, |train-loss: 0.6603
# epoch 35/100 steps 80/100, |train-loss: 0.6372
# epoch 35/100 steps 85/100, |train-loss: 0.6399
# epoch 35/100 steps 90/100, |train-loss: 0.6795
# epoch 35/100 steps 95/100, |train-loss: 0.5050
# epoch 35/100 steps 100/100, |train-loss: 0.8128 |avg-loss: 0.6855 dur 12.7s
# val-acc: 0.6400 val-AUC: 0.5093 |best-acc: 0.6400 at epoch 1
# epoch 36/100 steps 5/100, |train-loss: 0.9234
# epoch 36/100 steps 10/100, |train-loss: 0.7020
# epoch 36/100 steps 15/100, |train-loss: 0.6997
# epoch 36/100 steps 20/100, |train-loss: 0.6440
# epoch 36/100 steps 25/100, |train-loss: 0.6649
# epoch 36/100 steps 30/100, |train-loss: 0.7055
# epoch 36/100 steps 35/100, |train-loss: 0.6915
# epoch 36/100 steps 40/100, |train-loss: 0.7208
# epoch 36/100 steps 45/100, |train-loss: 0.6265
# epoch 36/100 steps 50/100, |train-loss: 0.6886
# epoch 36/100 steps 55/100, |train-loss: 0.6848
# epoch 36/100 steps 60/100, |train-loss: 0.6674
# epoch 36/100 steps 65/100, |train-loss: 0.5209
# epoch 36/100 steps 70/100, |train-loss: 0.5637
# epoch 36/100 steps 75/100, |train-loss: 0.7063
# epoch 36/100 steps 80/100, |train-loss: 0.6931
# epoch 36/100 steps 85/100, |train-loss: 0.7803
# epoch 36/100 steps 90/100, |train-loss: 0.5833
# epoch 36/100 steps 95/100, |train-loss: 0.6331
# epoch 36/100 steps 100/100, |train-loss: 0.7212 |avg-loss: 0.6837 dur 12.3s
# val-acc: 0.6400 val-AUC: 0.5147 |best-acc: 0.6400 at epoch 1
# epoch 37/100 steps 5/100, |train-loss: 0.6436
# epoch 37/100 steps 10/100, |train-loss: 0.6977
# epoch 37/100 steps 15/100, |train-loss: 0.6567
# epoch 37/100 steps 20/100, |train-loss: 0.7405
# epoch 37/100 steps 25/100, |train-loss: 0.6632
# epoch 37/100 steps 30/100, |train-loss: 0.7667
# epoch 37/100 steps 35/100, |train-loss: 0.6141
# epoch 37/100 steps 40/100, |train-loss: 0.6947
# epoch 37/100 steps 45/100, |train-loss: 0.6564
# epoch 37/100 steps 50/100, |train-loss: 0.5361
# epoch 37/100 steps 55/100, |train-loss: 0.7053
# epoch 37/100 steps 60/100, |train-loss: 0.9627
# epoch 37/100 steps 65/100, |train-loss: 0.7152
# epoch 37/100 steps 70/100, |train-loss: 0.6767
# epoch 37/100 steps 75/100, |train-loss: 0.6949
# epoch 37/100 steps 80/100, |train-loss: 0.6695
# epoch 37/100 steps 85/100, |train-loss: 0.6735
# epoch 37/100 steps 90/100, |train-loss: 0.6990
# epoch 37/100 steps 95/100, |train-loss: 0.6704
# epoch 37/100 steps 100/100, |train-loss: 0.6886 |avg-loss: 0.6851 dur 12.6s
# val-acc: 0.6400 val-AUC: 0.5131 |best-acc: 0.6400 at epoch 1
# epoch 38/100 steps 5/100, |train-loss: 0.6591
# epoch 38/100 steps 10/100, |train-loss: 0.6770
# epoch 38/100 steps 15/100, |train-loss: 0.7083
# epoch 38/100 steps 20/100, |train-loss: 0.7570
# epoch 38/100 steps 25/100, |train-loss: 0.6831
# epoch 38/100 steps 30/100, |train-loss: 0.6887
# epoch 38/100 steps 35/100, |train-loss: 0.6750
# epoch 38/100 steps 40/100, |train-loss: 0.6760
# epoch 38/100 steps 45/100, |train-loss: 0.6514
# epoch 38/100 steps 50/100, |train-loss: 0.6904
# epoch 38/100 steps 55/100, |train-loss: 0.7311
# epoch 38/100 steps 60/100, |train-loss: 0.6247
# epoch 38/100 steps 65/100, |train-loss: 0.6204
# epoch 38/100 steps 70/100, |train-loss: 0.5846
# epoch 38/100 steps 75/100, |train-loss: 0.3962
# epoch 38/100 steps 80/100, |train-loss: 0.5120
# epoch 38/100 steps 85/100, |train-loss: 0.7060
# epoch 38/100 steps 90/100, |train-loss: 0.7118
# epoch 38/100 steps 95/100, |train-loss: 0.6474
# epoch 38/100 steps 100/100, |train-loss: 0.6992 |avg-loss: 0.6815 dur 12.7s
# val-acc: 0.6400 val-AUC: 0.5069 |best-acc: 0.6400 at epoch 1
# epoch 39/100 steps 5/100, |train-loss: 0.6538
# epoch 39/100 steps 10/100, |train-loss: 0.6744
# epoch 39/100 steps 15/100, |train-loss: 0.7187
# epoch 39/100 steps 20/100, |train-loss: 0.6445
# epoch 39/100 steps 25/100, |train-loss: 0.6700
# epoch 39/100 steps 30/100, |train-loss: 0.6739
# epoch 39/100 steps 35/100, |train-loss: 0.7069
# epoch 39/100 steps 40/100, |train-loss: 0.5908
# epoch 39/100 steps 45/100, |train-loss: 0.5938
# epoch 39/100 steps 50/100, |train-loss: 0.5951
# epoch 39/100 steps 55/100, |train-loss: 0.7932
# epoch 39/100 steps 60/100, |train-loss: 0.6312
# epoch 39/100 steps 65/100, |train-loss: 0.8176
# epoch 39/100 steps 70/100, |train-loss: 0.5991
# epoch 39/100 steps 75/100, |train-loss: 0.5953
# epoch 39/100 steps 80/100, |train-loss: 0.4601
# epoch 39/100 steps 85/100, |train-loss: 0.6344
# epoch 39/100 steps 90/100, |train-loss: 0.6833
# epoch 39/100 steps 95/100, |train-loss: 0.6844
# epoch 39/100 steps 100/100, |train-loss: 0.7004 |avg-loss: 0.6820 dur 12.7s
# val-acc: 0.6400 val-AUC: 0.5100 |best-acc: 0.6400 at epoch 1
# epoch 40/100 steps 5/100, |train-loss: 0.7106
# epoch 40/100 steps 10/100, |train-loss: 0.6786
# epoch 40/100 steps 15/100, |train-loss: 0.6780
# epoch 40/100 steps 20/100, |train-loss: 0.7139
# epoch 40/100 steps 25/100, |train-loss: 0.6836
# epoch 40/100 steps 30/100, |train-loss: 0.6967
# epoch 40/100 steps 35/100, |train-loss: 0.6762
# epoch 40/100 steps 40/100, |train-loss: 0.6867
# epoch 40/100 steps 45/100, |train-loss: 0.6454
# epoch 40/100 steps 50/100, |train-loss: 0.7151
# epoch 40/100 steps 55/100, |train-loss: 0.6920
# epoch 40/100 steps 60/100, |train-loss: 0.7377
# epoch 40/100 steps 65/100, |train-loss: 0.7475
# epoch 40/100 steps 70/100, |train-loss: 0.6802
# epoch 40/100 steps 75/100, |train-loss: 0.6263
# epoch 40/100 steps 80/100, |train-loss: 0.5151
# epoch 40/100 steps 85/100, |train-loss: 0.7859
# epoch 40/100 steps 90/100, |train-loss: 0.6346
# epoch 40/100 steps 95/100, |train-loss: 0.7178
# epoch 40/100 steps 100/100, |train-loss: 0.7738 |avg-loss: 0.6832 dur 13.1s
# val-acc: 0.6400 val-AUC: 0.5185 |best-acc: 0.6400 at epoch 1|40ep model saved
# epoch 41/100 steps 5/100, |train-loss: 0.6247
# epoch 41/100 steps 10/100, |train-loss: 0.7060
# epoch 41/100 steps 15/100, |train-loss: 0.6979
# epoch 41/100 steps 20/100, |train-loss: 0.7026
# epoch 41/100 steps 25/100, |train-loss: 0.6067
# epoch 41/100 steps 30/100, |train-loss: 0.6247
# epoch 41/100 steps 35/100, |train-loss: 0.7135
# epoch 41/100 steps 40/100, |train-loss: 0.5120
# epoch 41/100 steps 45/100, |train-loss: 0.5688
# epoch 41/100 steps 50/100, |train-loss: 0.7458
# epoch 41/100 steps 55/100, |train-loss: 0.5164
# epoch 41/100 steps 60/100, |train-loss: 0.5272
# epoch 41/100 steps 65/100, |train-loss: 0.8017
# epoch 41/100 steps 70/100, |train-loss: 0.7246
# epoch 41/100 steps 75/100, |train-loss: 0.6838
# epoch 41/100 steps 80/100, |train-loss: 0.5769
# epoch 41/100 steps 85/100, |train-loss: 0.7058
# epoch 41/100 steps 90/100, |train-loss: 0.7175
# epoch 41/100 steps 95/100, |train-loss: 0.6727
# epoch 41/100 steps 100/100, |train-loss: 0.6919 |avg-loss: 0.6789 dur 12.5s
# val-acc: 0.6400 val-AUC: 0.5147 |best-acc: 0.6400 at epoch 1
# epoch 42/100 steps 5/100, |train-loss: 0.6865
# epoch 42/100 steps 10/100, |train-loss: 0.7016
# epoch 42/100 steps 15/100, |train-loss: 0.7040
# epoch 42/100 steps 20/100, |train-loss: 0.9434
# epoch 42/100 steps 25/100, |train-loss: 0.5215
# epoch 42/100 steps 30/100, |train-loss: 0.5927
# epoch 42/100 steps 35/100, |train-loss: 0.6999
# epoch 42/100 steps 40/100, |train-loss: 0.6028
# epoch 42/100 steps 45/100, |train-loss: 0.6865
# epoch 42/100 steps 50/100, |train-loss: 0.6589
# epoch 42/100 steps 55/100, |train-loss: 0.7892
# epoch 42/100 steps 60/100, |train-loss: 0.9395
# epoch 42/100 steps 65/100, |train-loss: 0.7867
# epoch 42/100 steps 70/100, |train-loss: 0.6971
# epoch 42/100 steps 75/100, |train-loss: 0.6735
# epoch 42/100 steps 80/100, |train-loss: 0.6944
# epoch 42/100 steps 85/100, |train-loss: 0.6920
# epoch 42/100 steps 90/100, |train-loss: 0.7099
# epoch 42/100 steps 95/100, |train-loss: 0.6875
# epoch 42/100 steps 100/100, |train-loss: 0.6854 |avg-loss: 0.6843 dur 12.5s
# val-acc: 0.6400 val-AUC: 0.5116 |best-acc: 0.6400 at epoch 1
# epoch 43/100 steps 5/100, |train-loss: 0.6913
# epoch 43/100 steps 10/100, |train-loss: 0.6989
# epoch 43/100 steps 15/100, |train-loss: 0.7163
# epoch 43/100 steps 20/100, |train-loss: 0.7155
# epoch 43/100 steps 25/100, |train-loss: 0.6455
# epoch 43/100 steps 30/100, |train-loss: 0.6269
# epoch 43/100 steps 35/100, |train-loss: 0.6676
# epoch 43/100 steps 40/100, |train-loss: 0.7573
# epoch 43/100 steps 45/100, |train-loss: 0.6173
# epoch 43/100 steps 50/100, |train-loss: 0.6236
# epoch 43/100 steps 55/100, |train-loss: 0.6627
# epoch 43/100 steps 60/100, |train-loss: 0.6132
# epoch 43/100 steps 65/100, |train-loss: 0.6985
# epoch 43/100 steps 70/100, |train-loss: 0.7453
# epoch 43/100 steps 75/100, |train-loss: 0.6754
# epoch 43/100 steps 80/100, |train-loss: 0.6936
# epoch 43/100 steps 85/100, |train-loss: 0.6313
# epoch 43/100 steps 90/100, |train-loss: 0.6883
# epoch 43/100 steps 95/100, |train-loss: 0.6179
# epoch 43/100 steps 100/100, |train-loss: 0.6691 |avg-loss: 0.6779 dur 12.5s
# val-acc: 0.6400 val-AUC: 0.5131 |best-acc: 0.6400 at epoch 1
# epoch 44/100 steps 5/100, |train-loss: 0.7283
# epoch 44/100 steps 10/100, |train-loss: 0.6253
# epoch 44/100 steps 15/100, |train-loss: 0.7120
# epoch 44/100 steps 20/100, |train-loss: 0.6412
# epoch 44/100 steps 25/100, |train-loss: 0.6770
# epoch 44/100 steps 30/100, |train-loss: 0.6836
# epoch 44/100 steps 35/100, |train-loss: 0.6806
# epoch 44/100 steps 40/100, |train-loss: 0.6192
# epoch 44/100 steps 45/100, |train-loss: 0.6468
# epoch 44/100 steps 50/100, |train-loss: 0.6504
# epoch 44/100 steps 55/100, |train-loss: 0.6202
# epoch 44/100 steps 60/100, |train-loss: 0.6964
# epoch 44/100 steps 65/100, |train-loss: 0.5284
# epoch 44/100 steps 70/100, |train-loss: 0.2319
# epoch 44/100 steps 75/100, |train-loss: 0.9865
# epoch 44/100 steps 80/100, |train-loss: 0.5816
# epoch 44/100 steps 85/100, |train-loss: 0.6753
# epoch 44/100 steps 90/100, |train-loss: 0.6811
# epoch 44/100 steps 95/100, |train-loss: 0.6887
# epoch 44/100 steps 100/100, |train-loss: 0.6953 |avg-loss: 0.6906 dur 12.5s
# val-acc: 0.6400 val-AUC: 0.5131 |best-acc: 0.6400 at epoch 1
# epoch 45/100 steps 5/100, |train-loss: 0.6892
# epoch 45/100 steps 10/100, |train-loss: 0.6929
# epoch 45/100 steps 15/100, |train-loss: 0.6916
# epoch 45/100 steps 20/100, |train-loss: 0.6924
# epoch 45/100 steps 25/100, |train-loss: 0.6892
# epoch 45/100 steps 30/100, |train-loss: 0.6911
# epoch 45/100 steps 35/100, |train-loss: 0.6892
# epoch 45/100 steps 40/100, |train-loss: 0.6953
# epoch 45/100 steps 45/100, |train-loss: 0.6937
# epoch 45/100 steps 50/100, |train-loss: 0.6921
# epoch 45/100 steps 55/100, |train-loss: 0.6920
# epoch 45/100 steps 60/100, |train-loss: 0.6954
# epoch 45/100 steps 65/100, |train-loss: 0.6963
# epoch 45/100 steps 70/100, |train-loss: 0.6925
# epoch 45/100 steps 75/100, |train-loss: 0.6885
# epoch 45/100 steps 80/100, |train-loss: 0.6935
# epoch 45/100 steps 85/100, |train-loss: 0.6939
# epoch 45/100 steps 90/100, |train-loss: 0.6941
# epoch 45/100 steps 95/100, |train-loss: 0.6935
# epoch 45/100 steps 100/100, |train-loss: 0.7012 |avg-loss: 0.6918 dur 12.5s
# val-acc: 0.6400 val-AUC: 0.5131 |best-acc: 0.6400 at epoch 1
# epoch 46/100 steps 5/100, |train-loss: 0.6916
# epoch 46/100 steps 10/100, |train-loss: 0.6946
# epoch 46/100 steps 15/100, |train-loss: 0.6972
# epoch 46/100 steps 20/100, |train-loss: 0.6919
# epoch 46/100 steps 25/100, |train-loss: 0.6937
# epoch 46/100 steps 30/100, |train-loss: 0.6953
# epoch 46/100 steps 35/100, |train-loss: 0.6901
# epoch 46/100 steps 40/100, |train-loss: 0.6912
# epoch 46/100 steps 45/100, |train-loss: 0.6950
# epoch 46/100 steps 50/100, |train-loss: 0.6918
# epoch 46/100 steps 55/100, |train-loss: 0.6933
# epoch 46/100 steps 60/100, |train-loss: 0.6794
# epoch 46/100 steps 65/100, |train-loss: 0.6778
# epoch 46/100 steps 70/100, |train-loss: 0.7022
# epoch 46/100 steps 75/100, |train-loss: 0.6764
# epoch 46/100 steps 80/100, |train-loss: 0.6625
# epoch 46/100 steps 85/100, |train-loss: 0.6967
# epoch 46/100 steps 90/100, |train-loss: 0.6633
# epoch 46/100 steps 95/100, |train-loss: 0.6912
# epoch 46/100 steps 100/100, |train-loss: 0.6722 |avg-loss: 0.6891 dur 12.8s
# val-acc: 0.6400 val-AUC: 0.5193 |best-acc: 0.6400 at epoch 1
# epoch 47/100 steps 5/100, |train-loss: 0.7533
# epoch 47/100 steps 10/100, |train-loss: 0.7291
# epoch 47/100 steps 15/100, |train-loss: 0.6520
# epoch 47/100 steps 20/100, |train-loss: 0.6210
# epoch 47/100 steps 25/100, |train-loss: 0.7142
# epoch 47/100 steps 30/100, |train-loss: 0.7843
# epoch 47/100 steps 35/100, |train-loss: 0.5656
# epoch 47/100 steps 40/100, |train-loss: 0.5550
# epoch 47/100 steps 45/100, |train-loss: 0.8204
# epoch 47/100 steps 50/100, |train-loss: 0.7784
# epoch 47/100 steps 55/100, |train-loss: 0.5300
# epoch 47/100 steps 60/100, |train-loss: 0.6754
# epoch 47/100 steps 65/100, |train-loss: 0.7057
# epoch 47/100 steps 70/100, |train-loss: 0.6257
# epoch 47/100 steps 75/100, |train-loss: 0.6435
# ...
# epoch 85/100 steps 80/100, |train-loss: 1.0683
# epoch 85/100 steps 85/100, |train-loss: 0.4199
# epoch 85/100 steps 90/100, |train-loss: 0.6688
# epoch 85/100 steps 95/100, |train-loss: 0.7074
# epoch 85/100 steps 100/100, |train-loss: 0.5650 |avg-loss: 0.6397 dur 12.5s
# val-acc: 0.6133 val-AUC: 0.5100 |best-acc: 0.6533 at epoch 83
# epoch 86/100 steps 5/100, |train-loss: 0.4833
# epoch 86/100 steps 10/100, |train-loss: 0.8989
# epoch 86/100 steps 15/100, |train-loss: 0.6650
# epoch 86/100 steps 20/100, |train-loss: 0.3628
# epoch 86/100 steps 25/100, |train-loss: 0.3822
# epoch 86/100 steps 30/100, |train-loss: 0.5513
# epoch 86/100 steps 35/100, |train-loss: 0.5267
# epoch 86/100 steps 40/100, |train-loss: 0.4542
# epoch 86/100 steps 45/100, |train-loss: 0.8950
# epoch 86/100 steps 50/100, |train-loss: 0.5868
# epoch 86/100 steps 55/100, |train-loss: 0.5650
# epoch 86/100 steps 60/100, |train-loss: 0.6662
# epoch 86/100 steps 65/100, |train-loss: 0.6404
# epoch 86/100 steps 70/100, |train-loss: 0.7426
# epoch 86/100 steps 75/100, |train-loss: 0.6277
# epoch 86/100 steps 80/100, |train-loss: 0.6741
# epoch 86/100 steps 85/100, |train-loss: 0.6888
# epoch 86/100 steps 90/100, |train-loss: 0.6253
# epoch 86/100 steps 95/100, |train-loss: 0.6155
# epoch 86/100 steps 100/100, |train-loss: 0.5330 |avg-loss: 0.6306 dur 12.5s
# val-acc: 0.6400 val-AUC: 0.5069 |best-acc: 0.6533 at epoch 83
# epoch 87/100 steps 5/100, |train-loss: 0.5491
# epoch 87/100 steps 10/100, |train-loss: 0.8099
# epoch 87/100 steps 15/100, |train-loss: 0.6856
# epoch 87/100 steps 20/100, |train-loss: 0.4187
# epoch 87/100 steps 25/100, |train-loss: 1.1194
# epoch 87/100 steps 30/100, |train-loss: 0.8248
# epoch 87/100 steps 35/100, |train-loss: 0.6324
# epoch 87/100 steps 40/100, |train-loss: 0.6509
# epoch 87/100 steps 45/100, |train-loss: 0.6923
# epoch 87/100 steps 50/100, |train-loss: 0.7111
# epoch 87/100 steps 55/100, |train-loss: 0.6569
# epoch 87/100 steps 60/100, |train-loss: 0.7119
# epoch 87/100 steps 65/100, |train-loss: 0.6960
# epoch 87/100 steps 70/100, |train-loss: 0.5093
# epoch 87/100 steps 75/100, |train-loss: 0.4344
# epoch 87/100 steps 80/100, |train-loss: 0.4020
# epoch 87/100 steps 85/100, |train-loss: 0.8544
# epoch 87/100 steps 90/100, |train-loss: 0.9051
# epoch 87/100 steps 95/100, |train-loss: 0.5897
# epoch 87/100 steps 100/100, |train-loss: 0.6515 |avg-loss: 0.6663 dur 12.5s
# val-acc: 0.6267 val-AUC: 0.5069 |best-acc: 0.6533 at epoch 83
# epoch 88/100 steps 5/100, |train-loss: 0.9448
# epoch 88/100 steps 10/100, |train-loss: 0.6230
# epoch 88/100 steps 15/100, |train-loss: 0.5578
# epoch 88/100 steps 20/100, |train-loss: 0.5891
# epoch 88/100 steps 25/100, |train-loss: 0.6219
# epoch 88/100 steps 30/100, |train-loss: 0.5922
# epoch 88/100 steps 35/100, |train-loss: 0.4245
# epoch 88/100 steps 40/100, |train-loss: 0.8330
# epoch 88/100 steps 45/100, |train-loss: 0.8635
# epoch 88/100 steps 50/100, |train-loss: 0.6814
# epoch 88/100 steps 55/100, |train-loss: 0.8251
# epoch 88/100 steps 60/100, |train-loss: 0.6113
# epoch 88/100 steps 65/100, |train-loss: 0.6060
# epoch 88/100 steps 70/100, |train-loss: 0.4169
# epoch 88/100 steps 75/100, |train-loss: 0.9594
# epoch 88/100 steps 80/100, |train-loss: 0.7621
# epoch 88/100 steps 85/100, |train-loss: 0.5435
# epoch 88/100 steps 90/100, |train-loss: 0.5474
# epoch 88/100 steps 95/100, |train-loss: 0.7076
# epoch 88/100 steps 100/100, |train-loss: 0.4508 |avg-loss: 0.6361 dur 12.5s
# val-acc: 0.4800 val-AUC: 0.4838 |best-acc: 0.6533 at epoch 83
# epoch 89/100 steps 5/100, |train-loss: 0.7011
# epoch 89/100 steps 10/100, |train-loss: 0.4753
# epoch 89/100 steps 15/100, |train-loss: 0.6231
# epoch 89/100 steps 20/100, |train-loss: 0.5929
# epoch 89/100 steps 25/100, |train-loss: 0.2236
# epoch 89/100 steps 30/100, |train-loss: 0.9272
# epoch 89/100 steps 35/100, |train-loss: 0.5898
# epoch 89/100 steps 40/100, |train-loss: 0.7258
# epoch 89/100 steps 45/100, |train-loss: 0.6548
# epoch 89/100 steps 50/100, |train-loss: 0.6661
# epoch 89/100 steps 55/100, |train-loss: 0.5968
# epoch 89/100 steps 60/100, |train-loss: 0.6901
# epoch 89/100 steps 65/100, |train-loss: 0.4977
# epoch 89/100 steps 70/100, |train-loss: 0.6682
# epoch 89/100 steps 75/100, |train-loss: 0.9892
# epoch 89/100 steps 80/100, |train-loss: 1.0239
# epoch 89/100 steps 85/100, |train-loss: 0.6891
# epoch 89/100 steps 90/100, |train-loss: 0.4943
# epoch 89/100 steps 95/100, |train-loss: 0.5821
# epoch 89/100 steps 100/100, |train-loss: 0.5667 |avg-loss: 0.6406 dur 12.3s
# val-acc: 0.5867 val-AUC: 0.4992 |best-acc: 0.6533 at epoch 83
# epoch 90/100 steps 5/100, |train-loss: 0.8819
# epoch 90/100 steps 10/100, |train-loss: 0.8460
# epoch 90/100 steps 15/100, |train-loss: 1.1425
# epoch 90/100 steps 20/100, |train-loss: 0.6748
# epoch 90/100 steps 25/100, |train-loss: 0.6718
# epoch 90/100 steps 30/100, |train-loss: 0.7499
# epoch 90/100 steps 35/100, |train-loss: 0.5784
# epoch 90/100 steps 40/100, |train-loss: 0.5873
# epoch 90/100 steps 45/100, |train-loss: 0.4103
# epoch 90/100 steps 50/100, |train-loss: 0.5594
# epoch 90/100 steps 55/100, |train-loss: 0.4933
# epoch 90/100 steps 60/100, |train-loss: 0.5931
# epoch 90/100 steps 65/100, |train-loss: 0.6439
# epoch 90/100 steps 70/100, |train-loss: 0.7371
# epoch 90/100 steps 75/100, |train-loss: 0.9407
# epoch 90/100 steps 80/100, |train-loss: 0.9600
# epoch 90/100 steps 85/100, |train-loss: 0.9077
# epoch 90/100 steps 90/100, |train-loss: 0.5900
# epoch 90/100 steps 95/100, |train-loss: 0.5305
# epoch 90/100 steps 100/100, |train-loss: 0.9053 |avg-loss: 0.6173 dur 12.6s
# val-acc: 0.4133 val-AUC: 0.4815 |best-acc: 0.6533 at epoch 83|90ep model saved
# epoch 91/100 steps 5/100, |train-loss: 0.6194
# epoch 91/100 steps 10/100, |train-loss: 0.7078
# epoch 91/100 steps 15/100, |train-loss: 0.7312
# epoch 91/100 steps 20/100, |train-loss: 0.7141
# epoch 91/100 steps 25/100, |train-loss: 0.6668
# epoch 91/100 steps 30/100, |train-loss: 0.5383
# epoch 91/100 steps 35/100, |train-loss: 0.6570
# epoch 91/100 steps 40/100, |train-loss: 0.6885
# epoch 91/100 steps 45/100, |train-loss: 0.6264
# epoch 91/100 steps 50/100, |train-loss: 0.7521
# epoch 91/100 steps 55/100, |train-loss: 0.6656
# epoch 91/100 steps 60/100, |train-loss: 0.5329
# epoch 91/100 steps 65/100, |train-loss: 0.6442
# epoch 91/100 steps 70/100, |train-loss: 0.4348
# epoch 91/100 steps 75/100, |train-loss: 0.6156
# epoch 91/100 steps 80/100, |train-loss: 0.6129
# epoch 91/100 steps 85/100, |train-loss: 0.5947
# epoch 91/100 steps 90/100, |train-loss: 0.5974
# epoch 91/100 steps 95/100, |train-loss: 0.6979
# epoch 91/100 steps 100/100, |train-loss: 0.4024 |avg-loss: 0.6297 dur 13.0s
# val-acc: 0.4667 val-AUC: 0.4830 |best-acc: 0.6533 at epoch 83
# epoch 92/100 steps 5/100, |train-loss: 0.3271
# epoch 92/100 steps 10/100, |train-loss: 0.4652
# epoch 92/100 steps 15/100, |train-loss: 0.3431
# epoch 92/100 steps 20/100, |train-loss: 0.9293
# epoch 92/100 steps 25/100, |train-loss: 0.6555
# epoch 92/100 steps 30/100, |train-loss: 0.6934
# epoch 92/100 steps 35/100, |train-loss: 0.5425
# epoch 92/100 steps 40/100, |train-loss: 0.6175
# epoch 92/100 steps 45/100, |train-loss: 0.9185
# epoch 92/100 steps 50/100, |train-loss: 0.8471
# epoch 92/100 steps 55/100, |train-loss: 0.6359
# epoch 92/100 steps 60/100, |train-loss: 0.4621
# epoch 92/100 steps 65/100, |train-loss: 0.7750
# epoch 92/100 steps 70/100, |train-loss: 1.1281
# epoch 92/100 steps 75/100, |train-loss: 0.7099
# epoch 92/100 steps 80/100, |train-loss: 0.5150
# epoch 92/100 steps 85/100, |train-loss: 0.4060
# epoch 92/100 steps 90/100, |train-loss: 0.9208
# epoch 92/100 steps 95/100, |train-loss: 0.4897
# epoch 92/100 steps 100/100, |train-loss: 0.6586 |avg-loss: 0.6284 dur 13.1s
# val-acc: 0.6000 val-AUC: 0.4977 |best-acc: 0.6533 at epoch 83
# epoch 93/100 steps 5/100, |train-loss: 0.6753
# epoch 93/100 steps 10/100, |train-loss: 0.6471
# epoch 93/100 steps 15/100, |train-loss: 0.6516
# epoch 93/100 steps 20/100, |train-loss: 0.6249
# epoch 93/100 steps 25/100, |train-loss: 0.5754
# epoch 93/100 steps 30/100, |train-loss: 0.5205
# epoch 93/100 steps 35/100, |train-loss: 0.3261
# epoch 93/100 steps 40/100, |train-loss: 0.6359
# epoch 93/100 steps 45/100, |train-loss: 0.7524
# epoch 93/100 steps 50/100, |train-loss: 0.6123
# epoch 93/100 steps 55/100, |train-loss: 0.5666
# epoch 93/100 steps 60/100, |train-loss: 0.4235
# epoch 93/100 steps 65/100, |train-loss: 0.5235
# epoch 93/100 steps 70/100, |train-loss: 0.5614
# epoch 93/100 steps 75/100, |train-loss: 0.2148
# epoch 93/100 steps 80/100, |train-loss: 0.8437
# epoch 93/100 steps 85/100, |train-loss: 0.4620
# epoch 93/100 steps 90/100, |train-loss: 0.3876
# epoch 93/100 steps 95/100, |train-loss: 0.3602
# epoch 93/100 steps 100/100, |train-loss: 0.6712 |avg-loss: 0.6128 dur 12.4s
# val-acc: 0.5333 val-AUC: 0.4853 |best-acc: 0.6533 at epoch 83
# epoch 94/100 steps 5/100, |train-loss: 0.5652
# epoch 94/100 steps 10/100, |train-loss: 0.6476
# epoch 94/100 steps 15/100, |train-loss: 0.9621
# epoch 94/100 steps 20/100, |train-loss: 0.4626
# epoch 94/100 steps 25/100, |train-loss: 0.2415
# epoch 94/100 steps 30/100, |train-loss: 0.7856
# epoch 94/100 steps 35/100, |train-loss: 0.5715
# epoch 94/100 steps 40/100, |train-loss: 0.3424
# epoch 94/100 steps 45/100, |train-loss: 0.4159
# epoch 94/100 steps 50/100, |train-loss: 1.1842
# epoch 94/100 steps 55/100, |train-loss: 0.4877
# epoch 94/100 steps 60/100, |train-loss: 0.4186
# epoch 94/100 steps 65/100, |train-loss: 0.6930
# epoch 94/100 steps 70/100, |train-loss: 0.6733
# epoch 94/100 steps 75/100, |train-loss: 0.6782
# epoch 94/100 steps 80/100, |train-loss: 0.5902
# epoch 94/100 steps 85/100, |train-loss: 0.6818
# epoch 94/100 steps 90/100, |train-loss: 0.7166
# epoch 94/100 steps 95/100, |train-loss: 0.6006
# epoch 94/100 steps 100/100, |train-loss: 0.5454 |avg-loss: 0.6190 dur 12.5s
# val-acc: 0.5333 val-AUC: 0.4830 |best-acc: 0.6533 at epoch 83
# epoch 95/100 steps 5/100, |train-loss: 0.7581
# epoch 95/100 steps 10/100, |train-loss: 0.3787
# epoch 95/100 steps 15/100, |train-loss: 0.3329
# epoch 95/100 steps 20/100, |train-loss: 0.5840
# epoch 95/100 steps 25/100, |train-loss: 0.3767
# epoch 95/100 steps 30/100, |train-loss: 0.6582
# epoch 95/100 steps 35/100, |train-loss: 0.5881
# epoch 95/100 steps 40/100, |train-loss: 0.8010
# epoch 95/100 steps 45/100, |train-loss: 0.5234
# epoch 95/100 steps 50/100, |train-loss: 0.7145
# epoch 95/100 steps 55/100, |train-loss: 1.0742
# epoch 95/100 steps 60/100, |train-loss: 0.5007
# epoch 95/100 steps 65/100, |train-loss: 0.5556
# epoch 95/100 steps 70/100, |train-loss: 0.5606
# epoch 95/100 steps 75/100, |train-loss: 0.4683
# epoch 95/100 steps 80/100, |train-loss: 0.5650
# epoch 95/100 steps 85/100, |train-loss: 0.7606
# epoch 95/100 steps 90/100, |train-loss: 0.3805
# epoch 95/100 steps 95/100, |train-loss: 0.5855
# epoch 95/100 steps 100/100, |train-loss: 0.4499 |avg-loss: 0.6051 dur 12.3s
# val-acc: 0.5733 val-AUC: 0.4969 |best-acc: 0.6533 at epoch 83
# epoch 96/100 steps 5/100, |train-loss: 0.5198
# epoch 96/100 steps 10/100, |train-loss: 0.4418
# epoch 96/100 steps 15/100, |train-loss: 0.5144
# epoch 96/100 steps 20/100, |train-loss: 0.7244
# epoch 96/100 steps 25/100, |train-loss: 0.6901
# epoch 96/100 steps 30/100, |train-loss: 0.6591
# epoch 96/100 steps 35/100, |train-loss: 0.4448
# epoch 96/100 steps 40/100, |train-loss: 0.4942
# epoch 96/100 steps 45/100, |train-loss: 0.6158
# epoch 96/100 steps 50/100, |train-loss: 0.5830
# epoch 96/100 steps 55/100, |train-loss: 0.5652
# epoch 96/100 steps 60/100, |train-loss: 0.4422
# epoch 96/100 steps 65/100, |train-loss: 0.7758
# epoch 96/100 steps 70/100, |train-loss: 0.5785
# epoch 96/100 steps 75/100, |train-loss: 0.6367
# epoch 96/100 steps 80/100, |train-loss: 0.5400
# epoch 96/100 steps 85/100, |train-loss: 0.7071
# epoch 96/100 steps 90/100, |train-loss: 0.5924
# epoch 96/100 steps 95/100, |train-loss: 0.5050
# epoch 96/100 steps 100/100, |train-loss: 0.6979 |avg-loss: 0.5988 dur 12.4s
# val-acc: 0.5733 val-AUC: 0.4884 |best-acc: 0.6533 at epoch 83
# epoch 97/100 steps 5/100, |train-loss: 0.8445
# epoch 97/100 steps 10/100, |train-loss: 0.2397
# epoch 97/100 steps 15/100, |train-loss: 0.4328
# epoch 97/100 steps 20/100, |train-loss: 0.4787
# epoch 97/100 steps 25/100, |train-loss: 0.4764
# epoch 97/100 steps 30/100, |train-loss: 0.5951
# epoch 97/100 steps 35/100, |train-loss: 0.5629
# epoch 97/100 steps 40/100, |train-loss: 0.5155
# epoch 97/100 steps 45/100, |train-loss: 0.4354
# epoch 97/100 steps 50/100, |train-loss: 0.6595
# epoch 97/100 steps 55/100, |train-loss: 0.4725
# epoch 97/100 steps 60/100, |train-loss: 0.8208
# epoch 97/100 steps 65/100, |train-loss: 0.7969
# epoch 97/100 steps 70/100, |train-loss: 0.4554
# epoch 97/100 steps 75/100, |train-loss: 0.7094
# epoch 97/100 steps 80/100, |train-loss: 0.5706
# epoch 97/100 steps 85/100, |train-loss: 0.5171
# epoch 97/100 steps 90/100, |train-loss: 0.4688
# epoch 97/100 steps 95/100, |train-loss: 0.4949
# epoch 97/100 steps 100/100, |train-loss: 1.1078 |avg-loss: 0.5784 dur 12.3s
# val-acc: 0.6267 val-AUC: 0.5039 |best-acc: 0.6533 at epoch 83
# epoch 98/100 steps 5/100, |train-loss: 0.5914
# epoch 98/100 steps 10/100, |train-loss: 0.5785
# epoch 98/100 steps 15/100, |train-loss: 0.6811
# epoch 98/100 steps 20/100, |train-loss: 0.5608
# epoch 98/100 steps 25/100, |train-loss: 0.4616
# epoch 98/100 steps 30/100, |train-loss: 0.5702
# epoch 98/100 steps 35/100, |train-loss: 0.6549
# epoch 98/100 steps 40/100, |train-loss: 0.5126
# epoch 98/100 steps 45/100, |train-loss: 0.2308
# epoch 98/100 steps 50/100, |train-loss: 0.7423
# epoch 98/100 steps 55/100, |train-loss: 0.8528
# epoch 98/100 steps 60/100, |train-loss: 0.2791
# epoch 98/100 steps 65/100, |train-loss: 1.1725
# epoch 98/100 steps 70/100, |train-loss: 0.1958
# epoch 98/100 steps 75/100, |train-loss: 0.4393
# epoch 98/100 steps 80/100, |train-loss: 1.0575
# epoch 98/100 steps 85/100, |train-loss: 0.6034
# epoch 98/100 steps 90/100, |train-loss: 0.3812
# epoch 98/100 steps 95/100, |train-loss: 0.4139
# epoch 98/100 steps 100/100, |train-loss: 0.6118 |avg-loss: 0.6009 dur 12.5s
# val-acc: 0.5867 val-AUC: 0.5023 |best-acc: 0.6533 at epoch 83
# epoch 99/100 steps 5/100, |train-loss: 0.3927
# epoch 99/100 steps 10/100, |train-loss: 0.4483
# epoch 99/100 steps 15/100, |train-loss: 0.6363
# epoch 99/100 steps 20/100, |train-loss: 0.7182
# epoch 99/100 steps 25/100, |train-loss: 0.6388
# epoch 99/100 steps 30/100, |train-loss: 0.6070
# epoch 99/100 steps 35/100, |train-loss: 0.5136
# epoch 99/100 steps 40/100, |train-loss: 0.5078
# epoch 99/100 steps 45/100, |train-loss: 0.7256
# epoch 99/100 steps 50/100, |train-loss: 0.5936
# epoch 99/100 steps 55/100, |train-loss: 0.6702
# epoch 99/100 steps 60/100, |train-loss: 0.5387
# epoch 99/100 steps 65/100, |train-loss: 0.4730
# epoch 99/100 steps 70/100, |train-loss: 1.0380
# epoch 99/100 steps 75/100, |train-loss: 0.4249
# epoch 99/100 steps 80/100, |train-loss: 0.6458
# epoch 99/100 steps 85/100, |train-loss: 0.5699
# epoch 99/100 steps 90/100, |train-loss: 0.5348
# epoch 99/100 steps 95/100, |train-loss: 0.4233
# epoch 99/100 steps 100/100, |train-loss: 0.7854 |avg-loss: 0.5891 dur 12.4s
# val-acc: 0.5600 val-AUC: 0.4861 |best-acc: 0.6533 at epoch 83
# epoch 100/100 steps 5/100, |train-loss: 0.6874
# epoch 100/100 steps 10/100, |train-loss: 0.3431
# epoch 100/100 steps 15/100, |train-loss: 0.4119
# epoch 100/100 steps 20/100, |train-loss: 0.3732
# epoch 100/100 steps 25/100, |train-loss: 0.6062
# epoch 100/100 steps 30/100, |train-loss: 0.6335
# epoch 100/100 steps 35/100, |train-loss: 0.4674
# epoch 100/100 steps 40/100, |train-loss: 0.4109
# epoch 100/100 steps 45/100, |train-loss: 0.6019
# epoch 100/100 steps 50/100, |train-loss: 0.4829
# epoch 100/100 steps 55/100, |train-loss: 0.5866
# epoch 100/100 steps 60/100, |train-loss: 0.8232
# epoch 100/100 steps 65/100, |train-loss: 0.4978
# epoch 100/100 steps 70/100, |train-loss: 0.7687
# epoch 100/100 steps 75/100, |train-loss: 0.4239
# epoch 100/100 steps 80/100, |train-loss: 0.5478
# epoch 100/100 steps 85/100, |train-loss: 0.7048
# epoch 100/100 steps 90/100, |train-loss: 0.5160
# epoch 100/100 steps 95/100, |train-loss: 0.3361
# epoch 100/100 steps 100/100, |train-loss: 0.7690 |avg-loss: 0.5637 dur 12.3s
# val-acc: 0.4133 val-AUC: 0.4853 |best-acc: 0.6533 at epoch 83|100ep model saved
# train completed, best_metric: 0.6533 at epoch: 83 for 100 epoches
# CPU times: user 20min 54s, sys: 5min 21s, total: 26min 15s
# Wall time: 30min 22s

# %%
# !rm -rf pymp-*

# %%
plt.figure("train", (12, 6))
plt.subplot(1, 2, 1)
plt.title("Epoch Average Loss")
x = [i + 1 for i in range(len(epoch_loss_values))]
y = epoch_loss_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.subplot(1, 2, 2)
plt.title("Val AUC")
x = [val_interval * (i + 1) for i in range(len(metric_values))]
y = metric_values
plt.xlabel("epoch")
plt.plot(x, y)

plt.show()

# %%
from enum import Enum
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from monai.metrics import ConfusionMatrixMetric
class Diagnosis(Enum):
    no_MVI = 0
    MVI = 1    

# %matplotlib inline
# Load best model
model.load_state_dict(torch.load(os.path.join(root_dir, "{}_model_best.pth".format(model_name))))
model.to(device)
model.eval()

with torch.no_grad():
    y_pred = torch.tensor([], dtype=torch.float32, device=device)
    y = torch.tensor([], dtype=torch.long, device=device)

    for val_data in val_loader:
        val_images, val_labels = val_data["image"].to(
            device), val_data["label"].to(device),

        outputs = model(val_images)
        y_pred = torch.cat([y_pred, outputs[0].argmax(dim=1)], dim=0)
        y = torch.cat([y, val_labels], dim=0)

print(classification_report(
    y.cpu().numpy(),
    y_pred.cpu().numpy(),
    target_names=[d.name for d in Diagnosis]))

cm = confusion_matrix (
    y.cpu().numpy(),
    y_pred.cpu().numpy(),
    normalize=None,
)
cmm = ConfusionMatrixMetric(include_background=True, metric_name=["sensitivity","specificity","negative predictive value"])

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=[d.name for d in Diagnosis],
)
disp.plot(ax=plt.subplots(1, 1, facecolor='white')[1])
# Out:
#               precision    recall  f1-score   support
#
#       no_MVI       0.60      0.11      0.19        27
#          MVI       0.66      0.96      0.78        48
#
#     accuracy                           0.65        75
#    macro avg       0.63      0.53      0.48        75
# weighted avg       0.64      0.65      0.57        75
